# %%
import sys
import importlib
sys.path.append('../')  # Adjust the path as needed


import utilities.functions as functions
import utilities.plot as plot
from tqdm import tqdm
import pandas as pd
from ms0_5.IN.data import primary_accessory_mutations as IN_db
from ms0_5.PR.data import primary_accessory_mutations as PR_db
from ms0_5.RT.data import primary_accessory_mutations as RT_db
# Reload the module to reflect the changes
importlib.reload(functions)
importlib.reload(plot)

#NRTI_primary_mutations
#NNRTI_primary_mutations
#PR_primary_mutations
#IN_primary_mutations
#
# Out:
# <module 'utilities.plot' from '/Users/xuechenkan/potts_model_test/ms0_5/../utilities/plot.py'>

# %%
IN_seq_path = 'IN/data/in.reduce4.seq'
PR_seq_path = 'PR/data/pr.exper.reduce4.seq'    
RT_seq_path = 'RT/data/rt.reduce4.seq'

IN_all_seq = functions.read_seq('IN/data/in.reduce4.seq')
PR_all_seq = functions.read_seq('PR/data/pr.exper.reduce4.seq')
RT_all_seq = functions.read_seq('RT/data/rt.reduce4.seq')

IN_consensus = 'IN/data/in.consensus.reduce4.seq'
with open(IN_consensus, 'r') as f:
    IN_consensus_seq = f.read().strip()
# print("IN consensus sequence:", IN_consensus_seq)
PR_consensus = 'PR/data/pr.consensus.reduce4.seq'
with open(PR_consensus, 'r') as f:
    PR_consensus_seq = f.read().strip()
RT_consensus = 'RT/data/rt.consensus.reduce4.seq'
with open(RT_consensus, 'r') as f:
    RT_consensus_seq = f.read().strip()

# print(IN_consensus_seq)
IN_min_position = 1
IN_max_position = 263
PR_min_position = 1
PR_max_position = 99
RT_min_position = 39
RT_max_position = 226

IN_redux = functions.get_redu_dict('IN/data/in.reduce4.redux',1)
PR_redux = functions.get_redu_dict('PR/data/pr.reduce4.redux',0)
RT_redux = functions.get_redu_dict('RT/data/rt.reduce4.redux',0)

IN_J = functions.load_J_dict('IN/data/J.npy',IN_min_position,IN_max_position)
PR_J = functions.load_J_dict('PR/data/J_PR.npy',PR_min_position,PR_max_position)
RT_J = functions.load_J_dict('RT/data/J_RT.npy',RT_min_position,RT_max_position)

IN_all_seq_unreduced = functions.read_seq('IN/data/in.fullseq')
PR_all_seq_unreduced = functions.read_seq('PR/data/pr.exper.fullseq')
RT_all_seq_unreduced = functions.read_seq('RT/data/rt.fullseq')

INSTI_DRAPs = [
    51, 66, 74, 92, 97, 118, 121, 138, 140, 142, 143, 145, 146, 147,
    148, 149, 151, 153, 155, 157, 163, 230, 263, 50, 54, 68, 95, 114,
    119, 128, 232
]


PI_DRAPs = [
    10, 11, 16, 20, 24, 30, 32, 33, 34, 36, 43, 46, 47, 48, 50, 53, 54,
    58, 60, 62, 63, 64, 69, 71, 73, 74, 76, 77, 82, 83, 84, 85, 88, 89,
    90, 93
]


NNRTI_DRAPs = [
    90, 98, 100, 101, 103, 106, 108, 132,
    138, 179, 181, 184, 188, 190, 221, 225
]


NRTI_DRAPs = [
    40, 41, 43, 44, 62, 65, 67, 69, 70, 74, 75, 77, 115, 116, 118, 151, 
    184, 203, 208, 210, 215, 218, 219, 223
]

# %%
# pair1_reduced = functions.unreduced_to_reduced(IN_redux, 'Y143R')
# pair2_reduced = functions.unreduced_to_reduced(IN_redux, 'I151V')

pair1_reduced = functions.unreduced_to_reduced(IN_redux, 'E138K')
pair2_reduced = functions.unreduced_to_reduced(IN_redux, 'Q148K')
print("Pair 1 reduced:", pair1_reduced, "Pair 2 reduced:", pair2_reduced)
print(functions.calculate_dde_v2(pair1_reduced,pair2_reduced, IN_consensus_seq, IN_J, 1,263))
# Out:
# Pair 1 reduced: D138A Pair 2 reduced: D148A
# (np.float32(-5.7896967), np.float32(-7.125413), np.float32(-8.014598), np.float32(4.9005117))

# %%
pair1_reduced = functions.unreduced_to_reduced(IN_redux, 'Y143R')
pair2_reduced = functions.unreduced_to_reduced(IN_redux, 'N155H')
print("Pair 1 reduced:", pair1_reduced, "Pair 2 reduced:", pair2_reduced)
print(functions.calculate_dde_v2(pair1_reduced,pair2_reduced, IN_consensus_seq, IN_J, 1,263))

pair1_reduced = functions.unreduced_to_reduced(IN_redux, 'N155H')
pair2_reduced = functions.unreduced_to_reduced(IN_redux, 'K160R')
print("Pair 1 reduced:", pair1_reduced, "Pair 2 reduced:", pair2_reduced)
print(functions.calculate_dde_v2(pair1_reduced,pair2_reduced, IN_consensus_seq, IN_J, 1,263))
# Out:
# Pair 1 reduced: D143C Pair 2 reduced: A155C
# (np.float32(-3.5068889), np.float32(-2.0809908), np.float32(-7.904745), np.float32(-2.3168654))
# Pair 1 reduced: A155C Pair 2 reduced: D160C
# (np.float32(-2.0809908), np.float32(-5.4081416), np.float32(-9.011467), np.float32(-1.5223346))

# %%
pair1_reduced = functions.unreduced_to_reduced(PR_redux, 'I54A')
pair2_reduced = functions.unreduced_to_reduced(PR_redux, 'V82A')
print("Pair 1 reduced:", pair1_reduced, "Pair 2 reduced:", pair2_reduced)
print(functions.calculate_dde_v2(pair1_reduced,pair2_reduced, PR_consensus_seq, PR_J, 1,99))

pair1_reduced = functions.unreduced_to_reduced(PR_redux, 'I54V')
pair2_reduced = functions.unreduced_to_reduced(PR_redux, 'V82A')
print("Pair 1 reduced:", pair1_reduced, "Pair 2 reduced:", pair2_reduced)
print(functions.calculate_dde_v2(pair1_reduced,pair2_reduced, PR_consensus_seq, PR_J, 1,99))
# Out:
# Pair 1 reduced: C54A Pair 2 reduced: C82B
# (np.float32(-8.926517), np.float32(-3.2296362), np.float32(-9.210552), np.float32(2.9456005))
# Pair 1 reduced: C54D Pair 2 reduced: C82B
# (np.float32(-4.8560233), np.float32(-3.2296362), np.float32(-5.2233877), np.float32(2.8622718))

# %%
#NRTI
pair1_reduced = functions.unreduced_to_reduced(RT_redux, 'K70R')
pair2_reduced = functions.unreduced_to_reduced(RT_redux, 'K219E')
print("Pair 1 reduced:", pair1_reduced, "Pair 2 reduced:", pair2_reduced)
print(functions.calculate_dde_v2(pair1_reduced,pair2_reduced, RT_consensus_seq, RT_J, 39,226))

pair1_reduced = functions.unreduced_to_reduced(RT_redux, 'V75I')
pair2_reduced = functions.unreduced_to_reduced(RT_redux, 'Q151M')
print("Pair 1 reduced:", pair1_reduced, "Pair 2 reduced:", pair2_reduced)
print(functions.calculate_dde_v2(pair1_reduced,pair2_reduced, RT_consensus_seq, RT_J, 39,226))
# Out:
# Pair 1 reduced: C70D Pair 2 reduced: C219A
# (np.float32(-3.3554964), np.float32(-5.2935934), np.float32(-5.8770666), np.float32(2.7720232))
# Pair 1 reduced: A75C Pair 2 reduced: D151C
# (np.float32(-5.19946), np.float32(-5.2563076), np.float32(-8.584975), np.float32(1.8707924))

# %%
#NNRTI
pair1_reduced = functions.unreduced_to_reduced(RT_redux, 'L100I')
pair2_reduced = functions.unreduced_to_reduced(RT_redux, 'K103N')
print("Pair 1 reduced:", pair1_reduced, "Pair 2 reduced:", pair2_reduced)
print(functions.calculate_dde_v2(pair1_reduced,pair2_reduced, RT_consensus_seq, RT_J, 39,226))

pair1_reduced = functions.unreduced_to_reduced(RT_redux, 'K101Q')
pair2_reduced = functions.unreduced_to_reduced(RT_redux, 'G190S')
print("Pair 1 reduced:", pair1_reduced, "Pair 2 reduced:", pair2_reduced)
print(functions.calculate_dde_v2(pair1_reduced,pair2_reduced, RT_consensus_seq, RT_J, 39,226))
# Out:
# Pair 1 reduced: C100B Pair 2 reduced: C103B
# (np.float32(-5.4267626), np.float32(-1.1189523), np.float32(-3.9572763), np.float32(2.5884385))
# Pair 1 reduced: C101B Pair 2 reduced: D190C
# (np.float32(-3.3310685), np.float32(-4.1833305), np.float32(-5.485812), np.float32(2.0285869))
