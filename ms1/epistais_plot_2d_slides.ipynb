# %%
import matplotlib.pyplot as plt
import sys
import importlib  # Import the importlib module
# Adjust y-axis limits to not be symmetrical
sys.path.append('../')  # Adjust the path as needed
from utilities.functions import *
from utilities.plot import *
import utilities.functions as functions
import utilities.plot as plot

# Reload the module to reflect the changes
importlib.reload(functions)
importlib.reload(plot)


def draw_2d_plot_with_arrows(de1, de2, de12):
    # Define x-axis labels and corresponding positions
    y_min = min(0, de1, de2, de12) - 1
    y_max = max(0, de1, de2, de12) + 1
    x_labels = ['DEm1', 'DEm2', 'DEm1m2']
    x_positions = [0, 1, 2]
    
    # Define y-axis values
    y_values = [de1, de2, de12]
    
    # Define colors based on the sign of the values
    colors = ['blue' if de > 0 else 'red' for de in y_values]
    
    # Create the plot
    plt.figure(figsize=(6, 4))
    for x, y, color in zip(x_positions, y_values, colors):
        # Draw the arrow
        plt.arrow(x, 0, 0, y, head_width=0.1, head_length=0.2, fc=color, ec=color, length_includes_head=True)
        # Draw the horizontal line at the y-level of the arrow
        plt.plot([x - 0.25, x + 0.25], [y, y], color=color, linewidth=1.5)
    
    # Set x-axis labels and limits
    plt.xticks(x_positions, x_labels)
    plt.xlim(-0.5, 2.5)
    
    # Set y-axis limits
    # y_max = max(abs(de1), abs(de2), abs(de12))
    plt.ylim(y_min, y_max)
    
    # Add grid and labels
    plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.ylabel('DE values')
    plt.title('')
    
    # Show the plot
    plt.show()

# %%
# draw_2d_plot_with_arrows(-7.654872392, -7.701221402, -6.847302347)
# draw_2d_plot_with_arrows(-8.819572784, -7.610829136, -7.921610474)
# draw_2d_plot_with_arrows(-5.459149698, -4.374572854, -1.324931105)

# draw_2d_plot_with_arrows(-7.670997436, -6.936329457, -9.996448665)
# draw_2d_plot_with_arrows(-2.74528407, -4.643937674, -2.778343514)
# draw_2d_plot_with_arrows(-2.109976037, -4.10300385, -1.602101658)

# draw_2d_plot_with_arrows(-5.306311152, -5.231635469, -7.234272221)
# draw_2d_plot_with_arrows(-3.159514975, -4.072060009, -3.927900584)
# draw_2d_plot_with_arrows(0.502141475, -1.579579439, 1.55834097)

# draw_2d_plot_with_arrows(-1, -4, -3)
# draw_2d_plot_with_arrows(-8, -9, -5)
# draw_2d_plot_with_arrows(-8, -3, -11)

# draw_2d_plot_with_arrows(-7.654872392, -7.701221402, -6.847302347)
# draw_2d_plot_with_arrows(-4.992795303, -5.185906099, -1.669909955)
# plot.plot_epistatic_plane(21, -7.654872392, -7.701221402, -6.847302347)
# plot.plot_epistatic_plane(21, -4.992795303, -5.185906099, -1.669909955)

# draw_2d_plot_with_arrows(-8.819572784, -7.610829136, -7.921610474)
# draw_2d_plot_with_arrows(-9.428811382, -7.822749364, -8.742769299)
# plot.plot_epistatic_plane(21, -8.819572784, -7.610829136, -7.921610474)
# plot.plot_epistatic_plane(21, -9.428811382, -7.822749364, -8.742769299)

# draw_2d_plot_with_arrows(-7.312340181, -5.870150968, -4.673699703)
# draw_2d_plot_with_arrows(-5.459149698, -4.374572854, -1.324931105)
# plot.plot_epistatic_plane(21, -7.312340181, -5.870150968, -4.673699703)
# plot.plot_epistatic_plane(21, -5.459149698, -4.374572854, -1.324931105)

# draw_2d_plot_with_arrows(-7.670997436, -6.936329457, -9.996448665)
# draw_2d_plot_with_arrows(-6.982896819, -6.548923015, -8.920941605)
# plot.plot_epistatic_plane(21, -7.670997436, -6.936329457, -9.996448665)
# plot.plot_epistatic_plane(21, -6.982896819, -6.548923015, -8.920941605)

# draw_2d_plot_with_arrows(-2.74528407, -4.643937674, -2.778343514)
# draw_2d_plot_with_arrows(-2.062116206, -4.783926957, -2.235164933)
# plot.plot_epistatic_plane(21, -2.74528407, -4.643937674, -2.778343514)
# plot.plot_epistatic_plane(21, -2.062116206, -4.783926957, -2.235164933)

# draw_2d_plot_with_arrows(-2.109976037, -4.10300385, -1.602101658)
# draw_2d_plot_with_arrows(-3.264474468, -4.118661128, -2.772257368)
# plot.plot_epistatic_plane(21, -2.109976037, -4.10300385, -1.602101658)
# plot.plot_epistatic_plane(21, -3.264474468, -4.118661128, -2.772257368)

draw_2d_plot_with_arrows(-1.078471596, -6.112375492, -4.555068155)
draw_2d_plot_with_arrows(1.179129899, -7.408113703, -3.593204871)
draw_2d_plot_with_arrows(0.502141475, -1.579579439, 1.55834097)
draw_2d_plot_with_arrows(-0.575542833, -1.765521421, 0.29471468)
# plot.plot_epistatic_plane(21, -1.078471596, -6.112375492, -4.555068155)
# plot.plot_epistatic_plane(21, 1.179129899, -7.408113703, -3.593204871)
# plot.plot_epistatic_plane(21, 0.502141475, -1.579579439, 1.55834097)
# plot.plot_epistatic_plane(21, -0.575542833, -1.765521421, 0.29471468)
