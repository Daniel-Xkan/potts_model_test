# %% [markdown]
# read dde from kn.her.all, first column includes two single mutations aa and site information, second column is dde, third is DE_double, fourth is first de, fifth is second de

# %% [markdown]
# # 1. read dde from file

# %%
import pandas as pd
# Try reading the file with space as a delimiter
df = pd.read_csv('../data/kn.her2.all', delim_whitespace=True, header=None, names=['Mutation', 'DDE','DE_double', 'First_DE', 'Second_DE'])
# Split the 'Mutation' column into 'First_mutation' and 'Second_mutation'
df[['First_mutation', 'Second_mutation']] = df['Mutation'].str.split('-', expand=True)
# Display the DataFrame
print(df)
# Out:
# /var/folders/17/rj19bvws2qscyfjmb7m44zmm0000gn/T/ipykernel_81417/1655497556.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('../data/kn.her2.all', delim_whitespace=True, header=None, names=['Mutation', 'DDE','DE_double', 'First_DE', 'Second_DE'])
#            Mutation       DDE  DE_double  First_DE  Second_DE First_mutation  \
# 0           A1B-B2A  0.012168 -20.532304 -8.380550 -12.211337            A1B
# 1           A1B-B2C -0.000908 -16.498453 -8.380550  -8.179655            A1B
# 2           A1B-B2D  0.000125 -16.658839 -8.380550  -8.339867            A1B
# 3           A1B-A3B  0.008785 -14.738873 -8.380550  -6.419735            A1B
# 4           A1B-A3C  0.008937 -13.811957 -8.380550  -5.493224            A1B
# ...             ...       ...        ...       ...        ...            ...
# 310072  B262C-A263C  0.390912 -16.406621 -8.433813  -8.236725          B262C
# 310073  B262C-A263D  0.391073 -16.553047 -8.433813  -8.383161          B262C
# 310074  B262D-A263B  0.267580 -15.236453 -8.310417  -7.223255          B262D
# 310075  B262D-A263C  0.001986 -16.321536 -8.310417  -8.236725          B262D
# 310076  B262D-A263D  0.002057 -16.467874 -8.310417  -8.383161          B262D
#
#        Second_mutation
# 0                  B2A
# 1                  B2C
# 2                  B2D
# 3                  A3B
# 4                  A3C
# ...                ...
# 310072           A263C
# 310073           A263D
# 310074           A263B
# 310075           A263C
# 310076           A263D
#
# [310077 rows x 7 columns]

# %%
# Filter rows for D148B and C140D
filtered_dde = df[(df['First_mutation'] == 'D148B') & (df['Second_mutation'] == 'C140D') |
                  (df['First_mutation'] == 'C140D') & (df['Second_mutation'] == 'D148B')]

# Print the DDE values
print(filtered_dde)
# Out:
#            Mutation      DDE  DE_double  First_DE  Second_DE First_mutation  \
# 242203  C140D-D148B  8.50879 -11.219437 -6.705909  -4.577816          C140D
#
#        Second_mutation
# 242203           D148B

# %% [markdown]
# # 2. index each sequence by its mutations compared to in.consensus.reduce4.seq

# %% [markdown]
# read in from ../data/in.reduce4.seq, there are 1220 sequences, create a df, with last column as mutations: with a list of mutaiton that occored compared to ../data/in.consensus.reduce4.seq the mutations are in format for example: [D148B, C140D, ...] where D and C notes the wildtime from consensus at pos 148 and 140

# %%
# Read the consensus sequence
with open('../data/in.consensus.reduce4.seq', 'r') as f:
    consensus_sequence = f.read().strip()

# Read the 1220 sequences
sequences = []
with open('../data/in.reduce4.seq', 'r') as f:
    for line in f:
        sequences.append(line.strip())

# Create a DataFrame to store sequences and their mutations
sequence_df = pd.DataFrame({'Sequence': sequences})

# Function to identify mutations compared to the consensus sequence
def find_mutations(sequence, consensus):
    mutations = []
    for i, (seq_residue, cons_residue) in enumerate(zip(sequence, consensus), start=1):
        if seq_residue != cons_residue:
            mutations.append(f"{cons_residue}{i}{seq_residue}")
    return mutations

# Add a column for mutations
sequence_df['Mutations'] = sequence_df['Sequence'].apply(lambda seq: find_mutations(seq, consensus_sequence))
sequence_df['Mutations_count'] = sequence_df['Mutations'].apply(len)
# Display the DataFrame
print(sequence_df)
# Out:
#                                                Sequence  \
# 0     ABAAABABACBBAACBDBABBDBDBBBAAAAAABAAABDAABAABA...
# 1     ABAAABCBACBBAACBDBABCDBDABBAAACAABAAABDAABAABA...
# 2     ABAAABCBACBBAACBDBABCDBDABBAAACAABAAABDAABAABA...
# 3     ABAAABCBACABAACBABABBDBDBBBBAACAABAAABAAABAABA...
# 4     ABAAABCBABABAACBDBABBDBDBBBAAACAABAAABDAABAABA...
# ...                                                 ...
# 1215  ABAAABCBACABAACBABABBDBDBBBBAACAABAAABDAABAAAA...
# 1216  ABAAABCBACABAACBDBABBDBDBBBAAACAABAAABDAABAAAA...
# 1217  ABAAABCBACABAACBABABBDBDBBBAAAAAABAAABDAABAABA...
# 1218  ABAAABCBACABAACBDBABBDBDBBBAAAAAABAAABDAABAABA...
# 1219  ABAAABCBACBBAACBDBABBDBDBBBBAAABABAABBDAABAABA...
#
#                                               Mutations  Mutations_count
# 0     [C7A, A11B, C31A, C50B, A72D, A101B, C124A, B1...               13
# 1     [A11B, B21C, B25A, D119A, C122B, D125A, D148C,...               13
# 2     [A11B, B21C, B25A, D119A, C122B, D125A, C140D,...               13
# 3     [D17A, A28B, D39A, D119C, C122B, C124A, D125A,...                9
# 4     [C10B, A101B, B106A, A155C, C156A, C165A, C195...                9
# ...                                                 ...              ...
# 1215  [D17A, A28B, B45A, C113D, C124D, D125A, C156A,...                8
# 1216                        [B45A, C140D, D148B, C156A]                4
# 1217  [D17A, C31A, A92B, D119A, C122B, D125A, A155C,...               14
# 1218  [C31A, C59A, A74C, A101B, D112C, C113B, C124A,...               14
# 1219  [A11B, A28B, C31A, A32B, A37B, A56B, D119C, C1...               16
#
# [1220 rows x 3 columns]

# %% [markdown]
# # 3. J matrix and delta e definition

# %% [markdown]
# ## 3.1 J matrix

# %%
import numpy as np

#dictionary of J matrix
J_dict = {}

# Load the J matrix from the downloaded file
J = np.load('../data/J.npy')

row = 0
for pos1 in range(1, 264):
    for pos2 in range(pos1 + 1, 264):

        for i, aa1 in enumerate(['A', 'B', 'C', 'D']):
            for j, aa2 in enumerate(['A', 'B', 'C', 'D']):
                col = i*4+j


                J_dict[(pos1, pos2, aa1, aa2)] = J[row, col]
                J_dict[(pos2, pos1, aa2, aa1)] = J[row, col]
            # print(f"Row {row}: J[{row}, {col}] = {J[row, col]} for positions ({pos1}, {pos2}) with amino acids ({aa1}, {aa2})")
        row += 1

print(f"Dictionary created with {len(J_dict)} entries")
# Out:
# Dictionary created with 1102496 entries

# %% [markdown]
# ## 3.2 define delta e

# %%
# Define delta E calculation
def calculate_delta_e(position, old_amino_acid, new_amino_acid, seq, J_dict):
    # E(old_amino_acid)
    energy_old = 0
    for other_pos in range(1, 264):
        if other_pos == position:
            continue
        other_aa = seq[other_pos - 1]  # Access the first sequence in sequence_list
        energy_old += J_dict.get((position, other_pos, old_amino_acid, other_aa), 0)

    # E(new_amino_acid)
    energy_new = 0
    for other_pos in range(1, 264):
        if other_pos == position:
            continue
        other_aa = seq[other_pos - 1]  # Access the first sequence in sequence_list
        energy_new += J_dict.get((position, other_pos, new_amino_acid, other_aa), 0)

    delta_e = energy_old - energy_new
    # print(f"E({old_amino_acid}) at {position}: {energy_old}")
    # print(f"E({new_amino_acid}) at {position}: {energy_new}")
    # print(f"Delta E for {old_amino_acid}{position}{new_amino_acid}: {delta_e}")
    return delta_e

# # Example usage
# position = 140
# old_amino_acid = 'C'
# new_amino_acid = 'D'
# calculate_delta_e(position, old_amino_acid, new_amino_acid, sequence_list, J_dict)

# %%
# define dm12
def calculate_dm12 (pos1, old_amino_acid1, new_amino_acid1, pos2, old_amino_acid2, new_amino_acid2, seq, J_dict):
    energy_old = 0
    energy_new = 0

# old energy
    for other_pos in range(1, 264):
        other_aa = seq[other_pos - 1] 
        if other_pos == pos1:
            continue
        if other_pos == pos2:
            energy_old += J_dict.get((pos1, pos2, old_amino_acid1, old_amino_acid2), 0)
        else:
            energy_old += J_dict.get((pos1, other_pos, old_amino_acid1, other_aa), 0)

    for other_pos in range(1, 264):
        other_aa = seq[other_pos - 1]
        if other_pos == pos2:
            continue
        if other_pos == pos1:
            # energy_old += J_dict.get((pos2, pos1, old_amino_acid2, old_amino_acid1), 0)
            continue
        else:
            energy_old += J_dict.get((pos2, other_pos, old_amino_acid2, other_aa), 0)

# new energy
    for other_pos in range(1, 264):
        other_aa = seq[other_pos - 1] 
        if other_pos == pos1:
            continue
        if other_pos == pos2:
            energy_new += J_dict.get((pos1, pos2, new_amino_acid1, new_amino_acid2), 0)
        else:
            energy_new += J_dict.get((pos1, other_pos, new_amino_acid1, other_aa), 0)

    for other_pos in range(1, 264):
        other_aa = seq[other_pos - 1] 
        if other_pos == pos2:
            continue
        if other_pos == pos1:
            # energy_new += J_dict.get((pos2, pos1, new_amino_acid2, new_amino_acid1), 0)
            continue
        
        else:
            energy_new += J_dict.get((pos2, other_pos, new_amino_acid2, other_aa), 0)
    
    return energy_old - energy_new

# %% [markdown]
# ## 3.3 flip on 1220

# %% [markdown]
# run de on all 1220 sequences with D148B, C140D (C140D, D148B), if the consensus vs one of 1220 sequences where the DE of each mutation changes its size compare to others  ( DE -DE sign change from consensus where the sign change means the sign of de D148B- deC140D sign change), record that sequence with its mutaitons and mutation len

# %%
# Define the mutations as input parameters
mutation1 = 'D148B'
mutation2 = 'C140D'

# Extract position and amino acid information from the mutations
pos1, old_aa1, new_aa1 = int(mutation1[1:-1]), mutation1[0], mutation1[-1]
pos2, old_aa2, new_aa2 = int(mutation2[1:-1]), mutation2[0], mutation2[-1]

# List to store sequences with sign change
sequences_with_sign_change = []

# Calculate delta E for the consensus sequence
de_mutation1_consensus = calculate_delta_e(pos1, old_aa1, new_aa1, consensus_sequence, J_dict)
de_mutation2_consensus = calculate_delta_e(pos2, old_aa2, new_aa2, consensus_sequence, J_dict)

print("-" * 50)
print(f'Consensus delta E for {mutation1}: {de_mutation1_consensus}, {mutation2}: {de_mutation2_consensus}')
print('Consensus dm12:', calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, consensus_sequence, J_dict))
print("-" * 50)

# Iterate through all sequences
for index, row in sequence_df.iterrows():
    sequence = row['Sequence']
    mutations = row['Mutations']
    mutation_count = row['Mutations_count']
    
    # Skip sequences without the specified mutations
    if mutation1 not in mutations or mutation2 not in mutations:
        # continue
        pass
    
    # Calculate delta E for the specified mutations
    de_mutation1 = calculate_delta_e(pos1, old_aa1, new_aa1, sequence, J_dict)
    de_mutation2 = calculate_delta_e(pos2, old_aa2, new_aa2, sequence, J_dict)
    
    # Check for sign change
    if (de_mutation1 - de_mutation2) * (de_mutation1_consensus - de_mutation2_consensus) < 0:
        dm12 = calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, sequence, J_dict)
        min_dm1_dm2 = min(de_mutation1, de_mutation2)
        max_dm1_dm2 = max(de_mutation1, de_mutation2)
        max_divide_min_dm1_dm2 = max_dm1_dm2 / min_dm1_dm2
        
        sequences_with_sign_change.append({
            'Sequence': sequence,
            'Mutations': mutations,
            'Mutation_count': mutation_count,
            'dm1': de_mutation1,
            'dm2': de_mutation2,
            'Dm1m2-max/min(dm1,dm2)': dm12 - max_divide_min_dm1_dm2,
            'Dm1m2-min(dm1,dm2)': dm12 - min_dm1_dm2
        })

# Create a DataFrame to store the results
sign_change_df = pd.DataFrame(sequences_with_sign_change)

# Sort the DataFrame by 'Dm1m2-min(dm1,dm2)' in descending order
sign_change_df = sign_change_df.sort_values(by='Dm1m2-min(dm1,dm2)', ascending=False)

# Print the results
for _, row in sign_change_df.iterrows():
    print(f"dm1: {row['dm1']}, dm2: {row['dm2']}")
    print(f"Mutations: {row['Mutations']}")
    print(f"Mutation Count: {row['Mutation_count']}")
    print(f"Dm1m2-min(dm1,dm2): {row['Dm1m2-min(dm1,dm2)']}")
    print("-" * 50)
# Out:
# --------------------------------------------------
# Consensus delta E for D148B: -4.553504943847656, C140D: -5.7286787033081055
# Consensus dm12: -1.7733955
# --------------------------------------------------
# dm1: -3.9327640533447266, dm2: -3.61911678314209
# Mutations: ['A11B', 'A28B', 'A37B', 'D39A', 'C50A', 'A72D', 'D112A', 'C124A', 'D125A', 'A167B', 'B201A', 'D253A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 4.889682769775391
# --------------------------------------------------
# dm1: -4.527413845062256, dm2: -3.775723457336426
# Mutations: ['C50A', 'A101B', 'A176B', 'B205A', 'B206A', 'D218C', 'B227A', 'D255C', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.733062267303467
# --------------------------------------------------
# dm1: -4.601166248321533, dm2: -4.03400993347168
# Mutations: ['D17A', 'A72D', 'A74C', 'C124A', 'D125A', 'C156A', 'A167B', 'B201A', 'C220B', 'B227A', 'D230A', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 4.47477388381958
# --------------------------------------------------
# dm1: -4.78171443939209, dm2: -4.052134990692139
# Mutations: ['A11B', 'A28B', 'A37B', 'A41C', 'B45A', 'A72D', 'C156A', 'B201A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.456656455993652
# --------------------------------------------------
# dm1: -4.379714012145996, dm2: -4.071926116943359
# Mutations: ['B6A', 'A14B', 'D17A', 'D24A', 'B25A', 'A28B', 'D39A', 'B45A', 'C50A', 'A74C']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 4.436858177185059
# --------------------------------------------------
# dm1: -6.257948398590088, dm2: -4.072028160095215
# Mutations: ['C50A', 'A74C', 'A101B', 'B111C', 'B157A', 'D160C', 'A193D', 'B201A', 'D253A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.436757564544678
# --------------------------------------------------
# dm1: -4.4074859619140625, dm2: 0.8113842010498047
# Mutations: ['D24C', 'A74C', 'A101B', 'D125A', 'D148C', 'B201A', 'D216A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.115972518920898
# --------------------------------------------------
# dm1: -4.966127395629883, dm2: -4.425081253051758
# Mutations: ['A101B', 'D112B', 'B157A', 'D160B', 'B173A', 'B200A', 'B201A', 'D230A', 'C234D']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.083703994750977
# --------------------------------------------------
# dm1: -4.966127395629883, dm2: -4.425081253051758
# Mutations: ['A101B', 'D112B', 'B157A', 'D160B', 'B173A', 'B200A', 'B201A', 'D230A', 'C234D']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.083703994750977
# --------------------------------------------------
# dm1: -4.966127395629883, dm2: -4.425081253051758
# Mutations: ['A101B', 'D112B', 'B157A', 'D160B', 'B173A', 'B200A', 'B201A', 'D230A', 'C234D']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.083703994750977
# --------------------------------------------------
# dm1: -5.328548908233643, dm2: -4.434983730316162
# Mutations: ['C31A', 'B106A', 'B111C', 'B157A', 'D160B', 'B201A', 'B256A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.073797702789307
# --------------------------------------------------
# dm1: -5.93227481842041, dm2: -4.448690414428711
# Mutations: ['A11B', 'C31A', 'A32B', 'A37B', 'B63A', 'A74C', 'A97B', 'A101B', 'C115A', 'D119B', 'D143B', 'B201A', 'D230A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 4.060114860534668
# --------------------------------------------------
# dm1: -5.419766426086426, dm2: -4.568212509155273
# Mutations: ['C31A', 'A72D', 'A74C', 'B111C', 'D112C', 'B206A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 3.9405813217163086
# --------------------------------------------------
# dm1: -4.946534633636475, dm2: -4.574021816253662
# Mutations: ['D17A', 'A101B', 'D211B', 'D218C', 'B256A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 3.934770107269287
# --------------------------------------------------
# dm1: -4.946534633636475, dm2: -4.574021816253662
# Mutations: ['D17A', 'A101B', 'D211B', 'D218C', 'B256A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 3.934770107269287
# --------------------------------------------------
# dm1: -5.408005714416504, dm2: -4.616400718688965
# Mutations: ['B6A', 'C7B', 'C31A', 'A74C', 'D112B', 'D125A', 'A181B', 'B206A', 'C234D']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 3.892390251159668
# --------------------------------------------------
# dm1: -5.433068752288818, dm2: -4.663212299346924
# Mutations: ['B106A', 'B111C', 'B157A', 'D160B', 'B201A', 'B256A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 3.8455729484558105
# --------------------------------------------------
# dm1: -4.903396129608154, dm2: -4.672615051269531
# Mutations: ['D17A', 'B91C', 'A101B', 'C124A', 'C156A', 'D160C', 'B201A', 'B227A', 'D229B', 'D253B', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 3.8361735343933105
# --------------------------------------------------
# dm1: -5.151336193084717, dm2: -4.703369617462158
# Mutations: ['A11B', 'B23D', 'A28B', 'A37B', 'A101B', 'B206A', 'C215B', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 3.805415630340576
# --------------------------------------------------
# dm1: -5.151336193084717, dm2: -4.703369617462158
# Mutations: ['A11B', 'B23D', 'A28B', 'A37B', 'A101B', 'B206A', 'C215B', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 3.805415630340576
# --------------------------------------------------
# dm1: -5.151336193084717, dm2: -4.703369617462158
# Mutations: ['A11B', 'B23D', 'A28B', 'A37B', 'A101B', 'B206A', 'C215B', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 3.805415630340576
# --------------------------------------------------
# dm1: -5.151336193084717, dm2: -4.703369617462158
# Mutations: ['A11B', 'B23D', 'A28B', 'A37B', 'A101B', 'B206A', 'C215B', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 3.805415630340576
# --------------------------------------------------
# dm1: -1.4754509925842285, dm2: 0.4728221893310547
# Mutations: ['D17A', 'A28B', 'C50A', 'A72D', 'C124A', 'D138A', 'D148C', 'C156A', 'A162B', 'C208A', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 3.777404308319092
# --------------------------------------------------
# dm1: -6.782304763793945, dm2: -4.778985977172852
# Mutations: ['A101B', 'D112B', 'D211B', 'B217A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 3.729802131652832
# --------------------------------------------------
# dm1: -6.782304763793945, dm2: -4.778985977172852
# Mutations: ['A101B', 'D112B', 'D211B', 'B217A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 3.729802131652832
# --------------------------------------------------
# dm1: -6.782304763793945, dm2: -4.778985977172852
# Mutations: ['A101B', 'D112B', 'D211B', 'B217A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 3.729802131652832
# --------------------------------------------------
# dm1: -6.782304763793945, dm2: -4.778985977172852
# Mutations: ['A101B', 'D112B', 'D211B', 'B217A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 3.729802131652832
# --------------------------------------------------
# dm1: -6.782304763793945, dm2: -4.778985977172852
# Mutations: ['A101B', 'D112B', 'D211B', 'B217A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 3.729802131652832
# --------------------------------------------------
# dm1: -6.782304763793945, dm2: -4.778985977172852
# Mutations: ['A101B', 'D112B', 'D211B', 'B217A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 3.729802131652832
# --------------------------------------------------
# dm1: -6.782304763793945, dm2: -4.778985977172852
# Mutations: ['A101B', 'D112B', 'D211B', 'B217A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 3.729802131652832
# --------------------------------------------------
# dm1: -6.782304763793945, dm2: 0.4045529365539551
# Mutations: ['A101B', 'D112B', 'D148A', 'D211B', 'B217A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 3.729802131652832
# --------------------------------------------------
# dm1: -5.429792881011963, dm2: -4.801017761230469
# Mutations: ['A101B', 'D112B', 'D211B']
# Mutation Count: 3
# Dm1m2-min(dm1,dm2): 3.7077717781066895
# --------------------------------------------------
# dm1: -4.863512992858887, dm2: -4.828516006469727
# Mutations: ['D17A', 'A28B', 'D39A', 'B201A', 'D211B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 3.6802682876586914
# --------------------------------------------------
# dm1: -4.863512992858887, dm2: -4.828516006469727
# Mutations: ['D17A', 'A28B', 'D39A', 'B201A', 'D211B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 3.6802682876586914
# --------------------------------------------------
# dm1: -4.97479248046875, dm2: -4.872464656829834
# Mutations: ['C31A', 'B45C', 'A101B', 'B206A', 'B254C']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 3.6363258361816406
# --------------------------------------------------
# dm1: -3.148472309112549, dm2: 0.3215498924255371
# Mutations: ['A11B', 'B21C', 'B25A', 'D119A', 'C122B', 'D125A', 'D148C', 'B201A', 'A203B', 'D218C', 'C234D', 'D253A', 'C259A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 3.6261324882507324
# --------------------------------------------------
# dm1: -5.012301445007324, dm2: -4.963837623596191
# Mutations: ['C31A', 'C165A', 'D211B']
# Mutation Count: 3
# Dm1m2-min(dm1,dm2): 3.54494571685791
# --------------------------------------------------
# dm1: -5.395366668701172, dm2: -4.968169689178467
# Mutations: ['C31A', 'A74C', 'D112B', 'C124A', 'D125A', 'D126C', 'B157A', 'D160B', 'A181B', 'B206A', 'B254C']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 3.540616989135742
# --------------------------------------------------
# dm1: -4.991074562072754, dm2: -4.980190277099609
# Mutations: ['C31A', 'D211B']
# Mutation Count: 2
# Dm1m2-min(dm1,dm2): 3.528590202331543
# --------------------------------------------------
# dm1: -4.991074562072754, dm2: -4.980190277099609
# Mutations: ['C31A', 'D211B']
# Mutation Count: 2
# Dm1m2-min(dm1,dm2): 3.528590202331543
# --------------------------------------------------
# dm1: -5.185905933380127, dm2: -4.992798805236816
# Mutations: ['A11B', 'C31A', 'A101B', 'B111C', 'D119C', 'C232A', 'B256A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 3.5159802436828613
# --------------------------------------------------
# dm1: -5.796274185180664, dm2: -5.0054497718811035
# Mutations: ['C7D', 'D17A', 'A101B', 'C156A', 'D211B', 'B256A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 3.5033397674560547
# --------------------------------------------------
# dm1: -5.545683860778809, dm2: -5.008012771606445
# Mutations: ['D17A', 'C31A', 'A101B', 'C124B', 'D125A', 'A198B', 'B201A', 'B206A', 'C232A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 3.50076961517334
# --------------------------------------------------
# dm1: -5.741486549377441, dm2: -5.068870544433594
# Mutations: ['A11B', 'D24C', 'A101B', 'D136A', 'B206A', 'C208A', 'D218C', 'D230A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 3.439913749694824
# --------------------------------------------------
# dm1: -7.05269718170166, dm2: -5.131762981414795
# Mutations: ['B6C', 'A11B', 'D17A', 'C31A', 'B63A', 'A74C', 'A96B', 'A101B', 'D112C', 'C124D', 'D125A', 'A134B', 'D136A', 'B157A', 'D160C', 'B201A', 'B206A', 'D211C', 'C234D']
# Mutation Count: 19
# Dm1m2-min(dm1,dm2): 3.3770265579223633
# --------------------------------------------------
# dm1: -7.05269718170166, dm2: -5.131762981414795
# Mutations: ['B6C', 'A11B', 'D17A', 'C31A', 'B63A', 'A74C', 'A96B', 'A101B', 'D112C', 'C124D', 'D125A', 'A134B', 'D136A', 'B157A', 'D160C', 'B201A', 'B206A', 'D211C', 'C234D']
# Mutation Count: 19
# Dm1m2-min(dm1,dm2): 3.3770265579223633
# --------------------------------------------------
# dm1: -4.570201873779297, dm2: 0.007540702819824219
# Mutations: ['A101B', 'D148C', 'C156A', 'C208A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 3.3121299743652344
# --------------------------------------------------
# dm1: -2.2086434364318848, dm2: 0.0019884109497070312
# Mutations: ['A101B', 'D138A', 'D148C', 'C156A', 'C208A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 3.3065714836120605
# --------------------------------------------------
# dm1: -6.154745101928711, dm2: -5.214681625366211
# Mutations: ['A11B', 'D24C', 'A101B', 'D136A', 'B206A', 'C208A', 'D218C', 'D230A', 'C232A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 3.2941055297851562
# --------------------------------------------------
# dm1: -5.268498420715332, dm2: -5.219578266143799
# Mutations: ['D17A', 'A28B', 'B106A', 'C156A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 3.2892141342163086
# --------------------------------------------------
# dm1: -1.2486882209777832, dm2: -0.027179718017578125
# Mutations: ['C50A', 'A72D', 'A101B', 'D112C', 'C124A', 'B135C', 'D138A', 'D148C', 'A167B', 'B201A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 3.277404308319092
# --------------------------------------------------
# dm1: -3.564995288848877, dm2: -0.09077167510986328
# Mutations: ['A14B', 'A72D', 'C124D', 'D125A', 'D148C', 'B201A', 'C232A', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 3.213806629180908
# --------------------------------------------------
# dm1: -1.7300128936767578, dm2: 3.1848907470703125
# Mutations: ['D17A', 'C124A', 'D125A', 'D138B', 'D148B', 'A163D', 'D211C']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 3.184885025024414
# --------------------------------------------------
# dm1: -5.419781684875488, dm2: -5.338059902191162
# Mutations: ['D17A', 'C31A', 'A101B', 'A103B', 'C124B', 'D125A', 'A198B', 'B201A', 'B206A', 'C232A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 3.1707239151000977
# --------------------------------------------------
# dm1: -5.378691673278809, dm2: -5.368936061859131
# Mutations: ['C10B', 'C50A', 'A101B', 'D112B', 'B157A', 'D160B', 'D230A', 'C234D', 'D253A', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 3.1398496627807617
# --------------------------------------------------
# dm1: -5.378691673278809, dm2: -5.368936061859131
# Mutations: ['C10B', 'C50A', 'A101B', 'D112B', 'B157A', 'D160B', 'D230A', 'C234D', 'D253A', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 3.1398496627807617
# --------------------------------------------------
# dm1: -5.48394775390625, dm2: -5.394426345825195
# Mutations: ['A11B', 'D24C', 'A101B', 'B135C', 'D136A', 'B206A', 'C208A', 'D218C', 'D230A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 3.1143646240234375
# --------------------------------------------------
# dm1: -4.047369956970215, dm2: -0.2360086441040039
# Mutations: ['C10B', 'A72D', 'A101B', 'D148C', 'C156A', 'C234D']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 3.0685834884643555
# --------------------------------------------------
# dm1: -5.938828468322754, dm2: -5.574437618255615
# Mutations: ['A101B', 'C124A', 'C156A', 'B201A', 'B217A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 2.9343557357788086
# --------------------------------------------------
# dm1: -5.938828468322754, dm2: -5.574437618255615
# Mutations: ['A101B', 'C124A', 'C156A', 'B201A', 'B217A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 2.9343557357788086
# --------------------------------------------------
# dm1: -5.938828468322754, dm2: -5.574437618255615
# Mutations: ['A101B', 'C124A', 'C156A', 'B201A', 'B217A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 2.9343557357788086
# --------------------------------------------------
# dm1: -5.6421003341674805, dm2: -5.630300521850586
# Mutations: ['A101B', 'D112B', 'B157A', 'D160B', 'D230A', 'C234D']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 2.878488540649414
# --------------------------------------------------
# dm1: -5.6421003341674805, dm2: -5.630300521850586
# Mutations: ['A101B', 'D112B', 'B157A', 'D160B', 'D230A', 'C234D']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 2.878488540649414
# --------------------------------------------------
# dm1: -5.856932163238525, dm2: -5.65791130065918
# Mutations: ['D17A', 'C50A', 'A72D', 'A101B', 'C124A', 'A155C', 'A163B', 'B206A', 'D218C', 'B227A', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 2.8508763313293457
# --------------------------------------------------
# dm1: -6.3541364669799805, dm2: -5.682710647583008
# Mutations: ['A11B', 'A32B', 'A37B', 'A41C', 'B60C', 'A97B', 'A101B', 'B106A', 'B111C', 'D119B', 'C122B', 'B201A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 2.826080322265625
# --------------------------------------------------
# dm1: -6.776785373687744, dm2: -5.693045616149902
# Mutations: ['C7D', 'D17A', 'C31A', 'A74C', 'A100C', 'A101B', 'B111C', 'D119B', 'D125A', 'B206A', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 2.8157525062561035
# --------------------------------------------------
# dm1: -7.0772600173950195, dm2: -5.701521396636963
# Mutations: ['A14B', 'D24C', 'A74C', 'D112B', 'C124D', 'D125A', 'A134B', 'D136A', 'B201A', 'B206A', 'C234D', 'D255C', 'B256A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 2.807265281677246
# --------------------------------------------------
# dm1: -3.8328142166137695, dm2: -0.5030765533447266
# Mutations: ['A72D', 'D148C', 'A181B', 'B201A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 2.801516532897949
# --------------------------------------------------
# dm1: -6.106990814208984, dm2: -5.7387518882751465
# Mutations: ['A101B', 'C124A', 'C156A', 'C164A', 'B201A', 'B217A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 2.770038604736328
# --------------------------------------------------
# dm1: -2.3880062103271484, dm2: 2.598515033721924
# Mutations: ['A14B', 'B84D', 'D112A', 'D125A', 'D148B', 'A154C', 'D230A', 'C234A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 2.598508834838867
# --------------------------------------------------
# dm1: -6.522168159484863, dm2: -5.930639743804932
# Mutations: ['A11B', 'D24C', 'C31A', 'A74B', 'A101B', 'D112A', 'C113A', 'C124A', 'D143C', 'B206A', 'C208B']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 2.57814884185791
# --------------------------------------------------
# dm1: -6.342606544494629, dm2: -6.020188808441162
# Mutations: ['C31A', 'B79A', 'A101B', 'D211B', 'B217A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 2.488605499267578
# --------------------------------------------------
# dm1: -6.188405990600586, dm2: -6.108770847320557
# Mutations: ['C31A', 'A101B', 'A151B', 'A198B', 'B201A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 2.4000205993652344
# --------------------------------------------------
# dm1: -8.243958473205566, dm2: -6.184665679931641
# Mutations: ['A72D', 'A101B', 'D119C', 'D136B', 'A155C', 'A188B', 'A198B', 'B201A', 'B217A', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 2.3241395950317383
# --------------------------------------------------
# dm1: -2.887948989868164, dm2: 2.2966747283935547
# Mutations: ['C31A', 'A72D', 'C124D', 'D126C', 'B135C', 'D148B']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 2.2966690063476562
# --------------------------------------------------
# dm1: -6.419956207275391, dm2: -6.229805946350098
# Mutations: ['A11B', 'A14B', 'D24C', 'B63A', 'A74C', 'A92C', 'A97B', 'A101B', 'D112B', 'D125A', 'A151B', 'A163C', 'B201A', 'C208B', 'C234A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): 2.2789764404296875
# --------------------------------------------------
# dm1: -6.9057207107543945, dm2: -6.282183647155762
# Mutations: ['D17A', 'B45A', 'C50A', 'A101B', 'D112B', 'C124A', 'D125A', 'D143C', 'C156A', 'B201A', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 2.2266130447387695
# --------------------------------------------------
# dm1: -6.436013698577881, dm2: -6.35678243637085
# Mutations: ['C31A', 'C50A', 'D143A', 'A163B', 'B206A', 'D218C', 'C220A', 'D230C']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 2.1520028114318848
# --------------------------------------------------
# dm1: -6.7771148681640625, dm2: -6.39094877243042
# Mutations: ['D17A', 'C31A', 'A101B', 'D112B', 'D119C', 'C122B', 'C124D', 'D143C', 'B206A', 'D218C', 'B227A', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 2.117842674255371
# --------------------------------------------------
# dm1: -6.7771148681640625, dm2: -6.39094877243042
# Mutations: ['D17A', 'C31A', 'A101B', 'D112B', 'D119C', 'C122B', 'C124D', 'D143C', 'B206A', 'D218C', 'B227A', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 2.117842674255371
# --------------------------------------------------
# dm1: -3.7019271850585938, dm2: -1.191227912902832
# Mutations: ['A11B', 'B21C', 'B25A', 'D119A', 'C122B', 'D125A', 'D148C', 'B201A', 'A203B', 'D218C', 'C234D', 'D253A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 2.1133546829223633
# --------------------------------------------------
# dm1: -2.3762598037719727, dm2: -1.3710055351257324
# Mutations: ['B111D', 'C124A', 'D125A', 'D126A', 'D138A', 'D148C', 'D211C', 'D230A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 1.9335746765136719
# --------------------------------------------------
# dm1: -6.891978740692139, dm2: -6.575749397277832
# Mutations: ['A11B', 'C31A', 'A37B', 'C113D', 'D119C', 'C122B', 'C124D', 'A155C', 'A196B', 'B201A', 'B254D', 'D255B']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 1.9330334663391113
# --------------------------------------------------
# dm1: -6.81554651260376, dm2: -6.600202560424805
# Mutations: ['A13B', 'A14B', 'B20A', 'A101B', 'D119C', 'C122B', 'C124A', 'A155C', 'A193C', 'B201A', 'B206A', 'B217A', 'D218C', 'D230A', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): 1.908583164215088
# --------------------------------------------------
# dm1: -7.288265705108643, dm2: -6.608691215515137
# Mutations: ['D17A', 'A101B', 'D112B', 'A155C', 'C165A', 'A171D', 'B206A', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 1.9001059532165527
# --------------------------------------------------
# dm1: -6.6558709144592285, dm2: -6.62837028503418
# Mutations: ['D17A', 'C31A', 'A72D', 'C124A', 'D143C', 'C156A', 'B206A', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 1.880415439605713
# --------------------------------------------------
# dm1: -1.5740928649902344, dm2: -1.4546236991882324
# Mutations: ['A11B', 'A93C', 'A101B', 'D138A', 'D148A', 'B189A', 'B201A', 'D211B', 'D216A', 'D218C', 'A222C', 'D230A', 'C234D']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 1.8706274032592773
# --------------------------------------------------
# dm1: -7.533339977264404, dm2: -6.672881126403809
# Mutations: ['D143C', 'B205A', 'C208A', 'D211B', 'C212B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 1.8359169960021973
# --------------------------------------------------
# dm1: -3.7685251235961914, dm2: -1.4733834266662598
# Mutations: ['C10B', 'A101B', 'D119C', 'C122B', 'C124D', 'D125C', 'D148C', 'D218C']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 1.8311996459960938
# --------------------------------------------------
# dm1: -7.183210849761963, dm2: -6.689525127410889
# Mutations: ['A11B', 'B23D', 'A28B', 'A37B', 'A101B', 'A155C', 'B201A', 'B206A', 'C215B', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 1.8192620277404785
# --------------------------------------------------
# dm1: -7.549708366394043, dm2: -6.743805885314941
# Mutations: ['A30B', 'A101B', 'D112A', 'A155C', 'A196B', 'C212B', 'D216A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 1.7649869918823242
# --------------------------------------------------
# dm1: -3.1475377082824707, dm2: -1.5843539237976074
# Mutations: ['A11B', 'A14B', 'B23D', 'C31A', 'D119A', 'C122B', 'D125A', 'D148C', 'B157A', 'D160B', 'B201A', 'D211C', 'C215B', 'C221D', 'A222C', 'B256A']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): 1.7202229499816895
# --------------------------------------------------
# dm1: -7.63547420501709, dm2: -6.791454315185547
# Mutations: ['C31A', 'C50A', 'B60C', 'A74B', 'A92C', 'C99A', 'B106A', 'D112C', 'C124A', 'A167B', 'B206A', 'D230A', 'B256A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 1.7173452377319336
# --------------------------------------------------
# dm1: -4.022712707519531, dm2: -1.6148486137390137
# Mutations: ['A14B', 'D17A', 'B34A', 'C50D', 'A72D', 'C124A', 'D148C', 'B201A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 1.6897382736206055
# --------------------------------------------------
# dm1: -7.9744672775268555, dm2: -6.832003116607666
# Mutations: ['A14B', 'A74C', 'A97B', 'A101B', 'D143A', 'A167B', 'C208A', 'D211B', 'D230C']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 1.676797866821289
# --------------------------------------------------
# dm1: -7.405843257904053, dm2: -6.973930358886719
# Mutations: ['D17A', 'C31A', 'A97B', 'A101B', 'D112B', 'D119C', 'C122B', 'C124D', 'D143C', 'B206A', 'D218C', 'B227A', 'B256A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 1.5348668098449707
# --------------------------------------------------
# dm1: -2.873225212097168, dm2: 1.534672737121582
# Mutations: ['B23D', 'C31A', 'A101B', 'D119A', 'C122B', 'D125A', 'D148B', 'C215B', 'C221D', 'A222C']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 1.5346708297729492
# --------------------------------------------------
# dm1: -7.125532627105713, dm2: -6.984862804412842
# Mutations: ['A14B', 'C31A', 'A155C', 'C215B', 'D230A', 'B231A', 'D253A', 'B254C', 'D255B', 'B256A', 'C258A', 'C259B', 'B260A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 1.5239157676696777
# --------------------------------------------------
# dm1: -7.090249061584473, dm2: -6.991204738616943
# Mutations: ['D17A', 'B84A', 'A92C', 'C124B', 'C156A', 'A203B', 'B256A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 1.5175848007202148
# --------------------------------------------------
# dm1: -7.128706932067871, dm2: -7.00505256652832
# Mutations: ['A11B', 'C31A', 'A101B', 'C124A', 'A155C', 'C156A', 'A193D', 'B201A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 1.5037431716918945
# --------------------------------------------------
# dm1: -8.885164260864258, dm2: -7.03157377243042
# Mutations: ['A11B', 'D24C', 'C50A', 'C68A', 'A74C', 'D112B', 'C113D', 'D119C', 'C122B', 'C124D', 'A151B', 'A155C', 'B157A', 'D160B', 'B201A', 'B206A', 'C208A', 'C212B']
# Mutation Count: 18
# Dm1m2-min(dm1,dm2): 1.4772310256958008
# --------------------------------------------------
# dm1: -7.162552356719971, dm2: -7.052547454833984
# Mutations: ['D17A', 'A96C', 'A101B', 'D119C', 'C122B', 'C124A', 'A155C', 'C156A', 'B201A', 'B206A', 'C208A', 'B227A', 'D253B', 'B256A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 1.4562458992004395
# --------------------------------------------------
# dm1: -7.227304935455322, dm2: -7.10757303237915
# Mutations: ['A11B', 'A28B', 'C31A', 'A32B', 'A37B', 'A155C', 'B201A', 'D211C']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 1.4012160301208496
# --------------------------------------------------
# dm1: -7.397032737731934, dm2: -7.127337455749512
# Mutations: ['A11B', 'D24C', 'C31A', 'D95C', 'A101B', 'D112A', 'A155C', 'A167B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 1.3814582824707031
# --------------------------------------------------
# dm1: -7.334409713745117, dm2: -7.218847751617432
# Mutations: ['D17A', 'A101B', 'D112B', 'C124A', 'D125B', 'A155C', 'B157A', 'D160B', 'A163C', 'D211C', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 1.2899456024169922
# --------------------------------------------------
# dm1: -8.23830509185791, dm2: -7.2944231033325195
# Mutations: ['C7D', 'A11B', 'C31A', 'C50A', 'A74B', 'C113D', 'D119C', 'C122B', 'A151B', 'A155C', 'C208A', 'D211B', 'C212B', 'D216C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 1.2143669128417969
# --------------------------------------------------
# dm1: -8.383708000183105, dm2: -7.29550313949585
# Mutations: ['D17A', 'B21A', 'B25A', 'B45A', 'A101B', 'B106A', 'B111D', 'D112B', 'C124A', 'A151B', 'A155C', 'B157A', 'D160B', 'A163C', 'C208A', 'B256A']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): 1.213292121887207
# --------------------------------------------------
# dm1: -7.324307441711426, dm2: -7.302330493927002
# Mutations: ['C50A', 'A101B', 'B111C', 'D119B', 'A151B', 'A155C', 'B227A', 'D253C', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 1.206465721130371
# --------------------------------------------------
# dm1: -7.513213157653809, dm2: -7.418384075164795
# Mutations: ['D17A', 'B20A', 'C31A', 'A74B', 'A97B', 'D112B', 'C113D', 'C124B', 'D125A', 'D143C', 'B157A', 'D160B', 'B201A', 'D211C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 1.0904150009155273
# --------------------------------------------------
# dm1: -8.086369514465332, dm2: -7.439286708831787
# Mutations: ['D17A', 'A72C', 'A74B', 'A101B', 'D112B', 'D119C', 'D143C', 'B201A', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 1.0695152282714844
# --------------------------------------------------
# dm1: -7.839544296264648, dm2: -7.513158321380615
# Mutations: ['C7A', 'C10A', 'A11B', 'A14B', 'C31A', 'B45D', 'A97B', 'A101B', 'D125A', 'D143C', 'A163C', 'A193D', 'B201A', 'C208B', 'C212B', 'D216A', 'C219B', 'D230A', 'B256A']
# Mutation Count: 19
# Dm1m2-min(dm1,dm2): 0.9956378936767578
# --------------------------------------------------
# dm1: 1.2796087265014648, dm2: 1.416407823562622
# Mutations: ['D17A', 'B27C', 'C31A', 'A35B', 'D39B', 'A41C', 'C50A', 'A101B', 'C140A', 'D148A', 'A163B', 'A193C', 'B201A', 'D218C', 'C220B', 'B227A', 'C234A']
# Mutation Count: 17
# Dm1m2-min(dm1,dm2): 0.9868631362915039
# --------------------------------------------------
# dm1: -7.909564018249512, dm2: -7.544458389282227
# Mutations: ['A3B', 'D17A', 'D39A', 'C50A', 'A72D', 'A151B', 'A155C', 'C156A', 'B157A', 'B173A', 'C232D']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 0.9643516540527344
# --------------------------------------------------
# dm1: -8.0728759765625, dm2: -7.549651622772217
# Mutations: ['C31A', 'A74C', 'A97B', 'D112B', 'C124A', 'D125A', 'D126C', 'D143C', 'B157A', 'D160B', 'A181B', 'B206A', 'B254C']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 0.9591484069824219
# --------------------------------------------------
# dm1: -9.798385620117188, dm2: -7.624763011932373
# Mutations: ['B45A', 'C50D', 'C69B', 'A72D', 'A74C', 'B84A', 'A101B', 'D112B', 'D125A', 'A151B', 'A155C', 'B157A', 'D160B', 'A163C', 'B201A', 'C212B', 'C215B', 'B256A']
# Mutation Count: 18
# Dm1m2-min(dm1,dm2): 0.8840436935424805
# --------------------------------------------------
# dm1: -7.653473377227783, dm2: -7.6372222900390625
# Mutations: ['B6C', 'C10B', 'C31A', 'D39B', 'A72D', 'A101B', 'B106A', 'D119C', 'A151B', 'A155C', 'B205A', 'C208B', 'D253A', 'D255C', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): 0.8715777397155762
# --------------------------------------------------
# dm1: -7.960160255432129, dm2: -7.641041278839111
# Mutations: ['D17A', 'A96B', 'A101B', 'D112B', 'D119B', 'A155C', 'C156A', 'D211C', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 0.8677616119384766
# --------------------------------------------------
# dm1: -7.960160255432129, dm2: -7.641041278839111
# Mutations: ['D17A', 'A96B', 'A101B', 'D112B', 'D119B', 'A155C', 'C156A', 'D211C', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 0.8677616119384766
# --------------------------------------------------
# dm1: -7.98671817779541, dm2: -7.6445393562316895
# Mutations: ['B16C', 'A28B', 'D112B', 'D119C', 'A155C', 'C156A', 'B201A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 0.8642673492431641
# --------------------------------------------------
# dm1: -7.7012224197387695, dm2: -7.654879093170166
# Mutations: ['C10B', 'A101B', 'B106A', 'A155C', 'C156A', 'C165A', 'C195B', 'B201A', 'C220D']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 0.8539218902587891
# --------------------------------------------------
# dm1: -4.221808910369873, dm2: -2.5538277626037598
# Mutations: ['D17A', 'A72D', 'B90C', 'A101B', 'A128C', 'D138A', 'D148C', 'C156A', 'B201A', 'C220D']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 0.750760555267334
# --------------------------------------------------
# dm1: -7.9694719314575195, dm2: -7.827441215515137
# Mutations: ['A14B', 'B20A', 'A32B', 'B45A', 'A101C', 'D136B', 'D138C', 'A151B', 'A155C', 'A163B', 'B201A', 'B206A', 'C220D']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 0.6813554763793945
# --------------------------------------------------
# dm1: -8.273347854614258, dm2: -7.909663200378418
# Mutations: ['D17A', 'A54B', 'A74C', 'A97B', 'A101B', 'D112A', 'D119B', 'C124A', 'D143A', 'B187A', 'A188B', 'D211C', 'D230C', 'B256A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 0.5991334915161133
# --------------------------------------------------
# dm1: -8.048493385314941, dm2: -7.914753437042236
# Mutations: ['A11B', 'D24C', 'A101B', 'D119C', 'A151B', 'A155C', 'B206A', 'B207A', 'C212B']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 0.5940475463867188
# --------------------------------------------------
# dm1: -8.462699890136719, dm2: -7.920778274536133
# Mutations: ['B6D', 'C7B', 'C10B', 'C31A', 'A72D', 'B84C', 'B91A', 'A101B', 'D112B', 'A151B', 'A155C', 'B201A', 'B206A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 0.5880222320556641
# --------------------------------------------------
# dm1: -8.229104042053223, dm2: -8.000999450683594
# Mutations: ['C7D', 'D17A', 'A28B', 'A30B', 'C50A', 'A72D', 'A101B', 'D112A', 'C124A', 'D125A', 'D136A', 'A151B', 'A155C', 'C156A', 'B201A', 'D218C', 'C234A', 'B256A']
# Mutation Count: 18
# Dm1m2-min(dm1,dm2): 0.5078029632568359
# --------------------------------------------------
# dm1: -8.522350311279297, dm2: -8.028604507446289
# Mutations: ['C31A', 'B60C', 'A74C', 'A97B', 'D112B', 'C124A', 'D125A', 'D126C', 'D143C', 'B157A', 'D160B', 'A181B', 'B206A', 'B254C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 0.480194091796875
# --------------------------------------------------
# dm1: -8.040247917175293, dm2: -8.031303405761719
# Mutations: ['D17A', 'B84A', 'A101B', 'B111C', 'C124A', 'D125A', 'A155C', 'B157A', 'D160A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 0.4774951934814453
# --------------------------------------------------
# dm1: -8.741189002990723, dm2: -8.24290657043457
# Mutations: ['D17A', 'A74B', 'A97B', 'D119B', 'D143C', 'B157A', 'D160B', 'B201A', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 0.2658987045288086
# --------------------------------------------------
# dm1: -8.391923904418945, dm2: -8.272007942199707
# Mutations: ['D17A', 'C31A', 'B80A', 'A97B', 'A101B', 'D119B', 'C124A', 'D125A', 'D143A', 'B206A', 'D230C', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 0.23679351806640625
# --------------------------------------------------
# dm1: -3.6034793853759766, dm2: 0.21628665924072266
# Mutations: ['A11B', 'D17C', 'A101B', 'D119C', 'C124D', 'B135C', 'D148B', 'A181B', 'B201A', 'C220B']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 0.21627235412597656
# --------------------------------------------------
# dm1: -10.259430885314941, dm2: -8.34112548828125
# Mutations: ['B6C', 'A11B', 'D24C', 'C31A', 'B42A', 'C50A', 'A73B', 'A74C', 'B84A', 'D95C', 'A101B', 'C113A', 'C124B', 'A151B', 'A155C', 'B157A', 'D160B', 'A163C', 'B201A', 'B206A', 'D211C', 'B240C']
# Mutation Count: 22
# Dm1m2-min(dm1,dm2): 0.1676807403564453
# --------------------------------------------------
# dm1: -8.971052169799805, dm2: -8.385730743408203
# Mutations: ['D17A', 'A97B', 'A101B', 'B111D', 'D112B', 'D119B', 'C124B', 'D125A', 'A155C', 'C165A', 'A198B', 'B201A', 'C220B', 'B227A', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): 0.12306976318359375
# --------------------------------------------------
# dm1: -9.110350608825684, dm2: -8.425379753112793
# Mutations: ['D17A', 'C31A', 'A72D', 'A74C', 'A101B', 'C113D', 'C124B', 'D125A', 'A151B', 'A155C', 'C156A', 'A171B', 'A181B', 'B201A', 'B206A', 'C221A']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): 0.08342552185058594
# --------------------------------------------------
# dm1: -0.2708745002746582, dm2: 0.5107488632202148
# Mutations: ['C31A', 'A41C', 'A101B', 'C140A', 'D148C', 'B201A', 'B206A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 0.06054544448852539
# --------------------------------------------------
# dm1: -5.939128875732422, dm2: -3.3114681243896484
# Mutations: ['A11B', 'B21C', 'B25A', 'D119A', 'C122B', 'D125A', 'D148C', 'A155C', 'B201A', 'A203B', 'D218C', 'C234D', 'D253A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -0.0068798065185546875
# --------------------------------------------------
# dm1: -8.664413452148438, dm2: -8.535841941833496
# Mutations: ['A11B', 'A14B', 'C31A', 'B84A', 'A97C', 'C113D', 'D119B', 'A151B', 'A155C', 'B157A', 'B201A', 'B206A', 'C208B', 'D218C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -0.02703857421875
# --------------------------------------------------
# dm1: -9.198379516601562, dm2: -8.590811729431152
# Mutations: ['C7D', 'D17A', 'A74B', 'A97B', 'A101B', 'B111A', 'D112B', 'D119B', 'D143A', 'B206A', 'D211C', 'D230C', 'B256A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -0.08201122283935547
# --------------------------------------------------
# dm1: -9.554149627685547, dm2: -8.615127563476562
# Mutations: ['C31A', 'A101B', 'D112B', 'C113D', 'A151B', 'A155C', 'C156A', 'B157A', 'B201A', 'D218C', 'D229C', 'D253A', 'B256A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -0.10632038116455078
# --------------------------------------------------
# dm1: -8.829741477966309, dm2: -8.65516471862793
# Mutations: ['A11B', 'D24C', 'C31A', 'A74B', 'A101B', 'D112A', 'D143C', 'B201A', 'D218A', 'C219B', 'C234D']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -0.14635848999023438
# --------------------------------------------------
# dm1: -8.959920883178711, dm2: -8.722884178161621
# Mutations: ['A11B', 'B25A', 'A28B', 'A37B', 'D39A', 'C50B', 'A74C', 'C124A', 'D138C', 'A151B', 'A155C', 'B157A', 'D160A', 'A203B', 'C208B', 'C232D', 'C234D', 'D253A', 'B254A']
# Mutation Count: 19
# Dm1m2-min(dm1,dm2): -0.2140798568725586
# --------------------------------------------------
# dm1: -9.438411712646484, dm2: -8.787951469421387
# Mutations: ['B6C', 'D17A', 'C50A', 'A72D', 'A74B', 'A97B', 'D119B', 'A151B', 'A155C', 'C156A', 'C208B', 'C212B']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -0.2791471481323242
# --------------------------------------------------
# dm1: -1.0241765975952148, dm2: -0.7334551811218262
# Mutations: ['A14B', 'D17A', 'B34A', 'C59A', 'D119C', 'C124D', 'D125A', 'C140B', 'D148C', 'B201A', 'D230A', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -0.28332042694091797
# --------------------------------------------------
# dm1: -0.8444404602050781, dm2: 0.05099201202392578
# Mutations: ['A11B', 'D24C', 'B25A', 'C50A', 'B111C', 'C140A', 'D148C', 'A203B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -0.3992137908935547
# --------------------------------------------------
# dm1: -0.8230552673339844, dm2: -0.027882099151611328
# Mutations: ['A11B', 'B111C', 'C124D', 'C140A', 'D148C', 'A167B']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): -0.4780845642089844
# --------------------------------------------------
# dm1: -9.47636604309082, dm2: -9.029587745666504
# Mutations: ['C7D', 'D17A', 'A101B', 'D119C', 'C122B', 'D143A', 'A155C', 'C156A', 'C165A', 'B201A', 'B206A', 'D218C', 'C219A', 'D230C', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -0.5207815170288086
# --------------------------------------------------
# dm1: -0.6105623245239258, dm2: -0.3231639862060547
# Mutations: ['A14B', 'D24B', 'B25A', 'B45A', 'C113D', 'C124D', 'D125A', 'C140A', 'D148C', 'B157A', 'D160C', 'C220B', 'B227A', 'C234A', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -0.7733688354492188
# --------------------------------------------------
# dm1: -0.6105623245239258, dm2: -0.3231639862060547
# Mutations: ['A14B', 'D24B', 'B25A', 'B45A', 'C113D', 'C124D', 'D125A', 'C140A', 'D148C', 'B157A', 'D160C', 'C220B', 'B227A', 'C234A', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -0.7733688354492188
# --------------------------------------------------
# dm1: -9.927176475524902, dm2: -9.305091857910156
# Mutations: ['D17A', 'C31A', 'C50A', 'D95C', 'A101B', 'D112A', 'D119B', 'A151B', 'A155C', 'C156A', 'B157A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -0.7962875366210938
# --------------------------------------------------
# dm1: -9.400376319885254, dm2: -9.38022518157959
# Mutations: ['C7D', 'D17A', 'A101B', 'D119C', 'C122B', 'D143A', 'A155C', 'C156A', 'C165A', 'B201A', 'B206A', 'D218C', 'C219A', 'D230C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -0.8714227676391602
# --------------------------------------------------
# dm1: -0.829096794128418, dm2: -0.48708534240722656
# Mutations: ['B6C', 'C10B', 'A11B', 'C31A', 'C140A', 'D148C', 'B201A', 'B206A', 'C234D']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -0.937291145324707
# --------------------------------------------------
# dm1: -9.748791694641113, dm2: -9.732709884643555
# Mutations: ['B20A', 'C50A', 'A92C', 'C124A', 'A155C', 'B157A', 'D160A', 'A193C', 'B201A', 'D218C', 'C220D', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -1.2239093780517578
# --------------------------------------------------
# dm1: 2.473680019378662, dm2: 2.933206081390381
# Mutations: ['D17A', 'A74C', 'B84A', 'D112B', 'C140D', 'D148C', 'B157A', 'D160B', 'B201A', 'B205A', 'B256A', 'C259A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -2.271005153656006
# --------------------------------------------------
# dm1: 5.200390815734863, dm2: 5.558464050292969
# Mutations: ['D17A', 'A32B', 'A74C', 'C124A', 'D125B', 'D136B', 'C140D', 'D148B', 'C165A', 'B201A', 'C234A', 'B256A', 'C259A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -2.9503355026245117
# --------------------------------------------------
# dm1: 4.223781108856201, dm2: 5.339542865753174
# Mutations: ['B63A', 'A73B', 'A74C', 'A96B', 'A101B', 'D112B', 'C140D', 'D148B', 'C208A', 'C232A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -3.169246196746826
# --------------------------------------------------
# dm1: 4.223781108856201, dm2: 5.339542865753174
# Mutations: ['B63A', 'A73B', 'A74C', 'A96B', 'A101B', 'D112B', 'C140D', 'D148B', 'C208A', 'C232A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -3.169246196746826
# --------------------------------------------------
# dm1: 5.244509220123291, dm2: 5.296130180358887
# Mutations: ['D24C', 'A41C', 'A74C', 'B91C', 'A101B', 'D125A', 'C140D', 'D148B', 'B201A', 'D216A', 'B254D']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -3.212667942047119
# --------------------------------------------------
# dm1: 3.636141777038574, dm2: 4.84396505355835
# Mutations: ['D17A', 'C50A', 'A101B', 'B111C', 'C124A', 'D125A', 'C140D', 'D148B', 'C156A', 'A167B', 'A193D', 'B201A', 'B206A', 'D216C', 'D230A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -3.66483211517334
# --------------------------------------------------
# dm1: 2.5531253814697266, dm2: 4.2477617263793945
# Mutations: ['A11B', 'A28B', 'A37B', 'A101B', 'D112B', 'C140D', 'D148B', 'B206A', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -4.261039733886719
# --------------------------------------------------
# dm1: 3.7554383277893066, dm2: 4.196710586547852
# Mutations: ['D17A', 'C31A', 'C50A', 'A101B', 'D112B', 'C140D', 'D148B', 'B254C']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.312092304229736
# --------------------------------------------------
# dm1: 3.5335474014282227, dm2: 4.137648582458496
# Mutations: ['C31A', 'A101B', 'C140D', 'D148B', 'C156A', 'B173A', 'A203B', 'B206A', 'B207A', 'C208A', 'B227A', 'D253B']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -4.371150016784668
# --------------------------------------------------
# dm1: 3.63800048828125, dm2: 4.067683696746826
# Mutations: ['A11B', 'D24C', 'C31A', 'D112B', 'C140D', 'D148B', 'B206A', 'C208A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.4411163330078125
# --------------------------------------------------
# dm1: 2.483302593231201, dm2: 3.6454477310180664
# Mutations: ['D17A', 'C31A', 'A101B', 'D112B', 'C124D', 'C140D', 'D148B', 'A163C', 'B201A', 'D211B', 'C220D', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -4.8633551597595215
# --------------------------------------------------
# dm1: 3.5521445274353027, dm2: 3.6061511039733887
# Mutations: ['D17A', 'D24C', 'A101B', 'D112B', 'C124D', 'D125A', 'C140D', 'D148B', 'B206A', 'D230A', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -4.902657985687256
# --------------------------------------------------

# %% [markdown]
# ## 3.4 compensate on 1220

# %%
# Define the mutations as input parameters
mutation1 = 'D148B'
mutation2 = 'C140D'

# Extract position and amino acid information from the mutations
pos1, old_aa1, new_aa1 = int(mutation1[1:-1]), mutation1[0], mutation1[-1]
pos2, old_aa2, new_aa2 = int(mutation2[1:-1]), mutation2[0], mutation2[-1]

# List to store sequences with sign change
sequences_with_sign_change = []

# Calculate delta E for the consensus sequence
de_mutation1_consensus = calculate_delta_e(pos1, old_aa1, new_aa1, consensus_sequence, J_dict)
de_mutation2_consensus = calculate_delta_e(pos2, old_aa2, new_aa2, consensus_sequence, J_dict)

print("-" * 50)
print(f'Consensus delta E for {mutation1}: {de_mutation1_consensus}, {mutation2}: {de_mutation2_consensus}')
print('Consensus dm12:', calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, consensus_sequence, J_dict))
print("-" * 50)

# Iterate through all sequences
for index, row in sequence_df.iterrows():
    sequence = row['Sequence']
    mutations = row['Mutations']
    mutation_count = row['Mutations_count']
    
    # Skip sequences without the specified mutations
    if mutation1 not in mutations or mutation2 not in mutations:
        # continue
        pass
    
    # Calculate delta E for the specified mutations
    de_mutation1 = calculate_delta_e(pos1, old_aa1, new_aa1, sequence, J_dict)
    de_mutation2 = calculate_delta_e(pos2, old_aa2, new_aa2, sequence, J_dict)
    dm12 = calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, sequence, J_dict)

    # Check for sign change
    if dm12 > de_mutation1 or dm12 > de_mutation2:
        min_dm1_dm2 = min(de_mutation1, de_mutation2)
        max_dm1_dm2 = max(de_mutation1, de_mutation2)
        max_divide_min_dm1_dm2 = max_dm1_dm2 / min_dm1_dm2
        
        sequences_with_sign_change.append({
            'Sequence': sequence,
            'Mutations': mutations,
            'Mutation_count': mutation_count,
            'dm1': de_mutation1,
            'dm2': de_mutation2,
            'dm12': dm12,
            'Dm1m2-max/min(dm1,dm2)': dm12 - max_divide_min_dm1_dm2,
            'Dm1m2-min(dm1,dm2)': dm12 - min_dm1_dm2
        })

# Create a DataFrame to store the results
sign_change_df = pd.DataFrame(sequences_with_sign_change)

# Sort the DataFrame by 'Dm1m2-min(dm1,dm2)' in descending order
sign_change_df = sign_change_df.sort_values(by='Dm1m2-min(dm1,dm2)', ascending=False)

# Print the results
for _, row in sign_change_df.iterrows():
    print(f"dm1: {row['dm1']}, dm2: {row['dm2']}")
    print(f"dm12: {row['dm12']}")
    print(f"Mutations: {row['Mutations']}")
    print(f"Mutation Count: {row['Mutation_count']}")
    print(f"Dm1m2-min(dm1,dm2): {row['Dm1m2-min(dm1,dm2)']}")
    print("-" * 50)
# Out:
# --------------------------------------------------
# Consensus delta E for D148B: -4.553504943847656, C140D: -5.7286787033081055
# Consensus dm12: -1.7733955
# --------------------------------------------------
# dm1: -1.6636333465576172, dm2: -4.737617015838623
# dm12: 2.107529640197754
# Mutations: ['C31A', 'B45D', 'A56B', 'A72D', 'D125B', 'D138A', 'A167B', 'A188B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 6.845146656036377
# --------------------------------------------------
# dm1: -2.2102975845336914, dm2: -5.9278435707092285
# dm12: 0.37064361572265625
# Mutations: ['A11B', 'C31A', 'A101B', 'C124D', 'D138B', 'C195D', 'A203B', 'C215B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 6.298487186431885
# --------------------------------------------------
# dm1: -2.2102975845336914, dm2: -5.9278435707092285
# dm12: 0.37064361572265625
# Mutations: ['A11B', 'C31A', 'A101B', 'C124D', 'D138B', 'C195D', 'A203B', 'C215B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 6.298487186431885
# --------------------------------------------------
# dm1: -2.4049692153930664, dm2: -4.845932483673096
# dm12: 1.2578868865966797
# Mutations: ['C10B', 'A41C', 'A101B', 'C122B', 'C124A', 'D125A', 'B201A', 'C208A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 6.103819370269775
# --------------------------------------------------
# dm1: -2.4814958572387695, dm2: -6.862914562225342
# dm12: -0.8356189727783203
# Mutations: ['A14B', 'A28B', 'B91C', 'A101B', 'D119A', 'C122B', 'C124A', 'D125A', 'A203B', 'C215D', 'C221D', 'A222C']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 6.0272955894470215
# --------------------------------------------------
# dm1: -2.6094789505004883, dm2: -5.415468215942383
# dm12: 0.48384666442871094
# Mutations: ['C7D', 'A72D', 'B88A', 'B111A', 'C113D', 'C124A', 'D125A', 'A163C', 'C208A', 'C234D']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 5.899314880371094
# --------------------------------------------------
# dm1: -2.7423229217529297, dm2: -5.725607395172119
# dm12: 0.040863037109375
# Mutations: ['C7D', 'A72D', 'B88A', 'B111A', 'C113D', 'C124A', 'D125A', 'A163C', 'A203B', 'C208A', 'C234D']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 5.766470432281494
# --------------------------------------------------
# dm1: -2.7438864707946777, dm2: -6.489396572113037
# dm12: -0.7244968414306641
# Mutations: ['B23D', 'C31A', 'A101B', 'D119A', 'C122B', 'D125A', 'B201A', 'C215B', 'C221D', 'A222C', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 5.764899730682373
# --------------------------------------------------
# dm1: -2.8994393348693848, dm2: -4.847321510314941
# dm12: 0.7620334625244141
# Mutations: ['D17A', 'A72D', 'C124A', 'A154C', 'C165A', 'B201A', 'B227A', 'C234A', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 5.6093549728393555
# --------------------------------------------------
# dm1: -2.9017343521118164, dm2: -4.813653469085693
# dm12: 0.7934055328369141
# Mutations: ['A14B', 'B20A', 'A72D', 'A101B', 'C113A', 'A193C', 'D230A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 5.607059001922607
# --------------------------------------------------
# dm1: -2.9017438888549805, dm2: -4.034186840057373
# dm12: 1.5728588104248047
# Mutations: ['B6D', 'C7A', 'C10B', 'B20A', 'A72D', 'D119C', 'C122D', 'D125A', 'A203B', 'B206A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 5.607045650482178
# --------------------------------------------------
# dm1: -2.9659605026245117, dm2: -5.242135524749756
# dm12: 0.30069541931152344
# Mutations: ['B20A', 'D39B', 'C50A', 'A101B', 'D119C', 'C122B', 'C124A', 'B201A', 'A222C']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 5.542830944061279
# --------------------------------------------------
# dm1: -3.0428638458251953, dm2: -4.56994104385376
# dm12: 0.8959884643554688
# Mutations: ['B20A', 'A72D', 'A101B', 'C113A', 'A193C', 'D230A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 5.4659295082092285
# --------------------------------------------------
# dm1: -3.0428638458251953, dm2: -4.56994104385376
# dm12: 0.8959884643554688
# Mutations: ['B20A', 'A72D', 'A101B', 'C113A', 'A193C', 'D230A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 5.4659295082092285
# --------------------------------------------------
# dm1: -3.096770763397217, dm2: -4.670529842376709
# dm12: 0.7414875030517578
# Mutations: ['C7A', 'A101B', 'D125B', 'B135C', 'A154B', 'C165A', 'D211C', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 5.412017345428467
# --------------------------------------------------
# dm1: -3.117727279663086, dm2: -6.009549617767334
# dm12: -0.6184787750244141
# Mutations: ['B23D', 'D39A', 'A101B', 'C124D', 'D125A', 'B135C', 'A167B', 'A181B', 'B201A', 'C215B']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 5.39107084274292
# --------------------------------------------------
# dm1: -3.146127700805664, dm2: -4.914676666259766
# dm12: 0.4479827880859375
# Mutations: ['B6C', 'C10B', 'D17A', 'B23D', 'A35B', 'D39B', 'B45D', 'C50A', 'B201A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 5.362659454345703
# --------------------------------------------------
# dm1: -3.14846134185791, dm2: -7.165055751800537
# dm12: -1.804727554321289
# Mutations: ['B6C', 'C31A', 'D39B', 'A72D', 'D119A', 'C122B', 'D125A', 'A176B', 'A203B', 'C215B', 'C221D', 'A222C']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 5.360328197479248
# --------------------------------------------------
# dm1: -3.164823532104492, dm2: -6.444362163543701
# dm12: -1.1003952026367188
# Mutations: ['D125A', 'B135C', 'A154C', 'A162B', 'B201A', 'C215B', 'C234D']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 5.343966960906982
# --------------------------------------------------
# dm1: -3.169173240661621, dm2: -4.4343390464782715
# dm12: 0.9052639007568359
# Mutations: ['C31A', 'C50A', 'C124D', 'D125A', 'D138C', 'A167B', 'B201A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 5.339602947235107
# --------------------------------------------------
# dm1: -3.169173240661621, dm2: -4.4343390464782715
# dm12: 0.9052639007568359
# Mutations: ['C31A', 'C50A', 'C124D', 'D125A', 'D138C', 'A167B', 'B201A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 5.339602947235107
# --------------------------------------------------
# dm1: -3.180471420288086, dm2: -5.135916233062744
# dm12: 0.19240188598632812
# Mutations: ['B45D', 'C50A', 'C124A', 'B201A', 'C208A', 'D218C', 'C220B']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 5.328318119049072
# --------------------------------------------------
# dm1: -3.203436851501465, dm2: -5.794458389282227
# dm12: -0.4891071319580078
# Mutations: ['C10B', 'C124D', 'D125A', 'A154C']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 5.305351257324219
# --------------------------------------------------
# dm1: -3.203436851501465, dm2: -5.794458389282227
# dm12: -0.4891071319580078
# Mutations: ['C10B', 'C124D', 'D125A', 'A154C']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 5.305351257324219
# --------------------------------------------------
# dm1: -3.2353663444519043, dm2: -3.5102124214172363
# dm12: 1.7632007598876953
# Mutations: ['A14B', 'C31A', 'C113D', 'C124A', 'D125A', 'A193C', 'B201A', 'B205A', 'B206A', 'D218C', 'B231A', 'B254D']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 5.273413181304932
# --------------------------------------------------
# dm1: -3.24466609954834, dm2: -6.522477626800537
# dm12: -1.258352279663086
# Mutations: ['B23D', 'A28B', 'A37B', 'A72D', 'D119A', 'C122B', 'D125A', 'C215B', 'C221D', 'A222C']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 5.264125347137451
# --------------------------------------------------
# dm1: -3.2637476921081543, dm2: -4.859922409057617
# dm12: 0.38510894775390625
# Mutations: ['A54B', 'A101B', 'C124D', 'D125B', 'A163B', 'D253A', 'B254D']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 5.245031356811523
# --------------------------------------------------
# dm1: -3.285371780395508, dm2: -4.715664863586426
# dm12: 0.5077438354492188
# Mutations: ['C31A', 'C124D', 'D125A', 'D138C', 'A167B', 'B201A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 5.2234086990356445
# --------------------------------------------------
# dm1: -3.287233352661133, dm2: -6.135939121246338
# dm12: -0.9143733978271484
# Mutations: ['C31A', 'A72D', 'D112C', 'D119A', 'C122B', 'C124A', 'B201A', 'C219A', 'A222C']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 5.2215657234191895
# --------------------------------------------------
# dm1: -3.309129238128662, dm2: -5.10749626159668
# dm12: 0.09216117858886719
# Mutations: ['C10B', 'A101B', 'D119C', 'C122B', 'D125A', 'C165A', 'B201A', 'C208A', 'C215B', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 5.199657440185547
# --------------------------------------------------
# dm1: -3.312962532043457, dm2: -4.542983055114746
# dm12: 0.6528511047363281
# Mutations: ['A11B', 'D24B', 'B25A', 'D39A', 'A72D', 'A101B', 'B201A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 5.195834159851074
# --------------------------------------------------
# dm1: -3.314356803894043, dm2: -4.7231764793396
# dm12: 0.47125816345214844
# Mutations: ['D17A', 'A72D', 'A101B', 'B201A', 'C208A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 5.194434642791748
# --------------------------------------------------
# dm1: -3.3308792114257812, dm2: -5.312198162078857
# dm12: -0.13428688049316406
# Mutations: ['C31A', 'B88A', 'A101B', 'D125A', 'A181B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 5.177911281585693
# --------------------------------------------------
# dm1: -3.3388619422912598, dm2: -5.426808834075928
# dm12: -0.2568798065185547
# Mutations: ['A14B', 'D17A', 'C31A', 'A56B', 'A101B', 'C124B', 'D125A', 'B135C', 'D160B', 'D218C', 'B251C']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 5.169929027557373
# --------------------------------------------------
# dm1: -3.339536666870117, dm2: -4.947511196136475
# dm12: 0.2217426300048828
# Mutations: ['A11B', 'D24C', 'C31A', 'B45D', 'A72D', 'D112C', 'D119C', 'C122B', 'D125A', 'C215B']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 5.169253826141357
# --------------------------------------------------
# dm1: -3.3407411575317383, dm2: -5.630547523498535
# dm12: -0.4624977111816406
# Mutations: ['A97B', 'A101B', 'D119B', 'D138B', 'D143B', 'C156A', 'C208A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 5.1680498123168945
# --------------------------------------------------
# dm1: -3.3656959533691406, dm2: -7.111997604370117
# dm12: -1.9688987731933594
# Mutations: ['A14B', 'A101B', 'C124A', 'B135C', 'A181B', 'B201A', 'A222C']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 5.143098831176758
# --------------------------------------------------
# dm1: -3.393589973449707, dm2: -6.304719924926758
# dm12: -1.1895179748535156
# Mutations: ['A11B', 'C31A', 'B38A', 'B45C', 'A72D', 'B84D', 'C124D', 'A163C', 'A193C', 'B201A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 5.115201950073242
# --------------------------------------------------
# dm1: -3.418804168701172, dm2: -5.143433570861816
# dm12: -0.053455352783203125
# Mutations: ['A11B', 'C31A', 'A101B', 'B111C', 'C113D', 'D119C', 'D125A', 'B135C', 'A181B', 'B201A', 'B206A', 'C212B', 'D218C', 'C219D', 'A222C']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): 5.089978218078613
# --------------------------------------------------
# dm1: -3.42006778717041, dm2: -4.785667896270752
# dm12: 0.3030567169189453
# Mutations: ['A14B', 'C31A', 'C50A', 'A72D', 'A101B', 'D119A', 'C122B', 'A163C', 'A171B', 'B201A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 5.088724613189697
# --------------------------------------------------
# dm1: -3.4254136085510254, dm2: -5.5536932945251465
# dm12: -0.4703197479248047
# Mutations: ['A14B', 'D17A', 'C31A', 'A56B', 'A101B', 'C124B', 'D125A', 'B135C', 'D160B', 'B251C']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 5.083373546600342
# --------------------------------------------------
# dm1: -3.4321718215942383, dm2: -5.246195316314697
# dm12: -0.1695842742919922
# Mutations: ['C31A', 'B34A', 'A101B', 'D112A', 'C124B', 'D125A', 'B135C', 'B207A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 5.076611042022705
# --------------------------------------------------
# dm1: -3.446906089782715, dm2: -4.868161678314209
# dm12: 0.1937236785888672
# Mutations: ['D17A', 'A72D', 'B201A', 'C208A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 5.061885356903076
# --------------------------------------------------
# dm1: -3.455885887145996, dm2: -5.625406742095947
# dm12: -0.5725040435791016
# Mutations: ['D17A', 'D39B', 'A72D', 'C124A', 'C219A', 'A222C']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 5.052902698516846
# --------------------------------------------------
# dm1: -3.483393669128418, dm2: -5.807560920715332
# dm12: -0.7821617126464844
# Mutations: ['D17A', 'A101B', 'C124D', 'D125B', 'B135C', 'A163C', 'C208A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 5.025399208068848
# --------------------------------------------------
# dm1: -3.524595260620117, dm2: -6.67430305480957
# dm12: -1.690103530883789
# Mutations: ['A72D', 'D112C', 'D119A', 'C122B', 'C124A', 'B201A', 'A203B', 'C219A', 'A222C']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.984199523925781
# --------------------------------------------------
# dm1: -3.534121036529541, dm2: -5.030986785888672
# dm12: -0.0563201904296875
# Mutations: ['A30B', 'A101B', 'C123B', 'C124D', 'B201A', 'D218B', 'B256A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.974666595458984
# --------------------------------------------------
# dm1: -3.539902687072754, dm2: -6.780471324920654
# dm12: -1.81158447265625
# Mutations: ['D17A', 'B25A', 'C50A', 'A101B', 'C124A', 'C221D', 'A222C', 'D253A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.968886852264404
# --------------------------------------------------
# dm1: -3.5408239364624023, dm2: -5.050738334655762
# dm12: -0.08276939392089844
# Mutations: ['A11B', 'B20A', 'B70A', 'A101B', 'D119B', 'C124D', 'A193C', 'C195D', 'B206A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.967968940734863
# --------------------------------------------------
# dm1: -3.5408239364624023, dm2: -5.050738334655762
# dm12: -0.08276939392089844
# Mutations: ['A11B', 'B20A', 'B70A', 'A101B', 'D119B', 'C124D', 'A193C', 'C195D', 'B206A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.967968940734863
# --------------------------------------------------
# dm1: -3.5408239364624023, dm2: -5.050738334655762
# dm12: -0.08276939392089844
# Mutations: ['A11B', 'B20A', 'B70A', 'A101B', 'D119B', 'C124D', 'A193C', 'C195D', 'B206A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.967968940734863
# --------------------------------------------------
# dm1: -3.5614657402038574, dm2: -4.419427394866943
# dm12: 0.52789306640625
# Mutations: ['A11B', 'B25A', 'C31A', 'B45D', 'A101B', 'A193C', 'B256A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.947320461273193
# --------------------------------------------------
# dm1: -3.592164993286133, dm2: -5.2559814453125
# dm12: -0.33935546875
# Mutations: ['A101B', 'A154C', 'C165A', 'A171D', 'D211C']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.9166259765625
# --------------------------------------------------
# dm1: -3.592164993286133, dm2: -5.2559814453125
# dm12: -0.33935546875
# Mutations: ['A101B', 'A154C', 'C165A', 'A171D', 'D211C']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.9166259765625
# --------------------------------------------------
# dm1: -3.5927629470825195, dm2: -6.649096965789795
# dm12: -1.7330741882324219
# Mutations: ['A11B', 'D17C', 'C50A', 'A72D', 'D119C', 'C220B']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.916022777557373
# --------------------------------------------------
# dm1: -3.5996522903442383, dm2: -6.0282392501831055
# dm12: -1.119100570678711
# Mutations: ['B45C', 'A101B', 'D125A', 'A181B', 'B201A', 'C219A', 'A222C']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.9091386795043945
# --------------------------------------------------
# dm1: -3.6028342247009277, dm2: -4.668622970581055
# dm12: 0.23732948303222656
# Mutations: ['A30B', 'A101B', 'D112A', 'C123B', 'C124D', 'B201A', 'D218B', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.905952453613281
# --------------------------------------------------
# dm1: -3.9327640533447266, dm2: -3.61911678314209
# dm12: 0.9569187164306641
# Mutations: ['A11B', 'A28B', 'A37B', 'D39A', 'C50A', 'A72D', 'D112A', 'C124A', 'D125A', 'A167B', 'B201A', 'D253A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 4.889682769775391
# --------------------------------------------------
# dm1: -3.6319799423217773, dm2: -5.665191650390625
# dm12: -0.7883815765380859
# Mutations: ['D17A', 'C124D', 'A154C', 'B201A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 4.876810073852539
# --------------------------------------------------
# dm1: -3.6322765350341797, dm2: -5.140528202056885
# dm12: -0.26401710510253906
# Mutations: ['B20A', 'A72D', 'A101B', 'C113A', 'C124D', 'D125B', 'B204A', 'B206A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.876511096954346
# --------------------------------------------------
# dm1: -3.6399240493774414, dm2: -4.740581035614014
# dm12: 0.1282806396484375
# Mutations: ['D17A', 'D24A', 'D39A', 'A101B', 'C124D', 'A167B', 'B201A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.868861675262451
# --------------------------------------------------
# dm1: -3.6474361419677734, dm2: -5.542069911956787
# dm12: -0.68072509765625
# Mutations: ['C10B', 'C31A', 'D112A', 'C113D', 'C124D', 'D125A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.861344814300537
# --------------------------------------------------
# dm1: -3.6809940338134766, dm2: -5.850817680358887
# dm12: -1.023019790649414
# Mutations: ['B6C', 'C10B', 'B45D', 'A101B', 'D119C', 'C122B', 'C124A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.827797889709473
# --------------------------------------------------
# dm1: -3.681349754333496, dm2: -5.916553020477295
# dm12: -1.089111328125
# Mutations: ['D17A', 'A72D', 'A101B', 'D119A', 'C122B', 'D125A', 'B169A', 'C220B', 'B227A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.827441692352295
# --------------------------------------------------
# dm1: -3.681349754333496, dm2: -5.916553020477295
# dm12: -1.089111328125
# Mutations: ['D17A', 'A72D', 'A101B', 'D119A', 'C122B', 'D125A', 'B169A', 'C220B', 'B227A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.827441692352295
# --------------------------------------------------
# dm1: -3.7019271850585938, dm2: -6.395430564880371
# dm12: -1.5885725021362305
# Mutations: ['A11B', 'B21C', 'B25A', 'D119A', 'C122B', 'D125A', 'B201A', 'A203B', 'D218C', 'C234D', 'D253A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 4.806858062744141
# --------------------------------------------------
# dm1: -3.7019271850585938, dm2: -6.395430564880371
# dm12: -1.5885725021362305
# Mutations: ['A11B', 'B21C', 'B25A', 'D119A', 'C122B', 'D125A', 'B201A', 'A203B', 'D218C', 'C234D', 'D253A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 4.806858062744141
# --------------------------------------------------
# dm1: -3.7019271850585938, dm2: -6.395430564880371
# dm12: -1.5885725021362305
# Mutations: ['A11B', 'B21C', 'B25A', 'D119A', 'C122B', 'D125A', 'B201A', 'A203B', 'D218C', 'C234D', 'D253A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 4.806858062744141
# --------------------------------------------------
# dm1: -3.703993797302246, dm2: -5.585803985595703
# dm12: -0.7810096740722656
# Mutations: ['A14B', 'A28B', 'D39A', 'B91C', 'C124D', 'A193C', 'B201A', 'D218C', 'D230A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.8047943115234375
# --------------------------------------------------
# dm1: -3.7065463066101074, dm2: -5.007496356964111
# dm12: -0.20525169372558594
# Mutations: ['C7A', 'A11B', 'B20A', 'C31A', 'A101B', 'B135C', 'A151B', 'B201A', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.802244663238525
# --------------------------------------------------
# dm1: -3.7151880264282227, dm2: -4.159154891967773
# dm12: 0.6344413757324219
# Mutations: ['B23D', 'C31A', 'A72D', 'B201A', 'D211B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.793596267700195
# --------------------------------------------------
# dm1: -3.721050262451172, dm2: -5.271993637084961
# dm12: -0.4842510223388672
# Mutations: ['D17A', 'D24A', 'B25A', 'D39A', 'A101B', 'C124D', 'C165A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.787742614746094
# --------------------------------------------------
# dm1: -3.724893569946289, dm2: -6.030790328979492
# dm12: -1.2468910217285156
# Mutations: ['A101B', 'A181B', 'B201A', 'C219A', 'A222C']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.783899307250977
# --------------------------------------------------
# dm1: -3.728761672973633, dm2: -5.64010763168335
# dm12: -0.8600788116455078
# Mutations: ['A11B', 'A28B', 'C31A', 'A32B', 'A72D', 'D119C', 'B135C', 'A181B', 'B201A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.780028820037842
# --------------------------------------------------
# dm1: -3.7478952407836914, dm2: -5.184152126312256
# dm12: -0.42325401306152344
# Mutations: ['D17A', 'B34A', 'A72D', 'C124A', 'B201A', 'B206A', 'D218C']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.760898113250732
# --------------------------------------------------
# dm1: -3.7609386444091797, dm2: -6.033051490783691
# dm12: -1.2851924896240234
# Mutations: ['B16C', 'D22A', 'A97B', 'A101B', 'D119B', 'D138B', 'D143B', 'C156A', 'C208A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.747859001159668
# --------------------------------------------------
# dm1: -4.527413845062256, dm2: -3.775723457336426
# dm12: 0.20564842224121094
# Mutations: ['C50A', 'A101B', 'A176B', 'B205A', 'B206A', 'D218C', 'B227A', 'D255C', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.733062267303467
# --------------------------------------------------
# dm1: -3.7757816314697266, dm2: -5.169486999511719
# dm12: -0.4364795684814453
# Mutations: ['B91C', 'A101B', 'D119C', 'C122B', 'C124A', 'A163C', 'C208B', 'D255B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.733007431030273
# --------------------------------------------------
# dm1: -3.782660484313965, dm2: -5.244297504425049
# dm12: -0.5181732177734375
# Mutations: ['B6A', 'C7B', 'A14B', 'D17A', 'C31A', 'D39C', 'D112C', 'C124A', 'D125A', 'B135C', 'D230A', 'B254C', 'D255B']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 4.726124286651611
# --------------------------------------------------
# dm1: -3.7910003662109375, dm2: -5.575707912445068
# dm12: -0.8579196929931641
# Mutations: ['C124A', 'D125A', 'B135C', 'A167B']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 4.717788219451904
# --------------------------------------------------
# dm1: -3.7910003662109375, dm2: -5.575707912445068
# dm12: -0.8579196929931641
# Mutations: ['C124A', 'D125A', 'B135C', 'A167B']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 4.717788219451904
# --------------------------------------------------
# dm1: -3.798262596130371, dm2: -5.048018932342529
# dm12: -0.337493896484375
# Mutations: ['D112B', 'C122B', 'C124D', 'D125A', 'B201A', 'D218C']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.710525035858154
# --------------------------------------------------
# dm1: -3.8132243156433105, dm2: -4.831280708312988
# dm12: -0.13571929931640625
# Mutations: ['A11B', 'A13B', 'C31A', 'A101B', 'D119C', 'C122B', 'C124D', 'A163C', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.695561408996582
# --------------------------------------------------
# dm1: -3.813425064086914, dm2: -5.544486045837402
# dm12: -0.84912109375
# Mutations: ['A11B', 'D24C', 'B25A', 'C31A', 'B84C', 'D95C', 'C99A', 'A101B', 'D112A', 'D119C', 'D136C', 'B201A', 'A203B', 'C208A', 'D218C', 'C234A']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): 4.695364952087402
# --------------------------------------------------
# dm1: -3.814401626586914, dm2: -5.635643482208252
# dm12: -0.9412517547607422
# Mutations: ['A101B', 'A154C', 'B201A', 'C215B']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 4.69439172744751
# --------------------------------------------------
# dm1: -3.818206310272217, dm2: -4.769307613372803
# dm12: -0.07872772216796875
# Mutations: ['B20A', 'A101B', 'A193C', 'B256A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 4.690579891204834
# --------------------------------------------------
# dm1: -3.819708824157715, dm2: -4.3873796463012695
# dm12: 0.30170249938964844
# Mutations: ['B23D', 'A72D', 'B201A', 'D211B']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 4.689082145690918
# --------------------------------------------------
# dm1: -3.820894241333008, dm2: -5.085425853729248
# dm12: -0.39754199981689453
# Mutations: ['A11B', 'C31A', 'A101B', 'B111C', 'C113D', 'C122B', 'C124D', 'D218C']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.6878838539123535
# --------------------------------------------------
# dm1: -3.821310043334961, dm2: -5.989697456359863
# dm12: -1.3022270202636719
# Mutations: ['A13B', 'C31A', 'B79A', 'A101B', 'B201A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.687470436096191
# --------------------------------------------------
# dm1: -3.824580192565918, dm2: -6.68416166305542
# dm12: -1.9999542236328125
# Mutations: ['A101B', 'A103B', 'D119A', 'C122B', 'C124D', 'A193C']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.684207439422607
# --------------------------------------------------
# dm1: -3.831756591796875, dm2: -6.5912251472473145
# dm12: -1.9141921997070312
# Mutations: ['C31A', 'A101B', 'D119A', 'C122B', 'C124D', 'A181B', 'B201A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.677032947540283
# --------------------------------------------------
# dm1: -3.842283248901367, dm2: -6.819342613220215
# dm12: -2.1528377532958984
# Mutations: ['A11B', 'D17C', 'B23D', 'B27D', 'C113D', 'D119C', 'C124A', 'B206A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.666504859924316
# --------------------------------------------------
# dm1: -3.8433170318603516, dm2: -6.469142436981201
# dm12: -1.8036613464355469
# Mutations: ['A72D', 'D119A', 'C122B', 'C124A', 'C215B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.665481090545654
# --------------------------------------------------
# dm1: -3.850545883178711, dm2: -6.994641304016113
# dm12: -2.336393356323242
# Mutations: ['D17A', 'A93C', 'A101B', 'C124A', 'B135C', 'A142C', 'B201A', 'C234D']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.658247947692871
# --------------------------------------------------
# dm1: -3.8601694107055664, dm2: -5.020771503448486
# dm12: -0.3721599578857422
# Mutations: ['A11B', 'D24C', 'C31A', 'A101B', 'D119C', 'C122B', 'D125A', 'B201A', 'C220B', 'C232A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 4.648611545562744
# --------------------------------------------------
# dm1: -3.8601694107055664, dm2: -5.020771503448486
# dm12: -0.3721599578857422
# Mutations: ['A11B', 'D24C', 'C31A', 'A101B', 'D119C', 'C122B', 'D125A', 'B201A', 'C220B', 'C232A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 4.648611545562744
# --------------------------------------------------
# dm1: -3.8608241081237793, dm2: -4.913544654846191
# dm12: -0.2655754089355469
# Mutations: ['D17A', 'A72D', 'C124A', 'A188B', 'B201A', 'B256A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.6479692459106445
# --------------------------------------------------
# dm1: -3.8685455322265625, dm2: -5.529704570770264
# dm12: -0.8894577026367188
# Mutations: ['A101B', 'C124A', 'D125A', 'A154C', 'A171C', 'B187A', 'B206A', 'D211C']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.640246868133545
# --------------------------------------------------
# dm1: -3.892425537109375, dm2: -5.615357875823975
# dm12: -0.9989948272705078
# Mutations: ['A11B', 'A14B', 'B21C', 'D24B', 'B25A', 'D39A', 'B45D', 'A74B', 'A97B', 'A101B', 'D119A', 'C122B', 'D125A', 'D143B', 'A163D', 'D216A']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): 4.616363048553467
# --------------------------------------------------
# dm1: -3.895705223083496, dm2: -5.162773609161377
# dm12: -0.5496864318847656
# Mutations: ['D17A', 'A101B', 'B201A', 'C208A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 4.613087177276611
# --------------------------------------------------
# dm1: -3.895705223083496, dm2: -5.162773609161377
# dm12: -0.5496864318847656
# Mutations: ['D17A', 'A101B', 'B201A', 'C208A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 4.613087177276611
# --------------------------------------------------
# dm1: -3.900886058807373, dm2: -4.615078449249268
# dm12: -0.00717926025390625
# Mutations: ['D17A', 'A101B', 'D112B', 'C122B', 'C124D', 'B201A', 'C208A', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.607899188995361
# --------------------------------------------------
# dm1: -3.9009132385253906, dm2: -4.611883163452148
# dm12: -0.0040130615234375
# Mutations: ['A11B', 'C31A', 'A37B', 'A101B', 'C113A', 'C124D', 'D125A', 'B201A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.607870101928711
# --------------------------------------------------
# dm1: -3.9009132385253906, dm2: -4.611883163452148
# dm12: -0.0040130615234375
# Mutations: ['A11B', 'C31A', 'A37B', 'A101B', 'C113A', 'C124D', 'D125A', 'B201A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.607870101928711
# --------------------------------------------------
# dm1: -3.9069061279296875, dm2: -6.673532009124756
# dm12: -2.0716400146484375
# Mutations: ['C7D', 'D39A', 'A101B', 'C124D', 'D125A', 'B135C', 'A167B', 'A181B', 'B201A', 'C215B']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 4.601891994476318
# --------------------------------------------------
# dm1: -3.907618522644043, dm2: -5.9305596351623535
# dm12: -1.3293895721435547
# Mutations: ['A11B', 'B45C', 'A72D', 'C113D', 'C124D', 'C195D']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.601170063018799
# --------------------------------------------------
# dm1: -3.910123825073242, dm2: -4.756073951721191
# dm12: -0.15740394592285156
# Mutations: ['D17A', 'A72D', 'C156A', 'B201A', 'C208A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.59867000579834
# --------------------------------------------------
# dm1: -3.9147467613220215, dm2: -5.128856658935547
# dm12: -0.5348148345947266
# Mutations: ['D17A', 'B45D', 'C50A', 'A101B', 'C113D', 'C124A', 'A163C', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.59404182434082
# --------------------------------------------------
# dm1: -3.9221725463867188, dm2: -4.198050022125244
# dm12: 0.3885612487792969
# Mutations: ['A11B', 'A101B', 'B111C', 'D112B', 'D119B', 'D125A', 'D126B', 'B150A', 'B201A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.586611270904541
# --------------------------------------------------
# dm1: -3.9259185791015625, dm2: -6.992849826812744
# dm12: -2.409975051879883
# Mutations: ['B6C', 'C10B', 'D119A', 'C122B', 'C124A', 'D125A', 'C220B', 'B227A', 'C234D']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.582874774932861
# --------------------------------------------------
# dm1: -3.9376368522644043, dm2: -5.30971622467041
# dm12: -0.7385654449462891
# Mutations: ['A11B', 'D24C', 'A101B', 'D119C', 'C122B', 'B135C', 'D211C', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.571150779724121
# --------------------------------------------------
# dm1: -3.9376368522644043, dm2: -5.30971622467041
# dm12: -0.7385654449462891
# Mutations: ['A11B', 'D24C', 'A101B', 'D119C', 'C122B', 'B135C', 'D211C', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.571150779724121
# --------------------------------------------------
# dm1: -3.938220500946045, dm2: -5.667089462280273
# dm12: -1.0965213775634766
# Mutations: ['D17A', 'A101B', 'C124A', 'D125B', 'B135C', 'A163C', 'B256A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.570568084716797
# --------------------------------------------------
# dm1: -3.943303108215332, dm2: -6.128482818603516
# dm12: -1.5630016326904297
# Mutations: ['C31A', 'A54B', 'C113D', 'C124A', 'D125A', 'B201A', 'C215B']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.565481185913086
# --------------------------------------------------
# dm1: -3.943303108215332, dm2: -6.128482818603516
# dm12: -1.5630016326904297
# Mutations: ['C31A', 'A54B', 'C113D', 'C124A', 'D125A', 'B201A', 'C215B']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.565481185913086
# --------------------------------------------------
# dm1: -3.9436349868774414, dm2: -6.333526611328125
# dm12: -1.7683830261230469
# Mutations: ['B6C', 'D17A', 'C124D', 'D125A', 'D126A', 'B135C', 'A188B', 'D218C', 'C220B', 'A225B', 'B227A', 'C234A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 4.565143585205078
# --------------------------------------------------
# dm1: -3.9497194290161133, dm2: -6.731297492980957
# dm12: -2.172229766845703
# Mutations: ['A101B', 'A103B', 'D119A', 'C122B', 'C124D']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.559067726135254
# --------------------------------------------------
# dm1: -3.9694995880126953, dm2: -5.216351509094238
# dm12: -0.6770610809326172
# Mutations: ['C31A', 'A101B', 'B111A']
# Mutation Count: 3
# Dm1m2-min(dm1,dm2): 4.539290428161621
# --------------------------------------------------
# dm1: -3.9760875701904297, dm2: -5.208654403686523
# dm12: -0.6759529113769531
# Mutations: ['B20A', 'D112A', 'C124A']
# Mutation Count: 3
# Dm1m2-min(dm1,dm2): 4.53270149230957
# --------------------------------------------------
# dm1: -3.977173328399658, dm2: -5.267848014831543
# dm12: -0.7362346649169922
# Mutations: ['C10B', 'D125B', 'C165A', 'B256A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 4.531613349914551
# --------------------------------------------------
# dm1: -3.984431266784668, dm2: -5.4554572105407715
# dm12: -0.9310989379882812
# Mutations: ['D39A', 'C59A', 'C124D', 'D125A', 'D126A', 'A154B', 'B201A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.52435827255249
# --------------------------------------------------
# dm1: -3.984431266784668, dm2: -5.4554572105407715
# dm12: -0.9310989379882812
# Mutations: ['D39A', 'C59A', 'C124D', 'D125A', 'D126A', 'A154B', 'B201A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.52435827255249
# --------------------------------------------------
# dm1: -3.984431266784668, dm2: -5.4554572105407715
# dm12: -0.9310989379882812
# Mutations: ['D39A', 'C59A', 'C124D', 'D125A', 'D126A', 'A154B', 'B201A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.52435827255249
# --------------------------------------------------
# dm1: -3.988072395324707, dm2: -5.265437602996826
# dm12: -0.7447299957275391
# Mutations: ['B25A', 'C31A', 'A101B', 'C165A', 'A193B', 'D211C']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.520707607269287
# --------------------------------------------------
# dm1: -3.9906110763549805, dm2: -5.554225444793701
# dm12: -1.0360431671142578
# Mutations: ['A11B', 'B20A', 'A101B', 'D119C', 'C124A', 'D136C', 'A193C']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.518182277679443
# --------------------------------------------------
# dm1: -3.991753578186035, dm2: -5.669339179992676
# dm12: -1.1522998809814453
# Mutations: ['B111C', 'D119A', 'C122B', 'D125A', 'B201A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.5170392990112305
# --------------------------------------------------
# dm1: -3.999666213989258, dm2: -5.50730037689209
# dm12: -0.9981861114501953
# Mutations: ['A14B', 'B21C', 'C50A', 'A176B']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 4.5091142654418945
# --------------------------------------------------
# dm1: -4.0006513595581055, dm2: -5.48744010925293
# dm12: -0.9793014526367188
# Mutations: ['A154C']
# Mutation Count: 1
# Dm1m2-min(dm1,dm2): 4.508138656616211
# --------------------------------------------------
# dm1: -4.022156715393066, dm2: -6.071883678436279
# dm12: -1.5852489471435547
# Mutations: ['A11B', 'C113D', 'D119C', 'C122B', 'D125A', 'B141A', 'C234D']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.486634731292725
# --------------------------------------------------
# dm1: -4.022156715393066, dm2: -6.071883678436279
# dm12: -1.5852489471435547
# Mutations: ['A11B', 'C113D', 'D119C', 'C122B', 'D125A', 'B141A', 'C234D']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.486634731292725
# --------------------------------------------------
# dm1: -4.023266792297363, dm2: -5.8863701820373535
# dm12: -1.4008464813232422
# Mutations: ['A32B', 'D119C', 'B201A', 'D211C', 'C219A', 'A222C']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.485523700714111
# --------------------------------------------------
# dm1: -4.028253555297852, dm2: -5.307759761810303
# dm12: -0.8272247314453125
# Mutations: ['D17A', 'B201A', 'C208A']
# Mutation Count: 3
# Dm1m2-min(dm1,dm2): 4.48053503036499
# --------------------------------------------------
# dm1: -4.031688690185547, dm2: -5.729218482971191
# dm12: -1.2521171569824219
# Mutations: ['C10B', 'D24C', 'A101B', 'A154C', 'A163D', 'C165A', 'B240A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.4771013259887695
# --------------------------------------------------
# dm1: -4.03321647644043, dm2: -5.565290927886963
# dm12: -1.0897140502929688
# Mutations: ['D17A', 'A101B', 'C124A', 'D125B', 'A163C', 'D218C']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.475576877593994
# --------------------------------------------------
# dm1: -4.601166248321533, dm2: -4.03400993347168
# dm12: -0.12639236450195312
# Mutations: ['D17A', 'A72D', 'A74C', 'C124A', 'D125A', 'C156A', 'A167B', 'B201A', 'C220B', 'B227A', 'D230A', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 4.47477388381958
# --------------------------------------------------
# dm1: -4.0474677085876465, dm2: -5.188828945159912
# dm12: -0.7275104522705078
# Mutations: ['D17A', 'A101B', 'D112B', 'C124D', 'D125B', 'A163C', 'C232D', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.461318492889404
# --------------------------------------------------
# dm1: -4.047717094421387, dm2: -5.343810081481934
# dm12: -0.8827419281005859
# Mutations: ['C57A', 'A72D']
# Mutation Count: 2
# Dm1m2-min(dm1,dm2): 4.461068153381348
# --------------------------------------------------
# dm1: -4.78171443939209, dm2: -4.052134990692139
# dm12: -0.3250579833984375
# Mutations: ['A11B', 'A28B', 'A37B', 'A41C', 'B45A', 'A72D', 'C156A', 'B201A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.456656455993652
# --------------------------------------------------
# dm1: -4.052328109741211, dm2: -5.544733047485352
# dm12: -1.088266372680664
# Mutations: ['A101B', 'C124B', 'D125B']
# Mutation Count: 3
# Dm1m2-min(dm1,dm2): 4.4564666748046875
# --------------------------------------------------
# dm1: -4.057496070861816, dm2: -6.192668914794922
# dm12: -1.7413787841796875
# Mutations: ['D17A', 'C50A', 'C124A', 'D125A', 'C215B', 'C220B']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.451290130615234
# --------------------------------------------------
# dm1: -4.063193321228027, dm2: -5.195903778076172
# dm12: -0.7503204345703125
# Mutations: ['D17A', 'C31A', 'A101B', 'B111C', 'C124D', 'C208A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.445583343505859
# --------------------------------------------------
# dm1: -4.066425800323486, dm2: -5.183044910430908
# dm12: -0.7406826019287109
# Mutations: ['A14B', 'D17A', 'A72D', 'C124A', 'C156A', 'B201A', 'B256A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.442362308502197
# --------------------------------------------------
# dm1: -4.068002223968506, dm2: -4.565499305725098
# dm12: -0.12471771240234375
# Mutations: ['B23D', 'B63C', 'A101B', 'C124A', 'B256A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.440781593322754
# --------------------------------------------------
# dm1: -4.379714012145996, dm2: -4.071926116943359
# dm12: 0.0571441650390625
# Mutations: ['B6A', 'A14B', 'D17A', 'D24A', 'B25A', 'A28B', 'D39A', 'B45A', 'C50A', 'A74C']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 4.436858177185059
# --------------------------------------------------
# dm1: -6.257948398590088, dm2: -4.072028160095215
# dm12: -1.8211908340454102
# Mutations: ['C50A', 'A74C', 'A101B', 'B111C', 'B157A', 'D160C', 'A193D', 'B201A', 'D253A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.436757564544678
# --------------------------------------------------
# dm1: -4.079805374145508, dm2: -6.253021717071533
# dm12: -1.824045181274414
# Mutations: ['D17A', 'C57A', 'C124D', 'D218C', 'C219A', 'A222C', 'D230A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.428976535797119
# --------------------------------------------------
# dm1: -4.079805374145508, dm2: -6.253021717071533
# dm12: -1.824045181274414
# Mutations: ['D17A', 'C57A', 'C124D', 'D218C', 'C219A', 'A222C', 'D230A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.428976535797119
# --------------------------------------------------
# dm1: -4.09140682220459, dm2: -5.088289260864258
# dm12: -0.6709079742431641
# Mutations: ['D17A', 'C50A', 'A72D', 'D112B', 'D119B', 'C123B', 'C124D']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.417381286621094
# --------------------------------------------------
# dm1: -4.097683906555176, dm2: -5.125670433044434
# dm12: -0.714569091796875
# Mutations: ['A28B', 'A30D', 'D39A', 'D112A', 'B201A', 'C220B', 'D253A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.411101341247559
# --------------------------------------------------
# dm1: -4.1009111404418945, dm2: -5.800514221191406
# dm12: -1.39263916015625
# Mutations: ['C10B', 'B201A']
# Mutation Count: 2
# Dm1m2-min(dm1,dm2): 4.407875061035156
# --------------------------------------------------
# dm1: -4.101034164428711, dm2: -5.296860218048096
# dm12: -0.8891029357910156
# Mutations: ['D17A', 'A101B', 'C208A']
# Mutation Count: 3
# Dm1m2-min(dm1,dm2): 4.40775728225708
# --------------------------------------------------
# dm1: -4.1018853187561035, dm2: -6.790482521057129
# dm12: -2.3835830688476562
# Mutations: ['D17A', 'C31A', 'A101B', 'D119A', 'C122B', 'C124A', 'D125A', 'C156A', 'B206A', 'C215B', 'C221D', 'A222C', 'B256A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 4.406899452209473
# --------------------------------------------------
# dm1: -4.104951858520508, dm2: -5.394957065582275
# dm12: -0.991119384765625
# Mutations: ['A11B', 'D24C', 'B25A', 'C31A', 'B84C', 'D95C', 'C99A', 'A101B', 'D112A', 'D119C', 'D136C', 'D160C', 'B201A', 'A203B', 'C208A', 'D218C', 'C234A', 'D253A']
# Mutation Count: 18
# Dm1m2-min(dm1,dm2): 4.40383768081665
# --------------------------------------------------
# dm1: -4.107888221740723, dm2: -5.079217433929443
# dm12: -0.678314208984375
# Mutations: ['A11B', 'A14B', 'D24C', 'A74C', 'A101B', 'D125A', 'A163C', 'B201A', 'C234A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.400903224945068
# --------------------------------------------------
# dm1: -4.11565637588501, dm2: -5.228795528411865
# dm12: -0.8356647491455078
# Mutations: ['D17A', 'A101B', 'C124D', 'A163C', 'C208A', 'D211A', 'B256A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.393130779266357
# --------------------------------------------------
# dm1: -4.118017196655273, dm2: -5.989512920379639
# dm12: -1.5987396240234375
# Mutations: ['C10B', 'A14B', 'B23D', 'A28B', 'A30B', 'D39A', 'A101B', 'C124A', 'A151B', 'B185A', 'B201A', 'B206A', 'D216A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 4.390773296356201
# --------------------------------------------------
# dm1: -4.118895053863525, dm2: -5.733956813812256
# dm12: -1.344064712524414
# Mutations: ['A3D', 'B70A', 'A101B', 'D119B', 'C124D', 'D125A', 'A154B', 'C165A', 'D211C', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 4.389892101287842
# --------------------------------------------------
# dm1: -4.138635158538818, dm2: -5.683110237121582
# dm12: -1.312967300415039
# Mutations: ['A14B', 'A32B', 'A101B', 'C124D', 'B201A', 'A222B', 'D230A', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.370142936706543
# --------------------------------------------------
# dm1: -4.140795707702637, dm2: -5.263590335845947
# dm12: -0.8956031799316406
# Mutations: ['B21C', 'C50A', 'A176B']
# Mutation Count: 3
# Dm1m2-min(dm1,dm2): 4.367987155914307
# --------------------------------------------------
# dm1: -4.1481757164001465, dm2: -5.50117826461792
# dm12: -1.14056396484375
# Mutations: ['A11B', 'B25A', 'A101B', 'B111D', 'D119C', 'C122B', 'C124A', 'A154B', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.36061429977417
# --------------------------------------------------
# dm1: -4.1481757164001465, dm2: -5.50117826461792
# dm12: -1.14056396484375
# Mutations: ['A11B', 'B25A', 'A101B', 'B111D', 'D119C', 'C122B', 'C124A', 'A154B', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.36061429977417
# --------------------------------------------------
# dm1: -4.159915924072266, dm2: -5.081158638000488
# dm12: -0.7322864532470703
# Mutations: ['A11B', 'D24C', 'A28B', 'D218B']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 4.348872184753418
# --------------------------------------------------
# dm1: -4.167396068572998, dm2: -6.141886234283447
# dm12: -1.8004951477050781
# Mutations: ['D119A', 'C122B', 'D125A', 'A154B', 'A203B', 'C234D', 'B256A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.341391086578369
# --------------------------------------------------
# dm1: -4.167454242706299, dm2: -5.766291618347168
# dm12: -1.4249553680419922
# Mutations: ['A11B', 'A13B', 'B21C', 'A101B', 'D119A', 'C122B', 'C124B', 'D136C', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.341336250305176
# --------------------------------------------------
# dm1: -4.169553756713867, dm2: -6.310757637023926
# dm12: -1.9715213775634766
# Mutations: ['C31A', 'A101B', 'D112B', 'C124A', 'D125B', 'B135C', 'A163D', 'A179C', 'A181B', 'B201A', 'C234D']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 4.339236259460449
# --------------------------------------------------
# dm1: -4.170379638671875, dm2: -6.982009410858154
# dm12: -2.643596649169922
# Mutations: ['A72D', 'B88A', 'A92C', 'B111A', 'C113D', 'C124A', 'D125A', 'A163C', 'A203B', 'C208A', 'C234D']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 4.338412761688232
# --------------------------------------------------
# dm1: -4.172049522399902, dm2: -7.163986682891846
# dm12: -2.8272361755371094
# Mutations: ['B6C', 'C10B', 'B91D', 'A97B', 'D119A', 'C122B', 'C124A', 'D125A', 'C220B', 'B227A', 'C234D']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 4.336750507354736
# --------------------------------------------------
# dm1: -4.175470352172852, dm2: -4.6790642738342285
# dm12: -0.3457469940185547
# Mutations: ['D17A', 'C31A', 'A72D', 'A103B', 'D112B', 'C124D', 'D125B', 'C156A', 'B201A', 'B206A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 4.333317279815674
# --------------------------------------------------
# dm1: -4.1861677169799805, dm2: -5.094882488250732
# dm12: -0.7722606658935547
# Mutations: ['A11B', 'C31A', 'A101B', 'B111A', 'D112A', 'D119C', 'C234D']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.322621822357178
# --------------------------------------------------
# dm1: -4.191465854644775, dm2: -5.579837799072266
# dm12: -1.2625160217285156
# Mutations: ['A11B', 'A101B', 'A181B', 'A193C', 'B201A', 'C220B', 'B227A', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.31732177734375
# --------------------------------------------------
# dm1: -4.192278861999512, dm2: -4.398229122161865
# dm12: -0.08171272277832031
# Mutations: ['D112A', 'D125A', 'C212B', 'D216A', 'D218C', 'C219A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.316516399383545
# --------------------------------------------------
# dm1: -4.192278861999512, dm2: -4.398229122161865
# dm12: -0.08171272277832031
# Mutations: ['D112A', 'D125A', 'C212B', 'D216A', 'D218C', 'C219A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 4.316516399383545
# --------------------------------------------------
# dm1: -4.193206310272217, dm2: -4.766724109649658
# dm12: -0.451141357421875
# Mutations: ['A11B', 'A13B', 'C50B', 'A101B', 'B111C', 'D125A', 'A128C', 'B227A', 'D230A', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 4.315582752227783
# --------------------------------------------------
# dm1: -4.1994218826293945, dm2: -5.224688529968262
# dm12: -0.9153270721435547
# Mutations: ['B20A', 'C31A', 'B45A', 'A101B', 'B135C', 'B157A', 'D160B', 'B201A', 'C215B']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.309361457824707
# --------------------------------------------------
# dm1: -4.204191207885742, dm2: -6.304335117340088
# dm12: -1.9997367858886719
# Mutations: ['A101B', 'C124A', 'B201A', 'D211C', 'C215B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.304598331451416
# --------------------------------------------------
# dm1: -4.205410480499268, dm2: -6.040975093841553
# dm12: -1.7375965118408203
# Mutations: ['B70A', 'A101B', 'D119B', 'C124D', 'B135C', 'A181B', 'B206A', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 4.303378582000732
# --------------------------------------------------
# dm1: -4.206392765045166, dm2: -5.676037788391113
# dm12: -1.373647689819336
# Mutations: ['A11B', 'D24C', 'B34A', 'A101B', 'D119C', 'B135C', 'C165A', 'D211C', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 4.302390098571777
# --------------------------------------------------
# dm1: -4.207394599914551, dm2: -6.405241966247559
# dm12: -2.103839874267578
# Mutations: ['D17A', 'D39A', 'A101B', 'C124D', 'B201A', 'C234A', 'B243A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.3014020919799805
# --------------------------------------------------
# dm1: -4.209763526916504, dm2: -5.80481481552124
# dm12: -1.5057849884033203
# Mutations: ['D17A', 'C31A', 'A101B', 'C124A', 'C234D']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.29902982711792
# --------------------------------------------------
# dm1: -4.209763526916504, dm2: -5.80481481552124
# dm12: -1.5057849884033203
# Mutations: ['D17A', 'C31A', 'A101B', 'C124A', 'C234D']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.29902982711792
# --------------------------------------------------
# dm1: -4.209763526916504, dm2: -5.80481481552124
# dm12: -1.5057849884033203
# Mutations: ['D17A', 'C31A', 'A101B', 'C124A', 'C234D']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 4.29902982711792
# --------------------------------------------------
# dm1: -4.218105316162109, dm2: -5.276700019836426
# dm12: -0.9860267639160156
# Mutations: ['C50A', 'A54B', 'A96B', 'A101B', 'D112B', 'C124D', 'D125A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.29067325592041
# --------------------------------------------------
# dm1: -4.218105316162109, dm2: -5.276700019836426
# dm12: -0.9860267639160156
# Mutations: ['C50A', 'A54B', 'A96B', 'A101B', 'D112B', 'C124D', 'D125A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 4.29067325592041
# --------------------------------------------------
# dm1: -4.226255416870117, dm2: -6.044014930725098
# dm12: -1.7614707946777344
# Mutations: ['C7D', 'A28B', 'D39A', 'B91D', 'C124A', 'B141A', 'C208A', 'D216A', 'C234D']
# ...
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 0.7032918930053711
# --------------------------------------------------
# dm1: -7.821249961853027, dm2: -8.374418258666992
# dm12: -7.6868696212768555
# Mutations: ['A101B', 'A151B', 'A155C', 'C156A', 'C208A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 0.6875486373901367
# --------------------------------------------------
# dm1: -7.821249961853027, dm2: -8.374418258666992
# dm12: -7.6868696212768555
# Mutations: ['A101B', 'A151B', 'A155C', 'C156A', 'C208A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 0.6875486373901367
# --------------------------------------------------
# dm1: -7.822751045227051, dm2: -9.428815841674805
# dm12: -8.742769241333008
# Mutations: ['A11B', 'C31B', 'A32B', 'D39A', 'A72D', 'A92C', 'A101B', 'B111D', 'D119C', 'B135C', 'A155C', 'A193C', 'B201A', 'D218C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 0.6860466003417969
# --------------------------------------------------
# dm1: -7.9694719314575195, dm2: -7.827441215515137
# dm12: -7.288116455078125
# Mutations: ['A14B', 'B20A', 'A32B', 'B45A', 'A101C', 'D136B', 'D138C', 'A151B', 'A155C', 'A163B', 'B201A', 'B206A', 'C220D']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 0.6813554763793945
# --------------------------------------------------
# dm1: -7.831982135772705, dm2: -9.9099760055542
# dm12: -9.233158111572266
# Mutations: ['A101C', 'C124D', 'D125A', 'B135C', 'A151B', 'A155C', 'A163C', 'B201A', 'C234D', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 0.6768178939819336
# --------------------------------------------------
# dm1: -7.832974433898926, dm2: -10.360374450683594
# dm12: -9.684547424316406
# Mutations: ['D39A', 'A92C', 'A101B', 'C124D', 'B135C', 'A155C', 'A181B', 'B201A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 0.6758270263671875
# --------------------------------------------------
# dm1: -7.838909149169922, dm2: -9.329418182373047
# dm12: -8.659524917602539
# Mutations: ['D17A', 'A72D', 'A92C', 'C124A', 'A155C']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 0.6698932647705078
# --------------------------------------------------
# dm1: -2.655229091644287, dm2: -3.9420151710510254
# dm12: -3.292660713195801
# Mutations: ['A11B', 'C113D', 'B114A', 'C124D', 'D125B', 'B147A', 'D148C', 'B158A', 'C195D']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 0.6493544578552246
# --------------------------------------------------
# dm1: -7.860657691955566, dm2: -8.775392532348633
# dm12: -8.12725830078125
# Mutations: ['D17A', 'B21A', 'B25A', 'A28B', 'D39A', 'A97B', 'A101B', 'D119B', 'A151B', 'A155C', 'D218C']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 0.6481342315673828
# --------------------------------------------------
# dm1: -7.876707077026367, dm2: -12.091141700744629
# dm12: -11.459046363830566
# Mutations: ['A11B', 'D17C', 'C31A', 'B79A', 'A97B', 'A101B', 'D119C', 'B135C', 'A151B', 'A155C', 'A163D', 'A181B', 'B201A', 'B206A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 0.6320953369140625
# --------------------------------------------------
# dm1: -2.6889660358428955, dm2: -4.791420936584473
# dm12: -4.1757917404174805
# Mutations: ['A14B', 'A74C', 'C75A', 'B79A', 'D119C', 'C122B', 'C124A', 'D125A', 'D138A', 'B147A', 'D148C', 'A151B', 'C156A', 'A163D', 'B201A', 'D218B', 'C234A', 'B256A']
# Mutation Count: 18
# Dm1m2-min(dm1,dm2): 0.6156291961669922
# --------------------------------------------------
# dm1: -8.273347854614258, dm2: -7.909663200378418
# dm12: -7.6742143630981445
# Mutations: ['D17A', 'A54B', 'A74C', 'A97B', 'A101B', 'D112A', 'D119B', 'C124A', 'D143A', 'B187A', 'A188B', 'D211C', 'D230C', 'B256A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 0.5991334915161133
# --------------------------------------------------
# dm1: -8.048493385314941, dm2: -7.914753437042236
# dm12: -7.454445838928223
# Mutations: ['A11B', 'D24C', 'A101B', 'D119C', 'A151B', 'A155C', 'B206A', 'B207A', 'C212B']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 0.5940475463867188
# --------------------------------------------------
# dm1: -7.920058250427246, dm2: -8.17281436920166
# dm12: -7.584072113037109
# Mutations: ['D17A', 'A74C', 'A97B', 'D112A', 'D119B', 'C124A', 'D125A', 'A128B', 'D143C', 'B201A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 0.5887422561645508
# --------------------------------------------------
# dm1: -8.462699890136719, dm2: -7.920778274536133
# dm12: -7.874677658081055
# Mutations: ['B6D', 'C7B', 'C10B', 'C31A', 'A72D', 'B84C', 'B91A', 'A101B', 'D112B', 'A151B', 'A155C', 'B201A', 'B206A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 0.5880222320556641
# --------------------------------------------------
# dm1: -7.936993598937988, dm2: -9.533552169799805
# dm12: -8.96174430847168
# Mutations: ['B23D', 'A92C', 'C124A', 'A155C']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): 0.571807861328125
# --------------------------------------------------
# dm1: -7.958406925201416, dm2: -10.441988945007324
# dm12: -9.891594886779785
# Mutations: ['D17A', 'B21A', 'C31A', 'A101B', 'A103B', 'C124A', 'B135C', 'A151B', 'A155C', 'B201A', 'D218A', 'C219B', 'C234A', 'B256A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 0.5503940582275391
# --------------------------------------------------
# dm1: -7.969465255737305, dm2: -8.697786331176758
# dm12: -8.158447265625
# Mutations: ['D17A', 'A72D', 'A97B', 'A100C', 'A101B', 'B111C', 'C113A', 'C124B', 'D125A', 'D143A', 'A203B', 'B206A', 'C208A', 'C212A', 'D218C', 'D230C']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): 0.5393390655517578
# --------------------------------------------------
# dm1: -7.982655048370361, dm2: -9.01052474975586
# dm12: -8.48437786102295
# Mutations: ['B111D', 'D112B', 'C124A', 'A151B', 'A155C', 'A163D', 'B201A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 0.5261468887329102
# --------------------------------------------------
# dm1: -7.991081237792969, dm2: -8.415894508361816
# dm12: -7.8981781005859375
# Mutations: ['B106A', 'C124A', 'A151B', 'A155C', 'A193D', 'B201A', 'B206A', 'C232D', 'D253A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 0.5177164077758789
# --------------------------------------------------
# dm1: -8.229104042053223, dm2: -8.000999450683594
# dm12: -7.721301078796387
# Mutations: ['C7D', 'D17A', 'A28B', 'A30B', 'C50A', 'A72D', 'A101B', 'D112A', 'C124A', 'D125A', 'D136A', 'A151B', 'A155C', 'C156A', 'B201A', 'D218C', 'C234A', 'B256A']
# Mutation Count: 18
# Dm1m2-min(dm1,dm2): 0.5078029632568359
# --------------------------------------------------
# dm1: -8.016641616821289, dm2: -9.223382949829102
# dm12: -8.731226921081543
# Mutations: ['B6C', 'C10B', 'A13B', 'C31A', 'A101B', 'D112C', 'D119C', 'C122B', 'C124D', 'A155C', 'C156A', 'D255A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 0.4921560287475586
# --------------------------------------------------
# dm1: -8.018303871154785, dm2: -8.850603103637695
# dm12: -8.360101699829102
# Mutations: ['C31A', 'A97B', 'B111C', 'D119B', 'D125A', 'D126A', 'B135C', 'A142B', 'D143C', 'A203B', 'C208A', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 0.49050140380859375
# --------------------------------------------------
# dm1: -8.522350311279297, dm2: -8.028604507446289
# dm12: -8.042156219482422
# Mutations: ['C31A', 'B60C', 'A74C', 'A97B', 'D112B', 'C124A', 'D125A', 'D126C', 'D143C', 'B157A', 'D160B', 'A181B', 'B206A', 'B254C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 0.480194091796875
# --------------------------------------------------
# dm1: -8.040247917175293, dm2: -8.031303405761719
# dm12: -7.562752723693848
# Mutations: ['D17A', 'B84A', 'A101B', 'B111C', 'C124A', 'D125A', 'A155C', 'B157A', 'D160A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 0.4774951934814453
# --------------------------------------------------
# dm1: -8.032193183898926, dm2: -9.068951606750488
# dm12: -8.592344284057617
# Mutations: ['C31A', 'A101B', 'A151B', 'A155C', 'A163C', 'A188B', 'A203B', 'C234D']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 0.4766073226928711
# --------------------------------------------------
# dm1: -8.045511245727539, dm2: -8.542503356933594
# dm12: -8.079214096069336
# Mutations: ['C7D', 'C50D', 'A72D', 'A74C', 'A97B', 'A101B', 'D119C', 'B135C', 'D143C', 'A171B']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 0.4632892608642578
# --------------------------------------------------
# dm1: -8.046005249023438, dm2: -8.885032653808594
# dm12: -8.422235488891602
# Mutations: ['D17A', 'B60D', 'D119B', 'A155C', 'A188B', 'B262A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 0.4627971649169922
# --------------------------------------------------
# dm1: -8.08928394317627, dm2: -8.489277839660645
# dm12: -8.06977653503418
# Mutations: ['A11B', 'B34A', 'D119B', 'D125A', 'A155C', 'C156A', 'B157A', 'D230A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 0.41950130462646484
# --------------------------------------------------
# dm1: -8.09835433959961, dm2: -8.792642593383789
# dm12: -8.382195472717285
# Mutations: ['A101B', 'D112B', 'A151B', 'A155C', 'C220B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): 0.4104471206665039
# --------------------------------------------------
# dm1: -8.127031326293945, dm2: -8.599248886108398
# dm12: -8.217477798461914
# Mutations: ['A11B', 'B25A', 'D95C', 'A101B', 'B106A', 'D119B', 'B135C', 'D143A', 'B157A', 'D160B', 'A193C', 'A203B', 'C208A', 'D230C', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): 0.3817710876464844
# --------------------------------------------------
# dm1: -8.176094055175781, dm2: -9.07975959777832
# dm12: -8.747054100036621
# Mutations: ['D17A', 'C50A', 'A101C', 'C124A', 'D125A', 'A155C', 'C156A', 'C165A', 'C194A', 'B201A', 'B206A', 'A222C', 'D230A', 'D255A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 0.3327054977416992
# --------------------------------------------------
# dm1: -8.17809772491455, dm2: -8.55191421508789
# dm12: -8.221212387084961
# Mutations: ['D17A', 'A72D', 'A92C', 'D112B', 'C124A', 'D125B', 'A155C', 'B206A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 0.3307018280029297
# --------------------------------------------------
# dm1: -8.193319320678711, dm2: -9.161306381225586
# dm12: -8.845830917358398
# Mutations: ['D17A', 'A101B', 'D136B', 'A151B', 'A155C', 'B157A', 'D160A', 'B169D', 'C208B', 'C232D', 'C234D', 'D253A', 'B256A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): 0.3154754638671875
# --------------------------------------------------
# dm1: -8.19527816772461, dm2: -8.730077743530273
# dm12: -8.416561126708984
# Mutations: ['A11B', 'A14B', 'C31A', 'A41C', 'A97C', 'C113D', 'D119B', 'A151B', 'A155C', 'B157A', 'B201A', 'B206A', 'C208B', 'D218C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 0.31351661682128906
# --------------------------------------------------
# dm1: -8.223912239074707, dm2: -8.7935791015625
# dm12: -8.508695602416992
# Mutations: ['B6C', 'D17A', 'B80A', 'A101B', 'C124D', 'D125B', 'A151B', 'A155C', 'A193C', 'C212B']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 0.2848834991455078
# --------------------------------------------------
# dm1: -8.741189002990723, dm2: -8.24290657043457
# dm12: -8.475290298461914
# Mutations: ['D17A', 'A74B', 'A97B', 'D119B', 'D143C', 'B157A', 'D160B', 'B201A', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 0.2658987045288086
# --------------------------------------------------
# dm1: -8.243980407714844, dm2: -9.089269638061523
# dm12: -8.82445240020752
# Mutations: ['B6A', 'C7B', 'C50A', 'A97B', 'A101B', 'D119C', 'A151B', 'A155C', 'B201A', 'B206A', 'C208A', 'D211C', 'C212A', 'C232D']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): 0.2648172378540039
# --------------------------------------------------
# dm1: -8.261094093322754, dm2: -9.041057586669922
# dm12: -8.793341636657715
# Mutations: ['D17A', 'B49C', 'C50D', 'A101B', 'D119B', 'A155C', 'C156A', 'B206A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): 0.24771595001220703
# --------------------------------------------------
# dm1: -8.391923904418945, dm2: -8.272007942199707
# dm12: -8.155130386352539
# Mutations: ['D17A', 'C31A', 'B80A', 'A97B', 'A101B', 'D119B', 'C124A', 'D125A', 'D143A', 'B206A', 'D230C', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): 0.23679351806640625
# --------------------------------------------------
# dm1: -8.289630889892578, dm2: -9.529251098632812
# dm12: -9.310081481933594
# Mutations: ['D22B', 'A28C', 'A32B', 'A97B', 'A101B', 'D119C', 'C124D', 'D143C', 'A163C', 'D216C', 'C221A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): 0.21916961669921875
# --------------------------------------------------
# dm1: -3.6034793853759766, dm2: 0.21628665924072266
# dm12: -3.38720703125
# Mutations: ['A11B', 'D17C', 'A101B', 'D119C', 'C124D', 'B135C', 'D148B', 'A181B', 'B201A', 'C220B']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 0.21627235412597656
# --------------------------------------------------
# dm1: -8.310877799987793, dm2: -9.25900650024414
# dm12: -9.061084747314453
# Mutations: ['D17A', 'D39A', 'C50A', 'A97B', 'D112C', 'C113D', 'D119B', 'C124D', 'A155C', 'B206A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): 0.1979217529296875
# --------------------------------------------------
# dm1: -8.327661514282227, dm2: -10.150684356689453
# dm12: -9.969541549682617
# Mutations: ['A14B', 'D17A', 'B23D', 'A28B', 'A30B', 'D39A', 'A74B', 'A97B', 'A101B', 'D112C', 'D119A', 'C122B', 'D125C', 'D143C', 'B201A', 'B206A', 'B240C']
# Mutation Count: 17
# Dm1m2-min(dm1,dm2): 0.18114280700683594
# --------------------------------------------------
# dm1: -10.259430885314941, dm2: -8.34112548828125
# dm12: -10.091750144958496
# Mutations: ['B6C', 'A11B', 'D24C', 'C31A', 'B42A', 'C50A', 'A73B', 'A74C', 'B84A', 'D95C', 'A101B', 'C113A', 'C124B', 'A151B', 'A155C', 'B157A', 'D160B', 'A163C', 'B201A', 'B206A', 'D211C', 'B240C']
# Mutation Count: 22
# Dm1m2-min(dm1,dm2): 0.1676807403564453
# --------------------------------------------------
# dm1: -8.971052169799805, dm2: -8.385730743408203
# dm12: -8.847982406616211
# Mutations: ['D17A', 'A97B', 'A101B', 'B111D', 'D112B', 'D119B', 'C124B', 'D125A', 'A155C', 'C165A', 'A198B', 'B201A', 'C220B', 'B227A', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): 0.12306976318359375
# --------------------------------------------------
# dm1: -8.390265464782715, dm2: -9.280771255493164
# dm12: -9.16223430633545
# Mutations: ['A74B', 'A97B', 'D119B', 'C124A', 'D143A', 'A163D', 'D230C']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 0.11853694915771484
# --------------------------------------------------
# dm1: -9.110350608825684, dm2: -8.425379753112793
# dm12: -9.026925086975098
# Mutations: ['D17A', 'C31A', 'A72D', 'A74C', 'A101B', 'C113D', 'C124B', 'D125A', 'A151B', 'A155C', 'C156A', 'A171B', 'A181B', 'B201A', 'B206A', 'C221A']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): 0.08342552185058594
# --------------------------------------------------
# dm1: 5.275847911834717, dm2: 1.3059263229370117
# dm12: 1.3775644302368164
# Mutations: ['A11B', 'A72D', 'D112A', 'D119C', 'C122B', 'D125A', 'D138A', 'C140D', 'D148C', 'A171B', 'A196B', 'A198B', 'B201A', 'D211C', 'C215B', 'C220D']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): 0.07163810729980469
# --------------------------------------------------
# dm1: -0.2708745002746582, dm2: 0.5107488632202148
# dm12: -0.2103290557861328
# Mutations: ['C31A', 'A41C', 'A101B', 'C140A', 'D148C', 'B201A', 'B206A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): 0.06054544448852539
# --------------------------------------------------
# dm1: -8.46209716796875, dm2: -9.134765625
# dm12: -9.08806037902832
# Mutations: ['A11B', 'A28B', 'C31A', 'A32B', 'A37B', 'A56B', 'D119C', 'C122B', 'C124D', 'A151B', 'A155C', 'A163B', 'B201A', 'D211C', 'C234A', 'A248B']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): 0.04670524597167969
# --------------------------------------------------
# dm1: -8.501531600952148, dm2: -8.668160438537598
# dm12: -8.660888671875
# Mutations: ['B6C', 'D17A', 'C31A', 'A97B', 'A101B', 'D119B', 'D143C', 'B206A', 'C232A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): 0.007271766662597656
# --------------------------------------------------
# dm1: 8.512259483337402, dm2: 5.84114408493042
# dm12: 5.844601631164551
# Mutations: ['A11B', 'B25A', 'D39C', 'B45C', 'B84A', 'B94A', 'A101B', 'C124D', 'D138B', 'C140D', 'D148B', 'A163B', 'A188B', 'C194A', 'B201A', 'A222C', 'D230A']
# Mutation Count: 17
# Dm1m2-min(dm1,dm2): 0.0034575462341308594
# --------------------------------------------------
# dm1: -8.507057189941406, dm2: -8.875526428222656
# dm12: -8.873780250549316
# Mutations: ['A74C', 'A155C', 'A163C', 'D216A', 'C221A', 'C234A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): 0.0017461776733398438
# --------------------------------------------------

# %% [markdown]
# ## 3.5 Antagonistic interactions

# %%
# Define the mutations as input parameters
mutation1 = 'D148B'
mutation2 = 'C140D'

# Extract position and amino acid information from the mutations
pos1, old_aa1, new_aa1 = int(mutation1[1:-1]), mutation1[0], mutation1[-1]
pos2, old_aa2, new_aa2 = int(mutation2[1:-1]), mutation2[0], mutation2[-1]

# List to store sequences with sign change
sequences_with_sign_change = []

# Calculate delta E for the consensus sequence
de_mutation1_consensus = calculate_delta_e(pos1, old_aa1, new_aa1, consensus_sequence, J_dict)
de_mutation2_consensus = calculate_delta_e(pos2, old_aa2, new_aa2, consensus_sequence, J_dict)

print("-" * 50)
print(f'Consensus delta E for {mutation1}: {de_mutation1_consensus}, {mutation2}: {de_mutation2_consensus}')
print('Consensus dm12:', calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, consensus_sequence, J_dict))
print("-" * 50)

# Iterate through all sequences
for index, row in sequence_df.iterrows():
    sequence = row['Sequence']
    mutations = row['Mutations']
    mutation_count = row['Mutations_count']
    
    # Skip sequences without the specified mutations
    if mutation1 not in mutations or mutation2 not in mutations:
        # continue
        pass
    
    # Calculate delta E for the specified mutations
    de_mutation1 = calculate_delta_e(pos1, old_aa1, new_aa1, sequence, J_dict)
    de_mutation2 = calculate_delta_e(pos2, old_aa2, new_aa2, sequence, J_dict)
    dm12 = calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, sequence, J_dict)

    # Check for sign change
    if dm12 < de_mutation1 and dm12 < de_mutation2:
        min_dm1_dm2 = min(de_mutation1, de_mutation2)
        max_dm1_dm2 = max(de_mutation1, de_mutation2)
        max_divide_min_dm1_dm2 = max_dm1_dm2 / min_dm1_dm2
        
        sequences_with_sign_change.append({
            'Sequence': sequence,
            'Mutations': mutations,
            'Mutation_count': mutation_count,
            'dm1': de_mutation1,
            'dm2': de_mutation2,
            'dm12': dm12,
            'Dm1m2-max/min(dm1,dm2)': dm12 - max_divide_min_dm1_dm2,
            'Dm1m2-min(dm1,dm2)': dm12 - min_dm1_dm2
        })

# Create a DataFrame to store the results
sign_change_df = pd.DataFrame(sequences_with_sign_change)

# Sort the DataFrame by 'Dm1m2-min(dm1,dm2)' in descending order
sign_change_df = sign_change_df.sort_values(by='Dm1m2-min(dm1,dm2)', ascending=False)

# Print the results
for _, row in sign_change_df.iterrows():
    print(f"dm1: {row['dm1']}, dm2: {row['dm2']}")
    print(f"dm12: {row['dm12']}")
    print(f"Mutations: {row['Mutations']}")
    print(f"Mutation Count: {row['Mutation_count']}")
    print(f"Dm1m2-min(dm1,dm2): {row['Dm1m2-min(dm1,dm2)']}")
    print("-" * 50)
# Out:
# --------------------------------------------------
# Consensus delta E for D148B: -4.553504943847656, C140D: -5.7286787033081055
# Consensus dm12: -1.7733955
# --------------------------------------------------
# dm1: -5.939128875732422, dm2: -3.3114681243896484
# dm12: -5.946008682250977
# Mutations: ['A11B', 'B21C', 'B25A', 'D119A', 'C122B', 'D125A', 'D148C', 'A155C', 'B201A', 'A203B', 'D218C', 'C234D', 'D253A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -0.0068798065185546875
# --------------------------------------------------
# dm1: -8.522528648376465, dm2: -9.32710075378418
# dm12: -9.340819358825684
# Mutations: ['B60A', 'C113D', 'A151B', 'A155C', 'A163D', 'B182A', 'B201A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -0.013718605041503906
# --------------------------------------------------
# dm1: -8.522528648376465, dm2: -9.32710075378418
# dm12: -9.340819358825684
# Mutations: ['B60A', 'C113D', 'A151B', 'A155C', 'A163D', 'B182A', 'B201A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -0.013718605041503906
# --------------------------------------------------
# dm1: -8.664413452148438, dm2: -8.535841941833496
# dm12: -8.691452026367188
# Mutations: ['A11B', 'A14B', 'C31A', 'B84A', 'A97C', 'C113D', 'D119B', 'A151B', 'A155C', 'B157A', 'B201A', 'B206A', 'C208B', 'D218C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -0.02703857421875
# --------------------------------------------------
# dm1: -8.547926902770996, dm2: -9.304998397827148
# dm12: -9.34411907196045
# Mutations: ['B6C', 'B34A', 'A74C', 'A92D', 'C124A', 'A155C', 'A171C', 'B201A', 'D211C', 'D230A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -0.03912067413330078
# --------------------------------------------------
# dm1: -8.570919036865234, dm2: -9.578195571899414
# dm12: -9.640307426452637
# Mutations: ['A101B', 'B111D', 'B201A', 'B206A', 'D211C', 'C212A', 'D218A', 'C219B', 'D255A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -0.062111854553222656
# --------------------------------------------------
# dm1: -9.198379516601562, dm2: -8.590811729431152
# dm12: -9.280390739440918
# Mutations: ['C7D', 'D17A', 'A74B', 'A97B', 'A101B', 'B111A', 'D112B', 'D119B', 'D143A', 'B206A', 'D211C', 'D230C', 'B256A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -0.08201122283935547
# --------------------------------------------------
# dm1: -9.554149627685547, dm2: -8.615127563476562
# dm12: -9.660470008850098
# Mutations: ['C31A', 'A101B', 'D112B', 'C113D', 'A151B', 'A155C', 'C156A', 'B157A', 'B201A', 'D218C', 'D229C', 'D253A', 'B256A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -0.10632038116455078
# --------------------------------------------------
# dm1: 0.33304882049560547, dm2: -0.5704054832458496
# dm12: -0.6875629425048828
# Mutations: ['C10D', 'A14B', 'B79A', 'D125B', 'C140A', 'D148C', 'C156A', 'A163D', 'C208B', 'C232D', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -0.1171574592590332
# --------------------------------------------------
# dm1: 8.386585235595703, dm2: 4.7846221923828125
# dm12: 4.662410736083984
# Mutations: ['C15B', 'B16A', 'A72D', 'B88A', 'A101B', 'C122B', 'D125A', 'B135C', 'C140D', 'D148B', 'A181B', 'B201A', 'C234A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -0.12221145629882812
# --------------------------------------------------
# dm1: -8.641721725463867, dm2: -10.118675231933594
# dm12: -10.251593589782715
# Mutations: ['C10B', 'B21A', 'A92C', 'A151B', 'A155C']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): -0.1329183578491211
# --------------------------------------------------
# dm1: -0.5952792167663574, dm2: -1.305783748626709
# dm12: -1.4509220123291016
# Mutations: ['B6D', 'C7B', 'A14B', 'C31A', 'A54B', 'A72D', 'A74B', 'B79A', 'D119C', 'D138A', 'C140B', 'D148C', 'B157A', 'B201A', 'D218C']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -0.14513826370239258
# --------------------------------------------------
# dm1: -8.829741477966309, dm2: -8.65516471862793
# dm12: -8.976099967956543
# Mutations: ['A11B', 'D24C', 'C31A', 'A74B', 'A101B', 'D112A', 'D143C', 'B201A', 'D218A', 'C219B', 'C234D']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -0.14635848999023438
# --------------------------------------------------
# dm1: -8.959920883178711, dm2: -8.722884178161621
# dm12: -9.17400074005127
# Mutations: ['A11B', 'B25A', 'A28B', 'A37B', 'D39A', 'C50B', 'A74C', 'C124A', 'D138C', 'A151B', 'A155C', 'B157A', 'D160A', 'A203B', 'C208B', 'C232D', 'C234D', 'D253A', 'B254A']
# Mutation Count: 19
# Dm1m2-min(dm1,dm2): -0.2140798568725586
# --------------------------------------------------
# dm1: -8.744173049926758, dm2: -9.68178939819336
# dm12: -9.917162895202637
# Mutations: ['D17A', 'C31A', 'D39B', 'B84C', 'A101B', 'C113D', 'C124A', 'D125A', 'A151B', 'A155C', 'B157A', 'D160A', 'A163D', 'D211A', 'D230A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -0.23537349700927734
# --------------------------------------------------
# dm1: -8.759712219238281, dm2: -9.627180099487305
# dm12: -9.878090858459473
# Mutations: ['C10B', 'C31A', 'C50A', 'C68D', 'A73B', 'A74B', 'A92C', 'A96B', 'A97B', 'A101B', 'D119B', 'C124D', 'D125A', 'B135C', 'B157A', 'C208B', 'D230A', 'C232A', 'C234B', 'D253A', 'B256A']
# Mutation Count: 21
# Dm1m2-min(dm1,dm2): -0.25091075897216797
# --------------------------------------------------
# dm1: -8.768757820129395, dm2: -11.03836441040039
# dm12: -11.298317909240723
# Mutations: ['A14B', 'C15A', 'A32B', 'D39A', 'C50A', 'A92C', 'A101B', 'D119C', 'C124A', 'B135C', 'D136C', 'A155C', 'B157A', 'D160B', 'A162B', 'B201A', 'C234A', 'B240C']
# Mutation Count: 18
# Dm1m2-min(dm1,dm2): -0.25995349884033203
# --------------------------------------------------
# dm1: -9.438411712646484, dm2: -8.787951469421387
# dm12: -9.717558860778809
# Mutations: ['B6C', 'D17A', 'C50A', 'A72D', 'A74B', 'A97B', 'D119B', 'A151B', 'A155C', 'C156A', 'C208B', 'C212B']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -0.2791471481323242
# --------------------------------------------------
# dm1: -8.789226531982422, dm2: -8.91424560546875
# dm12: -9.19466495513916
# Mutations: ['A11B', 'D24C', 'A72D', 'A92C', 'B111D', 'C113D', 'A155C', 'B206A', 'D230A', 'B254C', 'D255B']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -0.28041934967041016
# --------------------------------------------------
# dm1: -1.0241765975952148, dm2: -0.7334551811218262
# dm12: -1.3074970245361328
# Mutations: ['A14B', 'D17A', 'B34A', 'C59A', 'D119C', 'C124D', 'D125A', 'C140B', 'D148C', 'B201A', 'D230A', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -0.28332042694091797
# --------------------------------------------------
# dm1: -8.835153579711914, dm2: -9.726334571838379
# dm12: -10.052682876586914
# Mutations: ['A11B', 'C31A', 'A97B', 'A101B', 'B111C', 'C113D', 'D119B', 'C124D', 'D125A', 'A151B', 'A155C', 'C195B', 'A196B', 'B205C', 'D218C', 'C232D']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): -0.32634830474853516
# --------------------------------------------------
# dm1: -8.840871810913086, dm2: -9.185052871704102
# dm12: -9.517119407653809
# Mutations: ['D17A', 'C50A', 'A101B', 'D119B', 'C124A', 'A151B', 'A155C', 'C156A', 'B157A', 'B201A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -0.33206653594970703
# --------------------------------------------------
# dm1: -8.888456344604492, dm2: -10.44000244140625
# dm12: -10.819653511047363
# Mutations: ['C10B', 'A11B', 'A28B', 'A30B', 'D39A', 'B49C', 'C69A', 'A101B', 'D119B', 'D143A', 'A155C', 'B201A', 'D211A', 'D218C', 'D230C']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -0.3796510696411133
# --------------------------------------------------
# dm1: -8.888456344604492, dm2: -10.44000244140625
# dm12: -10.819653511047363
# Mutations: ['C10B', 'A11B', 'A28B', 'A30B', 'D39A', 'B49C', 'C69A', 'A101B', 'D119B', 'D143A', 'A155C', 'B201A', 'D211A', 'D218C', 'D230C']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -0.3796510696411133
# --------------------------------------------------
# dm1: -0.8444404602050781, dm2: 0.05099201202392578
# dm12: -1.2436542510986328
# Mutations: ['A11B', 'D24C', 'B25A', 'C50A', 'B111C', 'C140A', 'D148C', 'A203B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -0.3992137908935547
# --------------------------------------------------
# dm1: 0.05045938491821289, dm2: -0.542022705078125
# dm12: -0.9417638778686523
# Mutations: ['A14B', 'A101B', 'D119C', 'C124A', 'D136A', 'D138B', 'C140A', 'A142C', 'D148C', 'A203B', 'C208B', 'D218C', 'B227A', 'C234D', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -0.39974117279052734
# --------------------------------------------------
# dm1: -8.961055755615234, dm2: -9.41682243347168
# dm12: -9.869078636169434
# Mutations: ['D17A', 'C68B', 'A74B', 'A101B', 'C124A', 'A151B', 'A155C', 'A163C', 'B201A', 'D218C', 'C220B', 'B227A', 'D253B', 'B256A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -0.4522562026977539
# --------------------------------------------------
# dm1: 8.048833847045898, dm2: 4.808035373687744
# dm12: 4.348071098327637
# Mutations: ['B25A', 'A30D', 'D39A', 'C124D', 'D125A', 'D138B', 'C140D', 'D148B', 'B201A', 'B206A', 'C220B', 'B251C']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -0.4599642753601074
# --------------------------------------------------
# dm1: -0.8230552673339844, dm2: -0.027882099151611328
# dm12: -1.3011398315429688
# Mutations: ['A11B', 'B111C', 'C124D', 'C140A', 'D148C', 'A167B']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): -0.4780845642089844
# --------------------------------------------------
# dm1: -9.47636604309082, dm2: -9.029587745666504
# dm12: -9.997147560119629
# Mutations: ['C7D', 'D17A', 'A101B', 'D119C', 'C122B', 'D143A', 'A155C', 'C156A', 'C165A', 'B201A', 'B206A', 'D218C', 'C219A', 'D230C', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -0.5207815170288086
# --------------------------------------------------
# dm1: -9.081378936767578, dm2: -9.441649436950684
# dm12: -10.014223098754883
# Mutations: ['C31A', 'C68D', 'A74B', 'A97B', 'A101B', 'D119B', 'D143C', 'A163D', 'A181B', 'B206A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -0.5725736618041992
# --------------------------------------------------
# dm1: 7.9302873611450195, dm2: 3.8570289611816406
# dm12: 3.2785158157348633
# Mutations: ['A72D', 'A101B', 'D138A', 'C140D', 'D148B', 'C194A', 'C220A', 'A222C', 'B227A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -0.5785131454467773
# --------------------------------------------------
# dm1: 7.9302873611450195, dm2: 3.8570289611816406
# dm12: 3.2785158157348633
# Mutations: ['A72D', 'A101B', 'D138A', 'C140D', 'D148B', 'C194A', 'C220A', 'A222C', 'B227A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -0.5785131454467773
# --------------------------------------------------
# dm1: 4.596401691436768, dm2: 0.7815651893615723
# dm12: 0.17376232147216797
# Mutations: ['D112A', 'C124A', 'D125A', 'D136A', 'D138A', 'C140D', 'D148C', 'C156A', 'A193D', 'B206A', 'C208A', 'C212B', 'D218C', 'C234D']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -0.6078028678894043
# --------------------------------------------------
# dm1: -0.2623887062072754, dm2: -2.056880474090576
# dm12: -2.7694692611694336
# Mutations: ['C10B', 'C31A', 'C50A', 'B79A', 'A101B', 'B111C', 'D119B', 'C124B', 'D125A', 'B135C', 'C140A', 'D148C', 'A203B', 'C208A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -0.7125887870788574
# --------------------------------------------------
# dm1: 4.4837517738342285, dm2: 0.6827316284179688
# dm12: -0.03771781921386719
# Mutations: ['B23D', 'A72D', 'C140D', 'D148C', 'D211B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): -0.7204494476318359
# --------------------------------------------------
# dm1: 7.772834300994873, dm2: 5.887333869934082
# dm12: 5.151376724243164
# Mutations: ['D17A', 'B20A', 'C31A', 'D39C', 'B45D', 'B63A', 'A101B', 'D112C', 'C124A', 'A139B', 'C140D', 'D148B', 'A181B', 'B201A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -0.735957145690918
# --------------------------------------------------
# dm1: -0.6105623245239258, dm2: -0.3231639862060547
# dm12: -1.3839311599731445
# Mutations: ['A14B', 'D24B', 'B25A', 'B45A', 'C113D', 'C124D', 'D125A', 'C140A', 'D148C', 'B157A', 'D160C', 'C220B', 'B227A', 'C234A', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -0.7733688354492188
# --------------------------------------------------
# dm1: -0.6105623245239258, dm2: -0.3231639862060547
# dm12: -1.3839311599731445
# Mutations: ['A14B', 'D24B', 'B25A', 'B45A', 'C113D', 'C124D', 'D125A', 'C140A', 'D148C', 'B157A', 'D160C', 'C220B', 'B227A', 'C234A', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -0.7733688354492188
# --------------------------------------------------
# dm1: -9.927176475524902, dm2: -9.305091857910156
# dm12: -10.723464012145996
# Mutations: ['D17A', 'C31A', 'C50A', 'D95C', 'A101B', 'D112A', 'D119B', 'A151B', 'A155C', 'C156A', 'B157A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -0.7962875366210938
# --------------------------------------------------
# dm1: -9.31478500366211, dm2: -10.492223739624023
# dm12: -11.298205375671387
# Mutations: ['A32B', 'B45C', 'A72D', 'A155C', 'B201A', 'B205A', 'B206A', 'C212B', 'C219B', 'C221D', 'A222C', 'D255A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -0.8059816360473633
# --------------------------------------------------
# dm1: -9.400376319885254, dm2: -9.38022518157959
# dm12: -10.271799087524414
# Mutations: ['C7D', 'D17A', 'A101B', 'D119C', 'C122B', 'D143A', 'A155C', 'C156A', 'C165A', 'B201A', 'B206A', 'D218C', 'C219A', 'D230C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -0.8714227676391602
# --------------------------------------------------
# dm1: 7.621895790100098, dm2: 5.696676731109619
# dm12: 4.80977725982666
# Mutations: ['D17A', 'B21A', 'B23D', 'C31A', 'B45D', 'A101B', 'C124A', 'D125A', 'D126B', 'C140D', 'D148B', 'A176B', 'D218C']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -0.886899471282959
# --------------------------------------------------
# dm1: -0.829096794128418, dm2: -0.48708534240722656
# dm12: -1.766387939453125
# Mutations: ['B6C', 'C10B', 'A11B', 'C31A', 'C140A', 'D148C', 'B201A', 'B206A', 'C234D']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -0.937291145324707
# --------------------------------------------------
# dm1: 4.221741199493408, dm2: 2.421787738800049
# dm12: 1.439321517944336
# Mutations: ['D17A', 'C31A', 'B63A', 'A74C', 'A101B', 'C140D', 'D148C', 'C156A', 'D216A', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -0.9824662208557129
# --------------------------------------------------
# dm1: -0.5383868217468262, dm2: -1.8176939487457275
# dm12: -2.806285858154297
# Mutations: ['A11B', 'C31A', 'B79A', 'D125B', 'C140A', 'D148C', 'B158C', 'C234A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -0.9885919094085693
# --------------------------------------------------
# dm1: 4.213357448577881, dm2: 0.6766114234924316
# dm12: -0.3142375946044922
# Mutations: ['D125B', 'C140D', 'D148C', 'C156A', 'C208B', 'B256A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): -0.9908490180969238
# --------------------------------------------------
# dm1: -9.509199142456055, dm2: -10.181373596191406
# dm12: -11.18176555633545
# Mutations: ['D17A', 'A28B', 'A72D', 'B90C', 'D119B', 'A151B', 'A155C', 'B157A', 'D160B', 'C232A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -1.000391960144043
# --------------------------------------------------
# dm1: 4.134073734283447, dm2: 1.713663101196289
# dm12: 0.6435213088989258
# Mutations: ['A14B', 'C31A', 'B45A', 'A72D', 'C140D', 'D148C', 'D160C', 'A163D', 'A167B', 'B206A', 'D218C', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -1.0701417922973633
# --------------------------------------------------
# dm1: 7.404366493225098, dm2: 2.9429478645324707
# dm12: 1.838515281677246
# Mutations: ['D17A', 'C124D', 'D125A', 'D138A', 'C140D', 'D148B', 'A154C', 'C165A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -1.1044325828552246
# --------------------------------------------------
# dm1: 4.093292236328125, dm2: 0.5420513153076172
# dm12: -0.5688591003417969
# Mutations: ['A72D', 'C140D', 'D148C', 'C156A', 'A167B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): -1.110910415649414
# --------------------------------------------------
# dm1: 7.381657123565674, dm2: 5.055148601531982
# dm12: 3.928007125854492
# Mutations: ['C7A', 'A11B', 'C31A', 'C50B', 'A72D', 'A101B', 'C124A', 'B135C', 'C140D', 'D148B', 'B200A', 'B201A', 'C220B']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -1.1271414756774902
# --------------------------------------------------
# dm1: 7.380748271942139, dm2: 4.624989032745361
# dm12: 3.496941566467285
# Mutations: ['B23D', 'C31A', 'C50B', 'B91D', 'A93C', 'A101B', 'D138C', 'C140D', 'D148B', 'D218C', 'C232D']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -1.1280474662780762
# --------------------------------------------------
# dm1: 7.376908779144287, dm2: 3.708045482635498
# dm12: 2.5761680603027344
# Mutations: ['C124A', 'D138B', 'C140D', 'D148B', 'A154C', 'A193C', 'B201A', 'C208A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -1.1318774223327637
# --------------------------------------------------
# dm1: -9.680274963378906, dm2: -10.500907897949219
# dm12: -11.672385215759277
# Mutations: ['C10B', 'C31A', 'C50A', 'C68D', 'A73B', 'A74B', 'A92C', 'A96B', 'A97B', 'A101B', 'D119B', 'C124D', 'D125A', 'B135C', 'B157A', 'D160A', 'C208B', 'D230A', 'C232A', 'C234B', 'D253A', 'B256A']
# Mutation Count: 22
# Dm1m2-min(dm1,dm2): -1.1714773178100586
# --------------------------------------------------
# dm1: 4.013218879699707, dm2: 0.6464385986328125
# dm12: -0.5445461273193359
# Mutations: ['B6D', 'C7B', 'D17A', 'A72D', 'C140D', 'D148C', 'B201A', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -1.1909847259521484
# --------------------------------------------------
# dm1: 7.312935829162598, dm2: 5.066825866699219
# dm12: 3.8709659576416016
# Mutations: ['C31A', 'A72D', 'A101B', 'D112C', 'C122A', 'C124A', 'B135C', 'C140D', 'D148B', 'B201A', 'D218B', 'A225B', 'B251C']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -1.1958599090576172
# --------------------------------------------------
# dm1: -9.721712112426758, dm2: -10.030927658081055
# dm12: -11.24383544921875
# Mutations: ['D17A', 'A101B', 'B111D', 'D112C', 'D119B', 'C123B', 'C124D', 'A151B', 'A155C', 'C156A', 'B157A', 'B177C', 'B256A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -1.2129077911376953
# --------------------------------------------------
# dm1: 7.2864274978637695, dm2: 5.972302436828613
# dm12: 4.749942779541016
# Mutations: ['A11B', 'D24C', 'B34A', 'B84C', 'B91C', 'A101B', 'D125B', 'C140D', 'D148B', 'A161D', 'B201A', 'D230A', 'B260A', 'B261A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -1.2223596572875977
# --------------------------------------------------
# dm1: -9.748791694641113, dm2: -9.732709884643555
# dm12: -10.972701072692871
# Mutations: ['B20A', 'C50A', 'A92C', 'C124A', 'A155C', 'B157A', 'D160A', 'A193C', 'B201A', 'D218C', 'C220D', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -1.2239093780517578
# --------------------------------------------------
# dm1: 7.272566318511963, dm2: 2.6624679565429688
# dm12: 1.4262428283691406
# Mutations: ['A11B', 'A14B', 'A32B', 'D39A', 'B88A', 'A101B', 'A103B', 'D119A', 'C122B', 'D125A', 'D138A', 'C140D', 'D148B', 'B200C', 'B201A', 'B206A']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): -1.2362251281738281
# --------------------------------------------------
# dm1: -9.747254371643066, dm2: -9.97402572631836
# dm12: -11.212475776672363
# Mutations: ['C50A', 'A74C', 'A101B', 'C124B', 'B135C', 'A151B', 'A155C', 'B157A', 'D160A', 'A181B', 'B201A', 'B206A', 'D218C', 'C220B', 'B227A', 'D253B']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): -1.238450050354004
# --------------------------------------------------
# dm1: 7.259446144104004, dm2: 4.773435592651367
# dm12: 3.52408504486084
# Mutations: ['C31A', 'C50A', 'D138A', 'C140D', 'D148B', 'A188B', 'B201A', 'B206A', 'C215D', 'D230B']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -1.2493505477905273
# --------------------------------------------------
# dm1: -9.75868034362793, dm2: -11.13145637512207
# dm12: -12.381336212158203
# Mutations: ['D17A', 'C50A', 'A101B', 'D112B', 'C124D', 'D143A', 'A155C', 'A163C', 'B169A', 'B201A', 'B206A', 'C220B', 'C221D', 'D230C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -1.2498798370361328
# --------------------------------------------------
# dm1: 3.938589096069336, dm2: 0.007540702819824219
# dm12: -1.2580718994140625
# Mutations: ['A101B', 'C140D', 'D148C', 'C156A', 'C208A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): -1.2656126022338867
# --------------------------------------------------
# dm1: 7.2354817390441895, dm2: 4.9601263999938965
# dm12: 3.686807632446289
# Mutations: ['B20A', 'C31A', 'C50A', 'A72D', 'B84D', 'A101B', 'D119C', 'C122B', 'C140D', 'D148B', 'A163B', 'B201A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -1.2733187675476074
# --------------------------------------------------
# dm1: 3.872007369995117, dm2: 3.4211082458496094
# dm12: 2.088916778564453
# Mutations: ['B63C', 'A72D', 'A74C', 'C124A', 'C140D', 'D148C', 'C156A', 'A163D', 'B182A', 'B201A', 'B254C', 'C259A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -1.3321914672851562
# --------------------------------------------------
# dm1: 3.831883430480957, dm2: 0.8402466773986816
# dm12: -0.5320816040039062
# Mutations: ['C31A', 'C50A', 'A101B', 'C124D', 'C140D', 'D148C', 'A167B', 'B206A', 'B227A', 'D230A', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -1.372328281402588
# --------------------------------------------------
# dm1: 7.1119465827941895, dm2: 5.517501354217529
# dm12: 4.120649337768555
# Mutations: ['B63A', 'B70C', 'A101B', 'D125A', 'C140D', 'D148B', 'A181B', 'B201A', 'C208A', 'D218C']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -1.3968520164489746
# --------------------------------------------------
# dm1: 3.7660293579101562, dm2: 0.12073040008544922
# dm12: -1.3174400329589844
# Mutations: ['A3B', 'A101B', 'C140D', 'D148C', 'C156A', 'C208A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): -1.4381704330444336
# --------------------------------------------------
# dm1: 3.754579544067383, dm2: 0.46306800842285156
# dm12: -0.9865531921386719
# Mutations: ['A11B', 'D24C', 'A101B', 'D112A', 'D125A', 'C140D', 'D148C', 'C156A', 'A163C']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -1.4496212005615234
# --------------------------------------------------
# dm1: 7.057741641998291, dm2: 4.021564483642578
# dm12: 2.5705080032348633
# Mutations: ['C50A', 'C113D', 'C124D', 'D125A', 'D138B', 'C140D', 'D148B', 'A154B', 'A167B', 'B201A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -1.4510564804077148
# --------------------------------------------------
# dm1: 7.057741641998291, dm2: 4.021564483642578
# dm12: 2.5705080032348633
# Mutations: ['C50A', 'C113D', 'C124D', 'D125A', 'D138B', 'C140D', 'D148B', 'A154B', 'A167B', 'B201A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -1.4510564804077148
# --------------------------------------------------
# dm1: 7.057741641998291, dm2: 4.021564483642578
# dm12: 2.5705080032348633
# Mutations: ['C50A', 'C113D', 'C124D', 'D125A', 'D138B', 'C140D', 'D148B', 'A154B', 'A167B', 'B201A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -1.4510564804077148
# --------------------------------------------------
# dm1: 7.0526533126831055, dm2: 3.4124059677124023
# dm12: 1.9562644958496094
# Mutations: ['C10B', 'C31A', 'B49C', 'A72D', 'D112A', 'C124A', 'D138A', 'C140D', 'D148B', 'C156A', 'C165A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -1.456141471862793
# --------------------------------------------------
# dm1: 3.738528251647949, dm2: 1.9075250625610352
# dm12: 0.44185638427734375
# Mutations: ['D17A', 'C31A', 'B106A', 'D125A', 'D126A', 'C140D', 'D148C', 'C156A', 'A163B', 'B173A', 'B201A', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -1.4656686782836914
# --------------------------------------------------
# dm1: 7.041610240936279, dm2: 3.7570719718933105
# dm12: 2.289891242980957
# Mutations: ['D39A', 'A101B', 'D136C', 'D138A', 'C140D', 'D148B', 'A154C', 'A167B', 'B201A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -1.4671807289123535
# --------------------------------------------------
# dm1: -10.000349998474121, dm2: -10.000706672668457
# dm12: -11.4922456741333
# Mutations: ['C31A', 'A101B', 'D112B', 'D119B', 'C124A', 'D143A', 'A155C', 'B157A', 'D160B', 'B201A', 'D230C']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -1.4915390014648438
# --------------------------------------------------
# dm1: 6.944697856903076, dm2: 3.3013010025024414
# dm12: 1.737203598022461
# Mutations: ['A11B', 'C31A', 'D119B', 'C123B', 'C124D', 'D138A', 'C140D', 'D148B', 'C156A', 'D218B', 'C234D', 'B254D']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -1.5640974044799805
# --------------------------------------------------
# dm1: 6.894342422485352, dm2: 4.271142959594727
# dm12: 2.656683921813965
# Mutations: ['B6D', 'C7B', 'C31A', 'A72D', 'D138A', 'C140D', 'D148B', 'A163B', 'C234A', 'D253A', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -1.6144590377807617
# --------------------------------------------------
# dm1: 6.887374401092529, dm2: 6.833991527557373
# dm12: 5.212568283081055
# Mutations: ['A11B', 'A13B', 'B20A', 'B25A', 'C31A', 'D112A', 'C124A', 'D125A', 'C140D', 'D148B', 'B201A', 'B205A', 'C208B', 'C215B', 'B231A', 'B254D', 'D255B', 'C258B']
# Mutation Count: 18
# Dm1m2-min(dm1,dm2): -1.6214232444763184
# --------------------------------------------------
# dm1: 6.872113227844238, dm2: 2.8647923469543457
# dm12: 1.2281150817871094
# Mutations: ['D17A', 'A101B', 'C124A', 'D138B', 'C140D', 'D148B', 'C165A', 'B201A', 'D211C', 'C219A', 'A222C', 'D230A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -1.6366772651672363
# --------------------------------------------------
# dm1: 6.8455681800842285, dm2: 3.2833690643310547
# dm12: 1.6201448440551758
# Mutations: ['A14B', 'C31A', 'D39A', 'C50A', 'A101B', 'C124A', 'D138A', 'C140D', 'D148B', 'A154C', 'B201A', 'D211B', 'D230A', 'C234D', 'D253A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -1.663224220275879
# --------------------------------------------------
# dm1: 6.834969997406006, dm2: 4.543173313140869
# dm12: 2.8693437576293945
# Mutations: ['A11B', 'D24C', 'A41C', 'A72D', 'D112A', 'D119C', 'D138B', 'C140D', 'D148B']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -1.6738295555114746
# --------------------------------------------------
# dm1: -10.222626686096191, dm2: -12.042112350463867
# dm12: -13.755936622619629
# Mutations: ['B12A', 'A14B', 'B21A', 'B23C', 'C31A', 'A92C', 'A101B', 'C124A', 'A151B', 'A155C', 'B204A', 'C215B']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -1.7138242721557617
# --------------------------------------------------
# dm1: 3.481790065765381, dm2: 1.3830833435058594
# dm12: -0.3393268585205078
# Mutations: ['A72D', 'A74B', 'A100B', 'A101B', 'B111C', 'D119C', 'C124A', 'D125A', 'C140D', 'D148C', 'B157A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -1.7224102020263672
# --------------------------------------------------
# dm1: 6.749110698699951, dm2: 4.0446367263793945
# dm12: 2.2849578857421875
# Mutations: ['B20A', 'C31A', 'C99A', 'A101B', 'C122B', 'C124A', 'D125A', 'C140D', 'D148B', 'A163D', 'B201A', 'C234D']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -1.759678840637207
# --------------------------------------------------
# dm1: 3.4415369033813477, dm2: 2.172311305999756
# dm12: 0.4096508026123047
# Mutations: ['A11B', 'A28B', 'A37B', 'A72D', 'A74C', 'A101B', 'D112B', 'D119C', 'C122B', 'C124A', 'D125A', 'C140D', 'D148C', 'A167B', 'D211B', 'C234A']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): -1.7626605033874512
# --------------------------------------------------
# dm1: 6.737041473388672, dm2: 5.037822246551514
# dm12: 3.2660789489746094
# Mutations: ['B23D', 'D125A', 'C140D', 'D148B', 'A154C', 'B169C', 'B187A', 'A188B', 'B201A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -1.7717432975769043
# --------------------------------------------------
# dm1: 6.696420669555664, dm2: 1.6971969604492188
# dm12: -0.11516761779785156
# Mutations: ['C10B', 'B20A', 'C50A', 'A72D', 'A101B', 'D119A', 'C122B', 'D125A', 'C140D', 'D148B', 'A181B', 'D211C', 'C221D', 'A222C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -1.8123645782470703
# --------------------------------------------------
# dm1: 6.572693824768066, dm2: 1.7504539489746094
# dm12: -0.1856403350830078
# Mutations: ['C10B', 'B20A', 'A32B', 'C50A', 'A72D', 'A101B', 'D119A', 'C122B', 'D125A', 'C140D', 'D148B', 'A181B', 'D211C', 'C221D', 'A222C']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -1.9360942840576172
# --------------------------------------------------
# dm1: 6.572693824768066, dm2: 1.7504539489746094
# dm12: -0.1856403350830078
# Mutations: ['C10B', 'B20A', 'A32B', 'C50A', 'A72D', 'A101B', 'D119A', 'C122B', 'D125A', 'C140D', 'D148B', 'A181B', 'D211C', 'C221D', 'A222C']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -1.9360942840576172
# --------------------------------------------------
# dm1: 6.507983207702637, dm2: 2.746795654296875
# dm12: 0.7459850311279297
# Mutations: ['D17A', 'B25A', 'B84D', 'A101B', 'C124B', 'D125B', 'B135C', 'C140D', 'D148B', 'A154C']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -2.0008106231689453
# --------------------------------------------------
# dm1: 6.458237648010254, dm2: 4.105785369873047
# dm12: 2.055222511291504
# Mutations: ['B6A', 'C7B', 'D17A', 'C31A', 'A101B', 'D125A', 'D138B', 'C140D', 'D148B', 'C156A', 'A203B', 'C221B', 'A222C', 'B256A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -2.050562858581543
# --------------------------------------------------
# dm1: 3.1109213829040527, dm2: 0.3801693916320801
# dm12: -1.7131242752075195
# Mutations: ['A14B', 'C31A', 'A74C', 'B111C', 'C140D', 'D148C', 'B206A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -2.0932936668395996
# --------------------------------------------------
# dm1: 6.397902488708496, dm2: 5.5087385177612305
# dm12: 3.397846221923828
# Mutations: ['A30C', 'D39B', 'A72D', 'A101B', 'D112A', 'D119C', 'C140D', 'D148B', 'B150A', 'C165A', 'A167B', 'A171B', 'B201A', 'C220A', 'A222C', 'C232D']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): -2.1108922958374023
# --------------------------------------------------
# dm1: 6.395758152008057, dm2: 4.26987361907959
# dm12: 2.1568374633789062
# Mutations: ['D17A', 'A87B', 'C124D', 'D125A', 'C140D', 'D148B', 'A154C']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -2.1130361557006836
# --------------------------------------------------
# dm1: 6.37412691116333, dm2: 3.386129856109619
# dm12: 1.2514724731445312
# Mutations: ['A72D', 'C99A', 'C124D', 'C140D', 'D148B', 'A154C', 'B187A', 'B201A', 'D211C', 'D230A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -2.134657382965088
# --------------------------------------------------
# dm1: 6.355861663818359, dm2: 5.778877258300781
# dm12: 3.625947952270508
# Mutations: ['D17A', 'A72D', 'A101B', 'C124D', 'D125A', 'C140D', 'D148B', 'A167B', 'B173A', 'A179B', 'A193B', 'C195B', 'C220B', 'B227A', 'D255C', 'B256A']
# Mutation Count: 16
# Dm1m2-min(dm1,dm2): -2.1529293060302734
# --------------------------------------------------
# dm1: 6.3442864418029785, dm2: 3.8535141944885254
# dm12: 1.689000129699707
# Mutations: ['A11B', 'B20A', 'B25A', 'C31A', 'A32B', 'A41C', 'B111C', 'D125A', 'D126C', 'B135C', 'C140D', 'D148B', 'B201A', 'D218C']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -2.1645140647888184
# --------------------------------------------------
# dm1: 6.32704496383667, dm2: 4.632238864898682
# dm12: 2.4504947662353516
# Mutations: ['D17A', 'A87B', 'D112A', 'C124D', 'D125A', 'C140D', 'D148B', 'A154C']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -2.18174409866333
# --------------------------------------------------
# dm1: 6.273047924041748, dm2: 5.071123123168945
# dm12: 2.835378646850586
# Mutations: ['B6C', 'D17A', 'B20A', 'D22C', 'A28C', 'A35B', 'D39B', 'A101B', 'D125A', 'D136C', 'C140D', 'D148B', 'B200A', 'B201A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -2.2357444763183594
# --------------------------------------------------
# dm1: 2.9650702476501465, dm2: 0.3571038246154785
# dm12: -1.8820381164550781
# Mutations: ['A11B', 'A32B', 'A37B', 'A101B', 'C140D', 'D148C', 'B201A', 'C232A', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -2.2391419410705566
# --------------------------------------------------
# dm1: 2.473680019378662, dm2: 2.933206081390381
# dm12: 0.20267486572265625
# Mutations: ['D17A', 'A74C', 'B84A', 'D112B', 'C140D', 'D148C', 'B157A', 'D160B', 'B201A', 'B205A', 'B256A', 'C259A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -2.271005153656006
# --------------------------------------------------
# dm1: 6.211887836456299, dm2: 5.0582451820373535
# dm12: 2.761333465576172
# Mutations: ['D17A', 'B20A', 'A28B', 'D39A', 'B45D', 'C113D', 'C124D', 'D125A', 'C140D', 'D148B', 'A163C', 'B201A', 'C259A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -2.2969117164611816
# --------------------------------------------------
# dm1: 6.210565090179443, dm2: 3.534212112426758
# dm12: 1.2359790802001953
# Mutations: ['A14B', 'D17B', 'C50A', 'A72D', 'D125A', 'B135C', 'C140D', 'D148B', 'A154C', 'B206A', 'C219A', 'A222C']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -2.2982330322265625
# --------------------------------------------------
# dm1: 6.178462982177734, dm2: 5.4107255935668945
# dm12: 3.0803966522216797
# Mutations: ['B20A', 'C31A', 'C50B', 'A101B', 'D136B', 'C140D', 'D148B', 'C208A', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -2.330328941345215
# --------------------------------------------------
# dm1: 6.06456995010376, dm2: 4.174564361572266
# dm12: 1.7303390502929688
# Mutations: ['B6C', 'A14B', 'B21A', 'B23D', 'D24B', 'B25A', 'D39A', 'B45D', 'A101B', 'C140D', 'D148B', 'B201A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -2.444225311279297
# --------------------------------------------------
# dm1: 6.062260627746582, dm2: 4.319445610046387
# dm12: 1.8729114532470703
# Mutations: ['D17A', 'B20A', 'A28B', 'D39A', 'B70D', 'C124A', 'D125A', 'C140D', 'D148B', 'A163D', 'B201A', 'C208A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -2.4465341567993164
# --------------------------------------------------
# dm1: 6.046935081481934, dm2: 4.540170669555664
# dm12: 2.0783138275146484
# Mutations: ['A72D', 'A101B', 'D119C', 'D125A', 'D126B', 'C140D', 'D148B', 'A193B', 'B201A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -2.4618568420410156
# --------------------------------------------------
# dm1: 5.9961934089660645, dm2: 3.5637693405151367
# dm12: 1.051161766052246
# Mutations: ['A11B', 'D24C', 'C31A', 'A74C', 'D119B', 'C123B', 'C124D', 'D138A', 'C140D', 'D148B', 'C156A', 'D218B', 'C234D']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -2.5126075744628906
# --------------------------------------------------
# dm1: 5.995186805725098, dm2: 3.3408684730529785
# dm12: 0.8272533416748047
# Mutations: ['C31A', 'D39C', 'A101B', 'C124D', 'C140D', 'D148B', 'C208A', 'C215B', 'D218B', 'A222C']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -2.513615131378174
# --------------------------------------------------
# dm1: 5.960747718811035, dm2: 4.0085978507995605
# dm12: 1.4605464935302734
# Mutations: ['D17A', 'B20A', 'A28B', 'D39A', 'B45D', 'C113A', 'C124D', 'D125A', 'C140D', 'D148B', 'A163C', 'B201A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -2.548051357269287
# --------------------------------------------------
# dm1: 5.93370246887207, dm2: 4.08217191696167
# dm12: 1.5070781707763672
# Mutations: ['B6A', 'C7A', 'A32B', 'B45D', 'A101B', 'D125A', 'B135C', 'C140D', 'D148B']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -2.5750937461853027
# --------------------------------------------------
# dm1: 5.9170355796813965, dm2: 4.318560600280762
# dm12: 1.726806640625
# Mutations: ['B25A', 'A30D', 'D39A', 'C124D', 'D125A', 'C140D', 'D148B', 'B201A', 'B206A', 'C220B', 'B251C']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -2.5917539596557617
# --------------------------------------------------
# dm1: 5.9170355796813965, dm2: 4.318560600280762
# dm12: 1.726806640625
# Mutations: ['B25A', 'A30D', 'D39A', 'C124D', 'D125A', 'C140D', 'D148B', 'B201A', 'B206A', 'C220B', 'B251C']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -2.5917539596557617
# --------------------------------------------------
# dm1: 5.8951239585876465, dm2: 5.8922038078308105
# dm12: 3.2785263061523438
# Mutations: ['A11B', 'A13B', 'C31A', 'C50A', 'C57A', 'B63A', 'D119C', 'C122B', 'C124A', 'C140D', 'D148B', 'B206A', 'D255C', 'B256A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -2.613677501678467
# --------------------------------------------------
# dm1: 5.865355014801025, dm2: 3.872373104095459
# dm12: 1.2289276123046875
# Mutations: ['D17A', 'C50B', 'A101B', 'B111A', 'C113D', 'C124A', 'D125A', 'C140D', 'D148B', 'D218C']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -2.6434454917907715
# --------------------------------------------------
# dm1: 5.856884956359863, dm2: 4.0723347663879395
# dm12: 1.4204216003417969
# Mutations: ['A11B', 'D24C', 'B25A', 'C31A', 'A72D', 'A101B', 'D119C', 'C122B', 'C124A', 'C140D', 'D148B', 'A154C', 'C165A', 'D218C', 'D253A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -2.6519131660461426
# --------------------------------------------------
# dm1: 5.836109161376953, dm2: 4.714852809906006
# dm12: 2.042163848876953
# Mutations: ['C10B', 'A32B', 'B45D', 'A101B', 'D125A', 'C140D', 'D148B', 'A163C', 'B227A', 'D253C', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -2.6726889610290527
# --------------------------------------------------
# dm1: 5.796777725219727, dm2: 3.4612255096435547
# dm12: 0.74920654296875
# Mutations: ['A101B', 'D119B', 'D138B', 'C140D', 'D143B', 'D148B', 'C156A', 'C208A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -2.7120189666748047
# --------------------------------------------------
# dm1: 5.796777725219727, dm2: 3.4612255096435547
# dm12: 0.74920654296875
# Mutations: ['A101B', 'D119B', 'D138B', 'C140D', 'D143B', 'D148B', 'C156A', 'C208A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -2.7120189666748047
# --------------------------------------------------
# dm1: 5.796633720397949, dm2: 3.687835693359375
# dm12: 0.9756717681884766
# Mutations: ['C7D', 'D17A', 'A72D', 'A101B', 'D125B', 'C140D', 'D148B', 'C220B', 'A224B', 'C234D']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -2.7121639251708984
# --------------------------------------------------
# dm1: 5.760533332824707, dm2: 5.542263031005859
# dm12: 2.794008255004883
# Mutations: ['C31A', 'B63A', 'B70A', 'A101B', 'D119B', 'C122B', 'D125A', 'C140D', 'D148B', 'D160C', 'B201A', 'B205A', 'C234D']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -2.7482547760009766
# --------------------------------------------------
# dm1: 5.757429122924805, dm2: 4.379219055175781
# dm12: 1.6278514862060547
# Mutations: ['C31A', 'B111C', 'D119A', 'C122B', 'D125A', 'C140D', 'D148B', 'B201A', 'D211C', 'A242B', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -2.7513675689697266
# --------------------------------------------------
# dm1: 5.757331848144531, dm2: 3.1572580337524414
# dm12: 0.4057941436767578
# Mutations: ['B6C', 'C10B', 'B25A', 'C31A', 'D39B', 'A72D', 'A101B', 'C122B', 'C124A', 'C140D', 'D148B', 'C219A', 'A222C']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -2.7514638900756836
# --------------------------------------------------
# dm1: 5.740303039550781, dm2: 3.8977441787719727
# dm12: 1.1292476654052734
# Mutations: ['C10B', 'A11B', 'B21C', 'C50A', 'A72D', 'C113A', 'D119C', 'C122B', 'D125A', 'C140D', 'D148B', 'C234D', 'D253A', 'B256A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -2.768496513366699
# --------------------------------------------------
# dm1: 5.740303039550781, dm2: 3.8977441787719727
# dm12: 1.1292476654052734
# Mutations: ['C10B', 'A11B', 'B21C', 'C50A', 'A72D', 'C113A', 'D119C', 'C122B', 'D125A', 'C140D', 'D148B', 'C234D', 'D253A', 'B256A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -2.768496513366699
# --------------------------------------------------
# dm1: 5.740303039550781, dm2: 3.8977441787719727
# dm12: 1.1292476654052734
# Mutations: ['C10B', 'A11B', 'B21C', 'C50A', 'A72D', 'C113A', 'D119C', 'C122B', 'D125A', 'C140D', 'D148B', 'C234D', 'D253A', 'B256A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -2.768496513366699
# --------------------------------------------------
# dm1: 5.734970569610596, dm2: 4.853659629821777
# dm12: 2.079833984375
# Mutations: ['C7A', 'D17A', 'C31A', 'A72D', 'D119C', 'C122B', 'C124A', 'D125A', 'D126A', 'C140D', 'D148B', 'C165A', 'B201A', 'D216A', 'B256A']
# Mutation Count: 15
# Dm1m2-min(dm1,dm2): -2.7738256454467773
# --------------------------------------------------
# dm1: 5.7208099365234375, dm2: 5.0442914962768555
# dm12: 2.2563095092773438
# Mutations: ['B20A', 'C50A', 'B88A', 'A101B', 'D112B', 'D136B', 'C140D', 'D148B', 'A176B']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -2.7879819869995117
# --------------------------------------------------
# dm1: 5.718045711517334, dm2: 3.5782299041748047
# dm12: 0.7874774932861328
# Mutations: ['D17A', 'B45A', 'A101B', 'C124A', 'D125A', 'D138B', 'C140D', 'D148B', 'B157A', 'D160B', 'A163C', 'C165A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -2.790752410888672
# --------------------------------------------------
# dm1: 5.71750545501709, dm2: 3.435762882232666
# dm12: 0.6444778442382812
# Mutations: ['C10B', 'C31A', 'A72D', 'A101B', 'C122B', 'C124A', 'C140D', 'D148B', 'B201A', 'C220B', 'B227A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -2.7912850379943848
# --------------------------------------------------
# dm1: 5.706632137298584, dm2: 4.2254791259765625
# dm12: 1.423309326171875
# Mutations: ['C7A', 'B63C', 'D119C', 'C122B', 'C124A', 'D125A', 'C140D', 'D148B', 'C219A', 'A222C']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -2.8021697998046875
# --------------------------------------------------
# dm1: 5.65236759185791, dm2: 5.432234287261963
# dm12: 2.575807571411133
# Mutations: ['A14B', 'B20A', 'C31A', 'A101B', 'C124A', 'C140D', 'D148B', 'A193B', 'B201A', 'D211B', 'D218B', 'B231A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -2.85642671585083
# --------------------------------------------------
# dm1: 5.621337413787842, dm2: 5.611422538757324
# dm12: 2.7239646911621094
# Mutations: ['A11B', 'C31A', 'B63A', 'A101B', 'D112B', 'C140D', 'D148B', 'A193C', 'B201A', 'B254D']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -2.887457847595215
# --------------------------------------------------
# dm1: 5.612435340881348, dm2: 4.673677444458008
# dm12: 1.7773113250732422
# Mutations: ['C50A', 'A72D', 'D119C', 'C122B', 'C124A', 'D125B', 'C140D', 'D148B', 'A163B', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -2.8963661193847656
# --------------------------------------------------
# dm1: 5.612435340881348, dm2: 4.673677444458008
# dm12: 1.7773113250732422
# Mutations: ['C50A', 'A72D', 'D119C', 'C122B', 'C124A', 'D125B', 'C140D', 'D148B', 'A163B', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -2.8963661193847656
# --------------------------------------------------
# dm1: 5.612435340881348, dm2: 4.673677444458008
# dm12: 1.7773113250732422
# Mutations: ['C50A', 'A72D', 'D119C', 'C122B', 'C124A', 'D125B', 'C140D', 'D148B', 'A163B', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -2.8963661193847656
# --------------------------------------------------
# dm1: 5.608996391296387, dm2: 4.109317302703857
# dm12: 1.2095146179199219
# Mutations: ['B63A', 'C124D', 'C140D', 'D148B', 'D218B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): -2.8998026847839355
# --------------------------------------------------
# dm1: 5.568572044372559, dm2: 3.8725361824035645
# dm12: 0.9323177337646484
# Mutations: ['D17A', 'D24A', 'A28B', 'B45D', 'A72D', 'C124A', 'C140D', 'D148B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -2.940218448638916
# --------------------------------------------------
# dm1: 5.5609002113342285, dm2: 2.764742374420166
# dm12: -0.1831512451171875
# Mutations: ['C7A', 'A101B', 'C124D', 'B135C', 'C140D', 'D148B', 'A181B', 'B201A', 'B206A', 'C219A', 'A222C']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -2.9478936195373535
# --------------------------------------------------
# dm1: 5.200390815734863, dm2: 5.558464050292969
# dm12: 2.2500553131103516
# Mutations: ['D17A', 'A32B', 'A74C', 'C124A', 'D125B', 'D136B', 'C140D', 'D148B', 'C165A', 'B201A', 'C234A', 'B256A', 'C259A']
# Mutation Count: 13
# Dm1m2-min(dm1,dm2): -2.9503355026245117
# --------------------------------------------------
# dm1: 5.499889850616455, dm2: 3.9730138778686523
# dm12: 0.9641094207763672
# Mutations: ['C7A', 'A11B', 'C31A', 'C113D', 'C124D', 'D125A', 'C140D', 'D148B', 'A193C', 'D218B', 'D230A', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -3.008904457092285
# --------------------------------------------------
# dm1: 5.4897685050964355, dm2: 1.630793571472168
# dm12: -1.3882369995117188
# Mutations: ['B23D', 'B84C', 'D119A', 'C122B', 'D125A', 'C140D', 'D148B', 'B201A', 'C215B', 'C221D', 'A222C', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -3.0190305709838867
# --------------------------------------------------
# dm1: 5.462691307067871, dm2: 4.558107852935791
# dm12: 1.5120010375976562
# Mutations: ['C31A', 'A72D', 'A101B', 'B111C', 'D119C', 'C122B', 'C140D', 'D148B', 'B180A', 'B201A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -3.0461068153381348
# --------------------------------------------------
# dm1: 5.447834491729736, dm2: 2.3568029403686523
# dm12: -0.7041473388671875
# Mutations: ['D17A', 'A28B', 'A72D', 'C124A', 'D125A', 'D126C', 'C140D', 'B141A', 'D148B']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -3.06095027923584
# --------------------------------------------------
# dm1: 5.440762996673584, dm2: 3.428986072540283
# dm12: 0.36095237731933594
# Mutations: ['D17A', 'C50A', 'A72D', 'C113D', 'C124A', 'D125A', 'C140D', 'D148B', 'B201A', 'C220B', 'B227A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -3.0680336952209473
# --------------------------------------------------
# dm1: 5.439675807952881, dm2: 4.552812099456787
# dm12: 1.4836902618408203
# Mutations: ['A14B', 'B63A', 'A101B', 'D112A', 'C140D', 'D148B', 'A193C']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -3.069121837615967
# --------------------------------------------------
# dm1: 5.42790412902832, dm2: 3.2088398933410645
# dm12: 0.1279468536376953
# Mutations: ['A13B', 'A14B', 'C124D', 'C140D', 'D148B', 'A154C', 'B201A', 'D211C', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -3.080893039703369
# --------------------------------------------------
# dm1: 5.419378757476807, dm2: 3.9515676498413086
# dm12: 0.8621482849121094
# Mutations: ['D24B', 'B25A', 'A28B', 'A35B', 'B45D', 'D125A', 'C140D', 'D148B', 'B201A', 'D230A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -3.089419364929199
# --------------------------------------------------
# dm1: 5.419378757476807, dm2: 3.9515676498413086
# dm12: 0.8621482849121094
# Mutations: ['D24B', 'B25A', 'A28B', 'A35B', 'B45D', 'D125A', 'C140D', 'D148B', 'B201A', 'D230A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -3.089419364929199
# --------------------------------------------------
# dm1: 5.392232894897461, dm2: 2.9270896911621094
# dm12: -0.18946456909179688
# Mutations: ['D17A', 'A72D', 'A97B', 'A101B', 'D119B', 'D138B', 'C140D', 'D148B', 'C156A', 'A188B', 'B201A', 'D211C']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -3.1165542602539062
# --------------------------------------------------
# dm1: 5.3638997077941895, dm2: 4.244749069213867
# dm12: 1.0998516082763672
# Mutations: ['A72D', 'D112B', 'C124D', 'D126B', 'C140D', 'D148B', 'B201A', 'D218C']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -3.1448974609375
# --------------------------------------------------
# dm1: 4.223781108856201, dm2: 5.339542865753174
# dm12: 1.054534912109375
# Mutations: ['B63A', 'A73B', 'A74C', 'A96B', 'A101B', 'D112B', 'C140D', 'D148B', 'C208A', 'C232A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -3.169246196746826
# --------------------------------------------------
# dm1: 4.223781108856201, dm2: 5.339542865753174
# dm12: 1.054534912109375
# Mutations: ['B63A', 'A73B', 'A74C', 'A96B', 'A101B', 'D112B', 'C140D', 'D148B', 'C208A', 'C232A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -3.169246196746826
# --------------------------------------------------
# dm1: 2.0065197944641113, dm2: 1.663736343383789
# dm12: -1.5132856369018555
# Mutations: ['C50A', 'D112B', 'C140D', 'D148A', 'D211B', 'B217A', 'D230A', 'B231A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -3.1770219802856445
# --------------------------------------------------
# dm1: 2.0065197944641113, dm2: 1.663736343383789
# dm12: -1.5132856369018555
# Mutations: ['C50A', 'D112B', 'C140D', 'D148A', 'D211B', 'B217A', 'D230A', 'B231A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -3.1770219802856445
# --------------------------------------------------
# dm1: 5.317175388336182, dm2: 4.415979385375977
# dm12: 1.2243576049804688
# Mutations: ['A14B', 'B63A', 'A101B', 'D112A', 'C140D', 'D148B', 'A193C', 'D229B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -3.191621780395508
# --------------------------------------------------
# dm1: 5.317175388336182, dm2: 4.415979385375977
# dm12: 1.2243576049804688
# Mutations: ['A14B', 'B63A', 'A101B', 'D112A', 'C140D', 'D148B', 'A193C', 'D229B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -3.191621780395508
# --------------------------------------------------
# dm1: 5.311402320861816, dm2: 4.322800159454346
# dm12: 1.125406265258789
# Mutations: ['B63A', 'A101B', 'B111C', 'B135C', 'C140D', 'D148B', 'A181B', 'B206A', 'C208A', 'D218C']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -3.1973938941955566
# --------------------------------------------------
# dm1: 5.244509220123291, dm2: 5.296130180358887
# dm12: 2.031841278076172
# Mutations: ['D24C', 'A41C', 'A74C', 'B91C', 'A101B', 'D125A', 'C140D', 'D148B', 'B201A', 'D216A', 'B254D']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -3.212667942047119
# --------------------------------------------------
# dm1: 5.294961929321289, dm2: 3.7788214683532715
# dm12: 0.5649890899658203
# Mutations: ['D17A', 'C31A', 'A72D', 'C113D', 'C124A', 'D125A', 'D138C', 'C140D', 'D148B', 'B206A']
# Mutation Count: 10
# ...
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -3.9433131217956543
# --------------------------------------------------
# dm1: 4.562038421630859, dm2: 3.4096426963806152
# dm12: -0.5371189117431641
# Mutations: ['B23D', 'C31A', 'D125B', 'C140D', 'D148B', 'C232A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): -3.9467616081237793
# --------------------------------------------------
# dm1: 4.548741340637207, dm2: 3.692549228668213
# dm12: -0.2675037384033203
# Mutations: ['D17A', 'D39A', 'A101B', 'C124A', 'C140D', 'D148B', 'D160B', 'A167B', 'B201A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -3.960052967071533
# --------------------------------------------------
# dm1: 4.535735130310059, dm2: 3.667656421661377
# dm12: -0.3054046630859375
# Mutations: ['B6C', 'C10B', 'D17A', 'C31A', 'A101B', 'C124A', 'D136B', 'C140D', 'D148B', 'B206A', 'D255C', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -3.9730610847473145
# --------------------------------------------------
# dm1: 4.534238338470459, dm2: 3.102092742919922
# dm12: -0.8724460601806641
# Mutations: ['B20A', 'D39A', 'A101B', 'D119C', 'C140D', 'D148B', 'B201A', 'A203B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -3.974538803100586
# --------------------------------------------------
# dm1: 4.521880626678467, dm2: 2.3899049758911133
# dm12: -1.5970115661621094
# Mutations: ['C10B', 'A101B', 'D119C', 'D136C', 'C140D', 'D148B', 'C232D']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -3.9869165420532227
# --------------------------------------------------
# dm1: 4.515864372253418, dm2: 4.31193208694458
# dm12: 0.3189983367919922
# Mutations: ['D17A', 'D119C', 'C122B', 'C124A', 'D125A', 'C140D', 'D148B', 'B201A', 'B206A', 'C212B', 'D216A', 'D218C', 'C219A', 'B256A']
# Mutation Count: 14
# Dm1m2-min(dm1,dm2): -3.992933750152588
# --------------------------------------------------
# dm1: 4.509244918823242, dm2: 3.2399401664733887
# dm12: -0.7596206665039062
# Mutations: ['A14B', 'C140D', 'D148B', 'A188B', 'B201A', 'C219D', 'C220B', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -3.999560832977295
# --------------------------------------------------
# dm1: 4.509221076965332, dm2: 3.6956348419189453
# dm12: -0.30394554138183594
# Mutations: ['D17A', 'B34A', 'C50A', 'A72D', 'C124A', 'C140D', 'D148B', 'B206A', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -3.9995803833007812
# --------------------------------------------------
# dm1: 4.501689434051514, dm2: 2.4759135246276855
# dm12: -1.5311870574951172
# Mutations: ['A14B', 'D39A', 'A101B', 'C124A', 'C140D', 'D148B', 'B201A', 'D253A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.007100582122803
# --------------------------------------------------
# dm1: 4.497765064239502, dm2: 3.3612046241760254
# dm12: -0.6498298645019531
# Mutations: ['C50A', 'D125B', 'C140D', 'D148B']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): -4.0110344886779785
# --------------------------------------------------
# dm1: 4.4924397468566895, dm2: 2.9259095191955566
# dm12: -1.0904426574707031
# Mutations: ['D17A', 'D39B', 'A96B', 'A101B', 'C124A', 'C140D', 'D148B', 'A163D', 'B201A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -4.01635217666626
# --------------------------------------------------
# dm1: 4.465588092803955, dm2: 3.6505842208862305
# dm12: -0.3926219940185547
# Mutations: ['C10B', 'A11B', 'C31A', 'A101B', 'B111C', 'D112A', 'D119C', 'C122B', 'C140D', 'D148B', 'D218C', 'C234D']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -4.043206214904785
# --------------------------------------------------
# dm1: 4.464370250701904, dm2: 3.548661708831787
# dm12: -0.4957599639892578
# Mutations: ['D17A', 'A101B', 'C124A', 'C140D', 'D148B', 'B173A', 'A176B']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -4.044421672821045
# --------------------------------------------------
# dm1: 4.446755409240723, dm2: 3.645022392272949
# dm12: -0.417022705078125
# Mutations: ['B20A', 'C140D', 'D148B', 'D160C', 'B201A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): -4.062045097351074
# --------------------------------------------------
# dm1: 4.446755409240723, dm2: 3.645022392272949
# dm12: -0.417022705078125
# Mutations: ['B20A', 'C140D', 'D148B', 'D160C', 'B201A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): -4.062045097351074
# --------------------------------------------------
# dm1: 4.423200607299805, dm2: 3.2806334495544434
# dm12: -0.8049697875976562
# Mutations: ['B45D', 'A101B', 'C140D', 'D148B', 'B157A', 'D160B', 'C215B', 'C232D', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -4.0856032371521
# --------------------------------------------------
# dm1: 4.382209777832031, dm2: 3.782229423522949
# dm12: -0.3443641662597656
# Mutations: ['A11B', 'A32B', 'A41C', 'A101B', 'B111C', 'C140D', 'D148B', 'A222B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.126593589782715
# --------------------------------------------------
# dm1: 4.380406856536865, dm2: 3.3981070518493652
# dm12: -0.73028564453125
# Mutations: ['A11B', 'C31A', 'C140D', 'D148B', 'A154B', 'B201A', 'D218C']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -4.128392696380615
# --------------------------------------------------
# dm1: 4.348426818847656, dm2: 3.702324867248535
# dm12: -0.4580497741699219
# Mutations: ['A11B', 'C50A', 'C140D', 'D148B', 'A193C', 'B201A', 'B256A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -4.160374641418457
# --------------------------------------------------
# dm1: 4.343795299530029, dm2: 3.223633289337158
# dm12: -0.9413661956787109
# Mutations: ['C140D', 'D148B', 'B254D']
# Mutation Count: 3
# Dm1m2-min(dm1,dm2): -4.164999485015869
# --------------------------------------------------
# dm1: 4.322545528411865, dm2: 2.9044151306152344
# dm12: -1.2818317413330078
# Mutations: ['A14B', 'A28B', 'D39A', 'C140D', 'D148B', 'B201A']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): -4.186246871948242
# --------------------------------------------------
# dm1: 4.317439556121826, dm2: 3.0688509941101074
# dm12: -1.1225109100341797
# Mutations: ['A11B', 'D24C', 'B25A', 'B34A', 'C140D', 'D148B', 'B201A', 'D218C', 'D230A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -4.191361904144287
# --------------------------------------------------
# dm1: 4.312104225158691, dm2: 3.7243971824645996
# dm12: -0.47229576110839844
# Mutations: ['D39A', 'C50A', 'A101B', 'C140D', 'D148B', 'B201A', 'B206A', 'D211C', 'C219A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -4.196692943572998
# --------------------------------------------------
# dm1: 4.285390377044678, dm2: 3.090890884399414
# dm12: -1.1325111389160156
# Mutations: ['A14B', 'A101B', 'D112A', 'C140D', 'D148B', 'A193C']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): -4.22340202331543
# --------------------------------------------------
# dm1: 4.284333229064941, dm2: 3.0010762214660645
# dm12: -1.2233905792236328
# Mutations: ['A14B', 'B79A', 'D112A', 'D125B', 'C140D', 'D148B', 'C156A', 'A163D', 'C208B', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -4.224466800689697
# --------------------------------------------------
# dm1: 4.267179489135742, dm2: 1.5733733177185059
# dm12: -2.6682376861572266
# Mutations: ['A14B', 'D17A', 'B60C', 'A101B', 'D112C', 'C124A', 'B135C', 'D138C', 'C140D', 'D148B', 'B201A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -4.241611003875732
# --------------------------------------------------
# dm1: 2.5531253814697266, dm2: 4.2477617263793945
# dm12: -1.7079143524169922
# Mutations: ['A11B', 'A28B', 'A37B', 'A101B', 'D112B', 'C140D', 'D148B', 'B206A', 'B256A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -4.261039733886719
# --------------------------------------------------
# dm1: 4.2442626953125, dm2: 3.3378052711486816
# dm12: -0.9267253875732422
# Mutations: ['A101B', 'B106A', 'C113D', 'C124B', 'D125A', 'C140D', 'D148B', 'A167B', 'C234D']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -4.264530658721924
# --------------------------------------------------
# dm1: 4.239597320556641, dm2: 3.0606813430786133
# dm12: -1.2085113525390625
# Mutations: ['C124A', 'D125A', 'C140D', 'D148B', 'C156A', 'B187A', 'B201A', 'D230A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.269192695617676
# --------------------------------------------------
# dm1: 3.7554383277893066, dm2: 4.196710586547852
# dm12: -0.5566539764404297
# Mutations: ['D17A', 'C31A', 'C50A', 'A101B', 'D112B', 'C140D', 'D148B', 'B254C']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.312092304229736
# --------------------------------------------------
# dm1: 4.1684889793396, dm2: 3.02032470703125
# dm12: -1.3199901580810547
# Mutations: ['C31A', 'B111C', 'C113D', 'D125A', 'C140D', 'D148B', 'A203B']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -4.340314865112305
# --------------------------------------------------
# dm1: 4.148730278015137, dm2: 3.2777347564697266
# dm12: -1.08233642578125
# Mutations: ['D17A', 'A101B', 'D119A', 'C122B', 'C124A', 'D125A', 'C140D', 'D148B', 'D211B', 'B256A']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -4.360071182250977
# --------------------------------------------------
# dm1: 3.5335474014282227, dm2: 4.137648582458496
# dm12: -0.8376026153564453
# Mutations: ['C31A', 'A101B', 'C140D', 'D148B', 'C156A', 'B173A', 'A203B', 'B206A', 'B207A', 'C208A', 'B227A', 'D253B']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -4.371150016784668
# --------------------------------------------------
# dm1: 4.132562160491943, dm2: 3.2907280921936035
# dm12: -1.0855064392089844
# Mutations: ['C7D', 'B20A', 'C31A', 'B60D', 'A96B', 'A101B', 'D112B', 'C124D', 'D125B', 'B135C', 'C140D', 'D148B', 'B182A', 'B201A', 'A203B', 'D216A', 'B256A']
# Mutation Count: 17
# Dm1m2-min(dm1,dm2): -4.376234531402588
# --------------------------------------------------
# dm1: 4.11837100982666, dm2: 2.987381935119629
# dm12: -1.4030399322509766
# Mutations: ['A11B', 'B45C', 'B91C', 'A101B', 'C140D', 'D148B', 'C195B', 'A203B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.3904218673706055
# --------------------------------------------------
# dm1: 4.090719223022461, dm2: 3.8306403160095215
# dm12: -0.5874404907226562
# Mutations: ['B20A', 'D112B', 'C140D', 'D148B', 'B201A', 'C212B']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): -4.418080806732178
# --------------------------------------------------
# dm1: 3.63800048828125, dm2: 4.067683696746826
# dm12: -0.8031158447265625
# Mutations: ['A11B', 'D24C', 'C31A', 'D112B', 'C140D', 'D148B', 'B206A', 'C208A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.4411163330078125
# --------------------------------------------------
# dm1: 4.056406021118164, dm2: 2.6142544746398926
# dm12: -1.8381385803222656
# Mutations: ['A11B', 'A101B', 'C140D', 'D148B', 'C195D', 'A203B']
# Mutation Count: 6
# Dm1m2-min(dm1,dm2): -4.452393054962158
# --------------------------------------------------
# dm1: 4.038435935974121, dm2: 3.642324924468994
# dm12: -0.8280372619628906
# Mutations: ['A101B', 'B135C', 'C140D', 'D148B', 'A163B', 'B205A', 'B256A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -4.470362186431885
# --------------------------------------------------
# dm1: 4.017419338226318, dm2: 2.868518352508545
# dm12: -1.6228580474853516
# Mutations: ['A72D', 'B111C', 'C140D', 'D148B', 'C165A', 'A181B', 'B201A', 'C232A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.4913763999938965
# --------------------------------------------------
# dm1: 3.9938087463378906, dm2: 3.3505539894104004
# dm12: -1.1644363403320312
# Mutations: ['A11B', 'C31A', 'A97B', 'D119C', 'C122B', 'D125A', 'C140D', 'D148B', 'B201A', 'B254C', 'D255B']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -4.514990329742432
# --------------------------------------------------
# dm1: 3.9574108123779297, dm2: 3.5492520332336426
# dm12: -1.0021305084228516
# Mutations: ['A72D', 'A101B', 'D112B', 'C140D', 'D148B', 'B201A', 'B206A', 'C215B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.551382541656494
# --------------------------------------------------
# dm1: 3.918945789337158, dm2: 3.1656222343444824
# dm12: -1.4242305755615234
# Mutations: ['B23D', 'A74B', 'A101B', 'C140D', 'D148B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): -4.589852809906006
# --------------------------------------------------
# dm1: 3.918945789337158, dm2: 3.1656222343444824
# dm12: -1.4242305755615234
# Mutations: ['B23D', 'A74B', 'A101B', 'C140D', 'D148B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): -4.589852809906006
# --------------------------------------------------
# dm1: 3.914247512817383, dm2: 3.187565803527832
# dm12: -1.4069786071777344
# Mutations: ['A101B', 'C140D', 'D148B', 'A193C', 'B206A']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): -4.594544410705566
# --------------------------------------------------
# dm1: 3.909566879272461, dm2: 3.3555822372436523
# dm12: -1.2436542510986328
# Mutations: ['A11B', 'D24C', 'B25A', 'C50A', 'B111C', 'C140D', 'D148B', 'A203B']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.599236488342285
# --------------------------------------------------
# dm1: 3.861889362335205, dm2: 3.1295318603515625
# dm12: -1.5173721313476562
# Mutations: ['C140D', 'D148B', 'B201A', 'B206A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): -4.646903991699219
# --------------------------------------------------
# dm1: 3.842202663421631, dm2: 2.860199451446533
# dm12: -1.806396484375
# Mutations: ['B27D', 'A28B', 'B45C', 'C140D', 'D148B']
# Mutation Count: 5
# Dm1m2-min(dm1,dm2): -4.666595935821533
# --------------------------------------------------
# dm1: 3.816732883453369, dm2: 3.619025707244873
# dm12: -1.0730361938476562
# Mutations: ['C7D', 'C50A', 'A101B', 'C140D', 'D148B', 'B157A', 'D160B', 'A167B', 'A193B', 'C195D', 'B201A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -4.692061901092529
# --------------------------------------------------
# dm1: 3.7656073570251465, dm2: 1.8713855743408203
# dm12: -2.871793746948242
# Mutations: ['D17A', 'A72D', 'C124A', 'C140D', 'D148B', 'A154C', 'A155C', 'A170B', 'B201A']
# Mutation Count: 9
# Dm1m2-min(dm1,dm2): -4.7431793212890625
# --------------------------------------------------
# dm1: 3.7399635314941406, dm2: 2.7808823585510254
# dm12: -1.9879627227783203
# Mutations: ['B111D', 'C140D', 'D148B', 'B256A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): -4.768845081329346
# --------------------------------------------------
# dm1: 3.6957335472106934, dm2: 2.7133970260620117
# dm12: -2.099672317504883
# Mutations: ['D17A', 'A28B', 'D39A', 'C140D', 'D148B', 'D218C', 'C220B', 'C232A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.8130693435668945
# --------------------------------------------------
# dm1: 2.483302593231201, dm2: 3.6454477310180664
# dm12: -2.3800525665283203
# Mutations: ['D17A', 'C31A', 'A101B', 'D112B', 'C124D', 'C140D', 'D148B', 'A163C', 'B201A', 'D211B', 'C220D', 'B256A']
# Mutation Count: 12
# Dm1m2-min(dm1,dm2): -4.8633551597595215
# --------------------------------------------------
# dm1: 3.6276769638061523, dm2: 3.4899630546569824
# dm12: -1.3911590576171875
# Mutations: ['A28B', 'A37B', 'D39A', 'D112A', 'D119C', 'C124D', 'D125A', 'C140D', 'D148B', 'D218C']
# Mutation Count: 10
# Dm1m2-min(dm1,dm2): -4.88112211227417
# --------------------------------------------------
# dm1: 3.6245360374450684, dm2: 2.9127097129821777
# dm12: -1.9715557098388672
# Mutations: ['A101B', 'D119C', 'C140D', 'D148B', 'D211C', 'B227A', 'D230A', 'B256A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -4.884265422821045
# --------------------------------------------------
# dm1: 3.606997489929199, dm2: 1.667586326599121
# dm12: -3.2342090606689453
# Mutations: ['B25A', 'A72D', 'C140D', 'D148B', 'A151B', 'D211C', 'C215B']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -4.901795387268066
# --------------------------------------------------
# dm1: 3.5521445274353027, dm2: 3.6061511039733887
# dm12: -1.3505134582519531
# Mutations: ['D17A', 'D24C', 'A101B', 'D112B', 'C124D', 'D125A', 'C140D', 'D148B', 'B206A', 'D230A', 'B256A']
# Mutation Count: 11
# Dm1m2-min(dm1,dm2): -4.902657985687256
# --------------------------------------------------
# dm1: 3.249479293823242, dm2: 3.076098918914795
# dm12: -2.1832237243652344
# Mutations: ['B45A', 'C140D', 'D148B', 'C156A']
# Mutation Count: 4
# Dm1m2-min(dm1,dm2): -5.259322643280029
# --------------------------------------------------
# dm1: 3.237057685852051, dm2: 2.5646305084228516
# dm12: -2.7070999145507812
# Mutations: ['A97B', 'A101B', 'D119B', 'C140D', 'D148B', 'C156A', 'A161B', 'C208A']
# Mutation Count: 8
# Dm1m2-min(dm1,dm2): -5.271730422973633
# --------------------------------------------------
# dm1: 2.82773494720459, dm2: 2.157611846923828
# dm12: -3.5234413146972656
# Mutations: ['A97B', 'A101B', 'D119B', 'C140D', 'D148B', 'C156A', 'C208A']
# Mutation Count: 7
# Dm1m2-min(dm1,dm2): -5.681053161621094
# --------------------------------------------------
