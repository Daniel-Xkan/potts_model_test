# %% [markdown]
# # 1. read dde from file

# %%
import pandas as pd
# Try reading the file with space as a delimiter
df = pd.read_csv('data/kn.her2.all', delim_whitespace=True, header=None, names=['Mutation', 'DDE','DE_double', 'First_DE', 'Second_DE'])
# Split the 'Mutation' column into 'First_mutation' and 'Second_mutation'
df[['First_mutation', 'Second_mutation']] = df['Mutation'].str.split('-', expand=True)
# Display the DataFrame
print(df)
# Out:
# /var/folders/17/rj19bvws2qscyfjmb7m44zmm0000gn/T/ipykernel_1569/111636545.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('data/kn.her2.all', delim_whitespace=True, header=None, names=['Mutation', 'DDE','DE_double', 'First_DE', 'Second_DE'])
#         Mutation       DDE  DE_double  First_DE  Second_DE First_mutation  \
# 0        B1A-C2A  7.232628 -16.029196 -7.656878  -8.055814            B1A
# 1        B1A-C2B  2.924126 -17.516587 -7.656878 -11.322448            B1A
# 2        B1A-C2D  3.931540 -15.343873 -7.656878  -8.569091            B1A
# 3        B1A-C3A  6.683204 -16.250602 -7.656878  -7.958827            B1A
# 4        B1A-C3B  2.468630 -15.079575 -7.656878  -8.571916            B1A
# ...          ...       ...        ...       ...        ...            ...
# 43654  B98C-B99C -0.016739 -18.090722 -6.890913 -11.621474           B98C
# 43655  B98C-B99D -0.002944 -21.403432 -6.890913 -15.011783           B98C
# 43656  B98D-B99A  0.241060 -12.673526 -8.468545  -4.999852           B98D
# 43657  B98D-B99C -0.005845 -19.652754 -8.468545 -11.621474           B98D
# 43658  B98D-B99D  0.006986 -22.964501 -8.468545 -15.011783           B98D
#
#       Second_mutation
# 0                 C2A
# 1                 C2B
# 2                 C2D
# 3                 C3A
# 4                 C3B
# ...               ...
# 43654            B99C
# 43655            B99D
# 43656            B99A
# 43657            B99C
# 43658            B99D
#
# [43659 rows x 7 columns]

# %%
import pandas as pd
aa_offset =0 #redux start with 0, but position start with 1

# Load the TOP_SYN_LIST.TSV file
top_syn_list = pd.read_csv('data/top_syn_list.tsv', sep='\t')

# Load the PR.REDUCE4.REDUX file
with open('data/PR.reduce4.redux', 'r') as f:
    pr_reduce4_redux = f.readlines()

# Parse PR.REDUCE4.REDUX into a dictionary
translation_dict = {}
for line in pr_reduce4_redux:
    parts = line.strip().split(' ')
    position = int(parts[0])+aa_offset # Convert to 1-based index
    translation_dict[position] = {
        'A': set(parts[1]),
        'B': set(parts[2]),
        'C': set(parts[3]),
        'D': set(parts[4])
    }
untranslated_wildtype_aa1 = top_syn_list['wildtype_aa1']
untranslated_mutate_aa1 = top_syn_list['mutate_aa1']
untranslated_wildtype_aa2 = top_syn_list['wildtype_aa2']
untranslated_mutate_aa2 = top_syn_list['mutate_aa2']
# Function to translate amino acids
def translate_aa(position, aa):
    if position in translation_dict:
        for key, aa_set in translation_dict[position].items():
            if aa in aa_set:
                return key
    return None

# Apply translation to the dataframe
for col in ['wildtype_aa1', 'mutate_aa1', 'wildtype_aa2', 'mutate_aa2']:
    top_syn_list[col] = top_syn_list.apply(lambda row: translate_aa(row['pos1'] if '1' in col else row['pos2'], row[col]), axis=1)

# Look up the DDE value and add it as a new column
def lookup_dde(row):
    mutation1 = f"{row['wildtype_aa1']}{row['pos1']}{row['mutate_aa1']}"
    mutation2 = f"{row['wildtype_aa2']}{row['pos2']}{row['mutate_aa2']}"
    dde_row = df[(df['First_mutation'] == mutation1) & (df['Second_mutation'] == mutation2)]
    return dde_row['DDE'].values[0] if not dde_row.empty else None

top_syn_list['DDE'] = top_syn_list.apply(lookup_dde, axis=1)
# Keep the untranslated amino acids in the dataframe
# Save the translated dataframe

top_syn_list['untranslated_wildtype_aa1'] = untranslated_wildtype_aa1
top_syn_list['untranslated_mutate_aa1'] = untranslated_mutate_aa1
top_syn_list['untranslated_wildtype_aa2'] = untranslated_wildtype_aa2
top_syn_list['untranslated_mutate_aa2'] = untranslated_mutate_aa2

top_syn_list.to_csv('data/translated_top_syn_list.tsv', sep='\t', index=False)

# %% [markdown]
# read from data/top_syn_list.tsv , and traslate the amino acids with data/pr.reduce4.redux, where the first column is postion, second column corrosponding aas translate to A, third to B, and fourth to C, fifth to D and save it locally

# %% [markdown]
# # 2. index each sequence by its mutations compared to in.consensus.reduce4.seq

# %% [markdown]
# read in from ../data/in.reduce4.seq, there are 1220 sequences, create a df, with last column as mutations: with a list of mutaiton that occored compared to ../data/in.consensus.reduce4.seq the mutations are in format for example: [D148B, C140D, ...] where D and C notes the wildtime from consensus at pos 148 and 140

# %%
# Read the consensus sequence
with open('data/PR.consensus.reduce4.seq', 'r') as f:
    consensus_sequence = f.read().strip()

# Read the 1220 sequences
sequences = []
with open('data/PR.exper.reduce4.seq', 'r') as f:
    for line in f:
        sequences.append(line.strip())

# Create a DataFrame to store sequences and their mutations
sequence_df = pd.DataFrame({'Sequence': sequences})

# Function to identify mutations compared to the consensus sequence
def find_mutations(sequence, consensus):
    mutations = []
    for i, (seq_residue, cons_residue) in enumerate(zip(sequence, consensus), start=1):
        if seq_residue != cons_residue:
            mutations.append(f"{cons_residue}{i}{seq_residue}")
    return mutations

# Add a column for mutations
sequence_df['Mutations'] = sequence_df['Sequence'].apply(lambda seq: find_mutations(seq, consensus_sequence))
sequence_df['Mutations_count'] = sequence_df['Mutations'].apply(len)
# Display the DataFrame
print(sequence_df)
# Out:
#                                                Sequence  \
# 0     BCCDDDCDCCDDDDDDABCDABCABDBACBDCAACCBBCABACBCC...
# 1     BCCDDDCDCDDDDCDDABCDABCABDBACBDDAACDBBCABACBCD...
# 2     BCCDDDCDCDDDDCCDABCDABCABDBACBDDAADDBBCABACBCD...
# 3     BCCDDDCDCCDDDCCDABCDABCDBDBACBDCAADDCBCABACBCC...
# 4     BCCDDDCDCDDDDCCDABCDABCABDBACBDCAADDCBCABACBCC...
# ...                                                 ...
# 5705  BCCDDDCDCDDDDCDDABCDABCABDBACBDCAADDBBCABABBCC...
# 5706  BCCCDDCDCDDDDCDCABCDABCABDBACBDCAADDCBCABACBCC...
# 5707  BCCDDDCDCDDBDDDDABCDABCABDBACBDCAADDABCABACBCC...
# 5708  BCCDDDCDCDDDDDDDABCDABCABDBACBDCAADDCBCABACBCC...
# 5709  BCCDDDCDCCDDDCDDABCDABCDBDBACBDCAACDBBCABADBCD...
#
#                                               Mutations  Mutations_count
# 0     [D10C, C14D, D35C, D36C, C37B, C54D, A63D, B64...               12
# 1     [C32D, D35C, C37B, C46D, A47B, A63D, C73B, D77...               10
# 2     [D15C, C32D, C37B, C46D, A47B, A63D, C82B, A92...                9
# 3            [D10C, D15C, A24D, C54D, A63D, A71B, C82B]                7
# 4                                    [D15C, A63D, B64D]                3
# ...                                                 ...              ...
# 5705   [C37B, C43B, C55D, A61C, C62D, A63D, C69B, D77C]                8
# 5706                                        [D4C, D16C]                2
# 5707                           [D12B, C14D, C37A, A63D]                4
# 5708                                 [C14D, A63D, C69B]                3
# 5709  [D10C, A24D, D35C, C37B, C43D, C46D, C55D, C57...               11
#
# [5710 rows x 3 columns]

# %% [markdown]
# # 3. J matrix and delta e definition

# %% [markdown]
# ## 3.1 J matrix

# %%
import numpy as np

#dictionary of J matrix
J_dict = {}

# Load the J matrix from the downloaded file
J = np.load('data/J_PR.npy')

row = 0
# Determine the largest position in the 'Mutation' column of the dataframe
max_position = max(
    int(mutation[1:-1]) for mutation in df['First_mutation'].tolist() + df['Second_mutation'].tolist()
)
# print(max_position+1)
# Update the range to use the largest position
for pos1 in range(1, max_position + 1):
    for pos2 in range(pos1 + 1, max_position + 1):
        for i, aa1 in enumerate(['A', 'B', 'C', 'D']):
            for j, aa2 in enumerate(['A', 'B', 'C', 'D']):
                col = i * 4 + j
                J_dict[(pos1, pos2, aa1, aa2)] = J[row, col]
                J_dict[(pos2, pos1, aa2, aa1)] = J[row, col]
        row += 1

print(f"Dictionary created with {len(J_dict)} entries")
# Out:
# Dictionary created with 155232 entries

# %% [markdown]
# ## 3.2 define delta e

# %%
# Define delta E calculation
def calculate_delta_e(position, old_amino_acid, new_amino_acid, seq, J_dict):
    # E(old_amino_acid)
    energy_old = 0
    for other_pos in range(1, max_position+1):
        if other_pos == position:
            continue
        other_aa = seq[other_pos - 1]  # Access the first sequence in sequence_list
        energy_old += J_dict.get((position, other_pos, old_amino_acid, other_aa), 0)

    # E(new_amino_acid)
    energy_new = 0
    for other_pos in range(1, max_position+1):
        if other_pos == position:
            continue
        other_aa = seq[other_pos - 1]  # Access the first sequence in sequence_list
        energy_new += J_dict.get((position, other_pos, new_amino_acid, other_aa), 0)

    delta_e = energy_old - energy_new
    # print(f"E({old_amino_acid}) at {position}: {energy_old}")
    # print(f"E({new_amino_acid}) at {position}: {energy_new}")
    # print(f"Delta E for {old_amino_acid}{position}{new_amino_acid}: {delta_e}")
    return delta_e

# # Example usage
# position = 140
# old_amino_acid = 'C'
# new_amino_acid = 'D'
# calculate_delta_e(position, old_amino_acid, new_amino_acid, sequence_list, J_dict)

# %%
# define dm12
def calculate_dm12 (pos1, old_amino_acid1, new_amino_acid1, pos2, old_amino_acid2, new_amino_acid2, seq, J_dict):
    energy_old = 0
    energy_new = 0

# old energy
    for other_pos in range(1, max_position+1):
        other_aa = seq[other_pos - 1] 
        if other_pos == pos1:
            continue
        if other_pos == pos2:
            energy_old += J_dict.get((pos1, pos2, old_amino_acid1, old_amino_acid2), 0)
        else:
            energy_old += J_dict.get((pos1, other_pos, old_amino_acid1, other_aa), 0)

    for other_pos in range(1, max_position+1):
        other_aa = seq[other_pos - 1]
        if other_pos == pos2:
            continue
        if other_pos == pos1:
            # energy_old += J_dict.get((pos2, pos1, old_amino_acid2, old_amino_acid1), 0)
            continue
        else:
            energy_old += J_dict.get((pos2, other_pos, old_amino_acid2, other_aa), 0)

# new energy
    for other_pos in range(1, max_position+1):
        other_aa = seq[other_pos - 1] 
        if other_pos == pos1:
            continue
        if other_pos == pos2:
            energy_new += J_dict.get((pos1, pos2, new_amino_acid1, new_amino_acid2), 0)
        else:
            energy_new += J_dict.get((pos1, other_pos, new_amino_acid1, other_aa), 0)

    for other_pos in range(1, max_position+1):
        other_aa = seq[other_pos - 1] 
        if other_pos == pos2:
            continue
        if other_pos == pos1:
            # energy_new += J_dict.get((pos2, pos1, new_amino_acid2, new_amino_acid1), 0)
            continue
        
        else:
            energy_new += J_dict.get((pos2, other_pos, new_amino_acid2, other_aa), 0)
    
    return energy_old - energy_new

# %% [markdown]
# ## 3.3 flip on 1220

# %% [markdown]
# run de on all 1220 sequences with D148B, C140D (C140D, D148B), if the consensus vs one of 1220 sequences where the DE of each mutation changes its size compare to others  ( DE -DE sign change from consensus where the sign change means the sign of de D148B- deC140D sign change), record that sequence with its mutaitons and mutation len

# %% [markdown]
# make this a flip function, with mutation1 and 2 ans input and output the file in data/antag_out/{mut1}_{mut2}.tsv

# %%
import os

def flip(mutation1, mutation2, untranslated_mutation1, untranslated_mutation2):
    # Extract position and amino acid information from the mutations
    pos1, old_aa1, new_aa1 = int(mutation1[1:-1]), mutation1[0], mutation1[-1]
    pos2, old_aa2, new_aa2 = int(mutation2[1:-1]), mutation2[0], mutation2[-1]

    # List to store sequences with sign change
    sequences_with_sign_change = []

    # Calculate delta E for the consensus sequence
    de_mutation1_consensus = calculate_delta_e(pos1, old_aa1, new_aa1, consensus_sequence, J_dict)
    de_mutation2_consensus = calculate_delta_e(pos2, old_aa2, new_aa2, consensus_sequence, J_dict)

    print("-" * 50)
    print(f'Consensus delta E for {mutation1}: {de_mutation1_consensus}, {mutation2}: {de_mutation2_consensus}')
    print('Consensus dm12:', calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, consensus_sequence, J_dict))
    print("-" * 50)
    
    # Save the consensus energies to a TSV file######################################################
    consensus_output_dir = 'data/consensus_out'
    os.makedirs(consensus_output_dir, exist_ok=True)
    consensus_output_file = os.path.join(consensus_output_dir, f'{untranslated_mutation1}_{untranslated_mutation2}.tsv')

    consensus_data = {
        'Sequence': [consensus_sequence],  # Wrap the sequence in a list
        'Mutations': [[]],  # Wrap the empty list in another list
        'Mutation_count': [0],  # Wrap the integer in a list
        'dm1': [de_mutation1_consensus],
        'dm2': [de_mutation2_consensus],
        'dm12': [calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, consensus_sequence, J_dict)]
    }

    consensus_df = pd.DataFrame(consensus_data)
    consensus_df.to_csv(consensus_output_file, sep='\t', index=False)

    print(f"Consensus energies saved to {consensus_output_file}")
    ##################################################################################################

    # Iterate through all sequences
    for index, row in sequence_df.iterrows():
        sequence = row['Sequence']
        mutations = row['Mutations']
        mutation_count = row['Mutations_count']

        # Skip sequences without the specified mutations
        # if mutation1 not in mutations or mutation2 not in mutations:
        #     continue

        # Calculate delta E for the specified mutations
        de_mutation1 = calculate_delta_e(pos1, old_aa1, new_aa1, sequence, J_dict)
        de_mutation2 = calculate_delta_e(pos2, old_aa2, new_aa2, sequence, J_dict)

        # Check for sign change
        if (de_mutation1 - de_mutation2) * (de_mutation1_consensus - de_mutation2_consensus) < 0:
            dm12 = calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, sequence, J_dict)
            min_dm1_dm2 = min(de_mutation1, de_mutation2)
            max_dm1_dm2 = max(de_mutation1, de_mutation2)
            max_divide_min_dm1_dm2 = max_dm1_dm2 / min_dm1_dm2

            sequences_with_sign_change.append({
                'Sequence': sequence,
                'Mutations': mutations,
                'Mutation_count': mutation_count,
                'dm1': de_mutation1,
                'dm2': de_mutation2,
                'dm12': dm12,
                # 'Dm1m2-max/min(dm1,dm2)': dm12 - max_divide_min_dm1_dm2,
                # 'Dm1m2-min(dm1,dm2)': dm12 - min_dm1_dm2
                'Dm1m2-max(dm1,dm2)': dm12 - max_dm1_dm2,
            })

    # Create a DataFrame to store the results
    sign_change_df = pd.DataFrame(sequences_with_sign_change)

    # Sort the DataFrame by 'Dm1m2-min(dm1,dm2)' in descending order
    sign_change_df = sign_change_df.sort_values(by='Dm1m2-max(dm1,dm2)', ascending=False)

    # Define the output directory and file path
    output_dir = 'data/flip_out'
    os.makedirs(output_dir, exist_ok=True)
    output_file = os.path.join(output_dir, f'{untranslated_mutation1}_{untranslated_mutation2}.tsv')

    # Save the results to a TSV file
    sign_change_df.to_csv(output_file, sep='\t', index=False)

    print(f"Results saved to {output_file}")

# %% [markdown]
# ## 3.4 compensate on 1220

# %%
def compensate(mutation1, mutation2, untranslated_mutation1, untranslated_mutation2):
    # Extract position and amino acid information from the mutations
    pos1, old_aa1, new_aa1 = int(mutation1[1:-1]), mutation1[0], mutation1[-1]
    pos2, old_aa2, new_aa2 = int(mutation2[1:-1]), mutation2[0], mutation2[-1]

    # List to store sequences with compensation
    sequences_with_compensation = []

    # Calculate delta E for the consensus sequence
    de_mutation1_consensus = calculate_delta_e(pos1, old_aa1, new_aa1, consensus_sequence, J_dict)
    de_mutation2_consensus = calculate_delta_e(pos2, old_aa2, new_aa2, consensus_sequence, J_dict)

    print("-" * 50)
    print(f'Consensus delta E for {mutation1}: {de_mutation1_consensus}, {mutation2}: {de_mutation2_consensus}')
    print('Consensus dm12:', calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, consensus_sequence, J_dict))
    print("-" * 50)

    # Iterate through all sequences
    for index, row in sequence_df.iterrows():
        sequence = row['Sequence']
        mutations = row['Mutations']
        mutation_count = row['Mutations_count']
        

        # Skip sequences without the specified mutations
        # if mutation1 not in mutations or mutation2 not in mutations:
        #     continue

        # Calculate delta E for the specified mutations
        de_mutation1 = calculate_delta_e(pos1, old_aa1, new_aa1, sequence, J_dict)
        de_mutation2 = calculate_delta_e(pos2, old_aa2, new_aa2, sequence, J_dict)
        dm12 = calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, sequence, J_dict)

        # Check for compensation
        if (dm12 > de_mutation1 or dm12 > de_mutation2) and not (dm12 > de_mutation1 and dm12 > de_mutation2):
            min_dm1_dm2 = min(de_mutation1, de_mutation2)
            max_dm1_dm2 = max(de_mutation1, de_mutation2)
            max_divide_min_dm1_dm2 = max_dm1_dm2 / min_dm1_dm2
            sequences_with_compensation.append({
                'Sequence': sequence,
                'Mutations': mutations,
                'Mutation_count': mutation_count,
                'dm1': de_mutation1,
                'dm2': de_mutation2,
                'dm12': dm12,
                'Dm1m2-min(dm1,dm2)': dm12 - min_dm1_dm2
            })

    # Create a DataFrame to store the results
    compensation_df = pd.DataFrame(sequences_with_compensation)
    compensation_df = compensation_df.sort_values(by='Dm1m2-min(dm1,dm2)', ascending=False)

    # Define the output directory and file path
    output_dir = 'data/compensate_out'
    os.makedirs(output_dir, exist_ok=True)
    output_file = os.path.join(output_dir, f'{untranslated_mutation1}_{untranslated_mutation2}.tsv')

    # Save the results to a TSV file
    compensation_df.to_csv(output_file, sep='\t', index=False)

    print(f"Results saved to {output_file}")

# %% [markdown]
# ## 3.4.2 rescue

# %%
def rescue(mutation1, mutation2, untranslated_mutation1, untranslated_mutation2):
    # Extract position and amino acid information from the mutations
    pos1, old_aa1, new_aa1 = int(mutation1[1:-1]), mutation1[0], mutation1[-1]
    pos2, old_aa2, new_aa2 = int(mutation2[1:-1]), mutation2[0], mutation2[-1]

    # List to store sequences with compensation
    sequences_with_compensation = []

    # Calculate delta E for the consensus sequence
    de_mutation1_consensus = calculate_delta_e(pos1, old_aa1, new_aa1, consensus_sequence, J_dict)
    de_mutation2_consensus = calculate_delta_e(pos2, old_aa2, new_aa2, consensus_sequence, J_dict)

    print("-" * 50)
    print(f'Consensus delta E for {mutation1}: {de_mutation1_consensus}, {mutation2}: {de_mutation2_consensus}')
    print('Consensus dm12:', calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, consensus_sequence, J_dict))
    print("-" * 50)

    # Iterate through all sequences
    for index, row in sequence_df.iterrows():
        sequence = row['Sequence']
        mutations = row['Mutations']
        mutation_count = row['Mutations_count']
        

        # Skip sequences without the specified mutations
        # if mutation1 not in mutations or mutation2 not in mutations:
        #     continue

        # Calculate delta E for the specified mutations
        de_mutation1 = calculate_delta_e(pos1, old_aa1, new_aa1, sequence, J_dict)
        de_mutation2 = calculate_delta_e(pos2, old_aa2, new_aa2, sequence, J_dict)
        dm12 = calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, sequence, J_dict)

        # Check for compensation
        if dm12 > de_mutation1 and dm12 > de_mutation2:
            min_dm1_dm2 = min(de_mutation1, de_mutation2)
            max_dm1_dm2 = max(de_mutation1, de_mutation2)
            max_divide_min_dm1_dm2 = max_dm1_dm2 / min_dm1_dm2
            sequences_with_compensation.append({
                'Sequence': sequence,
                'Mutations': mutations,
                'Mutation_count': mutation_count,
                'dm1': de_mutation1,
                'dm2': de_mutation2,
                'dm12': dm12,
                'Dm1m2-max(dm1,dm2)': dm12 - max_dm1_dm2
            })

    # Create a DataFrame to store the results
    compensation_df = pd.DataFrame(sequences_with_compensation)
    compensation_df = compensation_df.sort_values(by='Dm1m2-max(dm1,dm2)', ascending=False)

    # Define the output directory and file path
    output_dir = 'data/rescue_out'
    os.makedirs(output_dir, exist_ok=True)
    output_file = os.path.join(output_dir, f'{untranslated_mutation1}_{untranslated_mutation2}.tsv')

    # Save the results to a TSV file
    compensation_df.to_csv(output_file, sep='\t', index=False)

    print(f"Results saved to {output_file}")

# %% [markdown]
# ## 3.5 antagonistic interactions

# %%
import os

def antagonistic(mutation1, mutation2 , untranslated_mutation1, untranslated_mutation2):
    # Extract position and amino acid information from the mutations
    pos1, old_aa1, new_aa1 = int(mutation1[1:-1]), mutation1[0], mutation1[-1]
    pos2, old_aa2, new_aa2 = int(mutation2[1:-1]), mutation2[0], mutation2[-1]

    # List to store sequences with antagonistic interactions
    sequences_with_antagonistic = []

    # Calculate delta E for the consensus sequence
    de_mutation1_consensus = calculate_delta_e(pos1, old_aa1, new_aa1, consensus_sequence, J_dict)
    de_mutation2_consensus = calculate_delta_e(pos2, old_aa2, new_aa2, consensus_sequence, J_dict)

    print("-" * 50)
    print(f'Consensus delta E for {mutation1}: {de_mutation1_consensus}, {mutation2}: {de_mutation2_consensus}')
    print('Consensus dm12:', calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, consensus_sequence, J_dict))
    print("-" * 50)

    # Iterate through all sequences
    for index, row in sequence_df.iterrows():
        sequence = row['Sequence']
        mutations = row['Mutations']
        mutation_count = row['Mutations_count']
        
        # Skip sequences without the specified mutations
        # if mutation1 not in mutations or mutation2 not in mutations:
        #     continue
        
        # Calculate delta E for the specified mutations
        de_mutation1 = calculate_delta_e(pos1, old_aa1, new_aa1, sequence, J_dict)
        de_mutation2 = calculate_delta_e(pos2, old_aa2, new_aa2, sequence, J_dict)
        dm12 = calculate_dm12(pos1, old_aa1, new_aa1, pos2, old_aa2, new_aa2, sequence, J_dict)

        # Check for antagonistic interaction
        if dm12 < de_mutation1 and dm12 < de_mutation2:
            min_dm1_dm2 = min(de_mutation1, de_mutation2)
            max_dm1_dm2 = max(de_mutation1, de_mutation2)
            max_divide_min_dm1_dm2 = max_dm1_dm2 / min_dm1_dm2
            
            sequences_with_antagonistic.append({
                'Sequence': sequence,
                'Mutations': mutations,
                'Mutation_count': mutation_count,
                'dm1': de_mutation1,
                'dm2': de_mutation2,
                'dm12': dm12,
                # 'Dm1m2-max/min(dm1,dm2)': dm12 - max_divide_min_dm1_dm2,
                # 'Dm1m2-min(dm1,dm2)': dm12 - min_dm1_dm2
                'Dm1m2-min(dm1,dm2)': dm12- min_dm1_dm2
            })

    # Create a DataFrame to store the results
    antagonistic_df = pd.DataFrame(sequences_with_antagonistic)

    # Sort the DataFrame by 'Dm1m2-min(dm1,dm2)' in descending order
    antagonistic_df = antagonistic_df.sort_values(by='Dm1m2-min(dm1,dm2)', ascending=False)

    # Define the output directory and file path
    output_dir = 'data/antag_out'
    os.makedirs(output_dir, exist_ok=True)
    output_file = os.path.join(output_dir, f'{untranslated_mutation1}_{untranslated_mutation2}.tsv')

    # Save the results to a TSV file
    antagonistic_df.to_csv(output_file, sep='\t', index=False)

    print(f"Results saved to {output_file}")

# %%
# # Define the mutations
# mutation1 = 'G140S'
# mutation2 = 'Q148H'
# Load the translated_top_syn_list.tsv file
translated_top_syn_list = pd.read_csv('data/translated_top_syn_list.tsv', sep='\t')

# Iterate through each row in the dataframe
for index, row in translated_top_syn_list.iterrows():
    # Extract mutation details
    mutation1 = f"{row['wildtype_aa1']}{row['pos1']}{row['mutate_aa1']}"
    mutation2 = f"{row['wildtype_aa2']}{row['pos2']}{row['mutate_aa2']}"
    untranslated_mutation1 = f"{row['untranslated_wildtype_aa1']}{row['pos1']}{row['untranslated_mutate_aa1']}"
    untranslated_mutation2 = f"{row['untranslated_wildtype_aa2']}{row['pos2']}{row['untranslated_mutate_aa2']}"
   

    # Print the mutations being processed
    print(f"Processing mutations: {mutation1}, {mutation2}")

    # Test the flip function
    print("Testing flip function:")
    flip(mutation1, mutation2,untranslated_mutation1, untranslated_mutation2)

    # Test the compensate function
    print("\nTesting compensate function:")
    compensate(mutation1, mutation2, untranslated_mutation1, untranslated_mutation2)

    # Test the rescue function
    print("\nTesting rescue function:")
    rescue(mutation1, mutation2, untranslated_mutation1, untranslated_mutation2)

    # Test the antagonistic function
    print("\nTesting antagonistic function:")
    antagonistic(mutation1, mutation2, untranslated_mutation1, untranslated_mutation2)
# Out:
# Processing mutations: B30D, B88C
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for B30D: -3.3826494216918945, B88C: -6.101837158203125
# Consensus dm12: -4.8736153
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/D30N_N88D.tsv
# Results saved to data/flip_out/D30N_N88D.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for B30D: -3.3826494216918945, B88C: -6.101837158203125
# Consensus dm12: -4.8736153
# --------------------------------------------------
# Results saved to data/compensate_out/D30N_N88D.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for B30D: -3.3826494216918945, B88C: -6.101837158203125
# Consensus dm12: -4.8736153
# --------------------------------------------------
# Results saved to data/rescue_out/D30N_N88D.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for B30D: -3.3826494216918945, B88C: -6.101837158203125
# Consensus dm12: -4.8736153
# --------------------------------------------------
# Results saved to data/antag_out/D30N_N88D.tsv
# Processing mutations: C32D, A47B
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C32D: -4.815643310546875, A47B: -6.037335395812988
# Consensus dm12: -7.4023676
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/V32I_I47V.tsv
# Results saved to data/flip_out/V32I_I47V.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C32D: -4.815643310546875, A47B: -6.037335395812988
# Consensus dm12: -7.4023676
# --------------------------------------------------
# Results saved to data/compensate_out/V32I_I47V.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C32D: -4.815643310546875, A47B: -6.037335395812988
# Consensus dm12: -7.4023676
# --------------------------------------------------
# Results saved to data/rescue_out/V32I_I47V.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C32D: -4.815643310546875, A47B: -6.037335395812988
# Consensus dm12: -7.4023676
# --------------------------------------------------
# Results saved to data/antag_out/V32I_I47V.tsv
# Processing mutations: B48A, C54A
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for B48A: -5.687655925750732, C54A: -8.92651653289795
# Consensus dm12: -11.476565
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/G48V_I54A.tsv
# Results saved to data/flip_out/G48V_I54A.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for B48A: -5.687655925750732, C54A: -8.92651653289795
# Consensus dm12: -11.476565
# --------------------------------------------------
# Results saved to data/compensate_out/G48V_I54A.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for B48A: -5.687655925750732, C54A: -8.92651653289795
# Consensus dm12: -11.476565
# --------------------------------------------------
# Results saved to data/rescue_out/G48V_I54A.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for B48A: -5.687655925750732, C54A: -8.92651653289795
# Consensus dm12: -11.476565
# --------------------------------------------------
# Results saved to data/antag_out/G48V_I54A.tsv
# Processing mutations: B30D, C45D
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for B30D: -3.3826494216918945, C45D: -7.306343078613281
# Consensus dm12: -7.607358
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/D30N_K45Q.tsv
# Results saved to data/flip_out/D30N_K45Q.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for B30D: -3.3826494216918945, C45D: -7.306343078613281
# Consensus dm12: -7.607358
# --------------------------------------------------
# Results saved to data/compensate_out/D30N_K45Q.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for B30D: -3.3826494216918945, C45D: -7.306343078613281
# Consensus dm12: -7.607358
# --------------------------------------------------
# Results saved to data/rescue_out/D30N_K45Q.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for B30D: -3.3826494216918945, C45D: -7.306343078613281
# Consensus dm12: -7.607358
# --------------------------------------------------
# Results saved to data/antag_out/D30N_K45Q.tsv
# Processing mutations: C54A, C82B
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C54A: -8.92651653289795, C82B: -3.2296361923217773
# Consensus dm12: -9.210552
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/I54A_V82A.tsv
# Results saved to data/flip_out/I54A_V82A.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C54A: -8.92651653289795, C82B: -3.2296361923217773
# Consensus dm12: -9.210552
# --------------------------------------------------
# Results saved to data/compensate_out/I54A_V82A.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C54A: -8.92651653289795, C82B: -3.2296361923217773
# Consensus dm12: -9.210552
# --------------------------------------------------
# Results saved to data/rescue_out/I54A_V82A.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C54A: -8.92651653289795, C82B: -3.2296361923217773
# Consensus dm12: -9.210552
# --------------------------------------------------
# Results saved to data/antag_out/I54A_V82A.tsv
# Processing mutations: C54D, C82B
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C54D: -4.85602331161499, C82B: -3.2296361923217773
# Consensus dm12: -5.2233877
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/I54V_V82A.tsv
# Results saved to data/flip_out/I54V_V82A.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C54D: -4.85602331161499, C82B: -3.2296361923217773
# Consensus dm12: -5.2233877
# --------------------------------------------------
# Results saved to data/compensate_out/I54V_V82A.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C54D: -4.85602331161499, C82B: -3.2296361923217773
# Consensus dm12: -5.2233877
# --------------------------------------------------
# Results saved to data/rescue_out/I54V_V82A.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C54D: -4.85602331161499, C82B: -3.2296361923217773
# Consensus dm12: -5.2233877
# --------------------------------------------------
# Results saved to data/antag_out/I54V_V82A.tsv
# Processing mutations: C46D, A76C
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, A76C: -6.450879096984863
# Consensus dm12: -7.147024
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/M46I_L76V.tsv
# Results saved to data/flip_out/M46I_L76V.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, A76C: -6.450879096984863
# Consensus dm12: -7.147024
# --------------------------------------------------
# Results saved to data/compensate_out/M46I_L76V.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, A76C: -6.450879096984863
# Consensus dm12: -7.147024
# --------------------------------------------------
# Results saved to data/rescue_out/M46I_L76V.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, A76C: -6.450879096984863
# Consensus dm12: -7.147024
# --------------------------------------------------
# Results saved to data/antag_out/M46I_L76V.tsv
# Processing mutations: C54D, C82A
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C54D: -4.85602331161499, C82A: -4.7160444259643555
# Consensus dm12: -7.0959435
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/I54V_V82T.tsv
# Results saved to data/flip_out/I54V_V82T.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C54D: -4.85602331161499, C82A: -4.7160444259643555
# Consensus dm12: -7.0959435
# --------------------------------------------------
# Results saved to data/compensate_out/I54V_V82T.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C54D: -4.85602331161499, C82A: -4.7160444259643555
# Consensus dm12: -7.0959435
# --------------------------------------------------
# Results saved to data/rescue_out/I54V_V82T.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C54D: -4.85602331161499, C82A: -4.7160444259643555
# Consensus dm12: -7.0959435
# --------------------------------------------------
# Results saved to data/antag_out/I54V_V82T.tsv
# Processing mutations: C54A, C82A
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C54A: -8.92651653289795, C82A: -4.7160444259643555
# Consensus dm12: -11.298969
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/I54A_V82T.tsv
# Results saved to data/flip_out/I54A_V82T.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C54A: -8.92651653289795, C82A: -4.7160444259643555
# Consensus dm12: -11.298969
# --------------------------------------------------
# Results saved to data/compensate_out/I54A_V82T.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C54A: -8.92651653289795, C82A: -4.7160444259643555
# Consensus dm12: -11.298969
# --------------------------------------------------
# Results saved to data/rescue_out/I54A_V82T.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C54A: -8.92651653289795, C82A: -4.7160444259643555
# Consensus dm12: -11.298969
# --------------------------------------------------
# Results saved to data/antag_out/I54A_V82T.tsv
# Processing mutations: B48A, C82B
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for B48A: -5.687655925750732, C82B: -3.2296361923217773
# Consensus dm12: -6.598114
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/G48V_V82A.tsv
# Results saved to data/flip_out/G48V_V82A.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for B48A: -5.687655925750732, C82B: -3.2296361923217773
# Consensus dm12: -6.598114
# --------------------------------------------------
# Results saved to data/compensate_out/G48V_V82A.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for B48A: -5.687655925750732, C82B: -3.2296361923217773
# Consensus dm12: -6.598114
# --------------------------------------------------
# Results saved to data/rescue_out/G48V_V82A.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for B48A: -5.687655925750732, C82B: -3.2296361923217773
# Consensus dm12: -6.598114
# --------------------------------------------------
# Results saved to data/antag_out/G48V_V82A.tsv
# Processing mutations: C54A, A71D
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C54A: -8.92651653289795, A71D: -7.438209533691406
# Consensus dm12: -14.104578
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/I54A_A71I.tsv
# Results saved to data/flip_out/I54A_A71I.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C54A: -8.92651653289795, A71D: -7.438209533691406
# Consensus dm12: -14.104578
# --------------------------------------------------
# Results saved to data/compensate_out/I54A_A71I.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C54A: -8.92651653289795, A71D: -7.438209533691406
# Consensus dm12: -14.104578
# --------------------------------------------------
# Results saved to data/rescue_out/I54A_A71I.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C54A: -8.92651653289795, A71D: -7.438209533691406
# Consensus dm12: -14.104578
# --------------------------------------------------
# Results saved to data/antag_out/I54A_A71I.tsv
# Processing mutations: C46D, B88A
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, B88A: -7.829169273376465
# Consensus dm12: -8.950181
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/M46I_N88T.tsv
# Results saved to data/flip_out/M46I_N88T.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, B88A: -7.829169273376465
# Consensus dm12: -8.950181
# --------------------------------------------------
# Results saved to data/compensate_out/M46I_N88T.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, B88A: -7.829169273376465
# Consensus dm12: -8.950181
# --------------------------------------------------
# Results saved to data/rescue_out/M46I_N88T.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, B88A: -7.829169273376465
# Consensus dm12: -8.950181
# --------------------------------------------------
# Results saved to data/antag_out/M46I_N88T.tsv
# Processing mutations: C90B, B95C
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C90B: -3.569046974182129, B95C: -8.550134658813477
# Consensus dm12: -10.117173
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/L90M_C95F.tsv
# Results saved to data/flip_out/L90M_C95F.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C90B: -3.569046974182129, B95C: -8.550134658813477
# Consensus dm12: -10.117173
# --------------------------------------------------
# Results saved to data/compensate_out/L90M_C95F.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C90B: -3.569046974182129, B95C: -8.550134658813477
# Consensus dm12: -10.117173
# --------------------------------------------------
# Results saved to data/rescue_out/L90M_C95F.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C90B: -3.569046974182129, B95C: -8.550134658813477
# Consensus dm12: -10.117173
# --------------------------------------------------
# Results saved to data/antag_out/L90M_C95F.tsv
# Processing mutations: C32D, C46D
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C32D: -4.815643310546875, C46D: -3.3616909980773926
# Consensus dm12: -6.1991167
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/V32I_M46I.tsv
# Results saved to data/flip_out/V32I_M46I.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C32D: -4.815643310546875, C46D: -3.3616909980773926
# Consensus dm12: -6.1991167
# --------------------------------------------------
# Results saved to data/compensate_out/V32I_M46I.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C32D: -4.815643310546875, C46D: -3.3616909980773926
# Consensus dm12: -6.1991167
# --------------------------------------------------
# Results saved to data/rescue_out/V32I_M46I.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C32D: -4.815643310546875, C46D: -3.3616909980773926
# Consensus dm12: -6.1991167
# --------------------------------------------------
# Results saved to data/antag_out/V32I_M46I.tsv
# Processing mutations: B48A, C82A
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for B48A: -5.687655925750732, C82A: -4.7160444259643555
# Consensus dm12: -8.446971
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/G48V_V82T.tsv
# Results saved to data/flip_out/G48V_V82T.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for B48A: -5.687655925750732, C82A: -4.7160444259643555
# Consensus dm12: -8.446971
# --------------------------------------------------
# Results saved to data/compensate_out/G48V_V82T.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for B48A: -5.687655925750732, C82A: -4.7160444259643555
# Consensus dm12: -8.446971
# --------------------------------------------------
# Results saved to data/rescue_out/G48V_V82T.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for B48A: -5.687655925750732, C82A: -4.7160444259643555
# Consensus dm12: -8.446971
# --------------------------------------------------
# Results saved to data/antag_out/G48V_V82T.tsv
# Processing mutations: C54D, A91C
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C54D: -4.85602331161499, A91C: -8.415323257446289
# Consensus dm12: -11.344474
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/I54V_T91S.tsv
# Results saved to data/flip_out/I54V_T91S.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C54D: -4.85602331161499, A91C: -8.415323257446289
# Consensus dm12: -11.344474
# --------------------------------------------------
# Results saved to data/compensate_out/I54V_T91S.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C54D: -4.85602331161499, A91C: -8.415323257446289
# Consensus dm12: -11.344474
# --------------------------------------------------
# Results saved to data/rescue_out/I54V_T91S.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C54D: -4.85602331161499, A91C: -8.415323257446289
# Consensus dm12: -11.344474
# --------------------------------------------------
# Results saved to data/antag_out/I54V_T91S.tsv
# Processing mutations: C46D, C53D
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, C53D: -8.76024055480957
# Consensus dm12: -10.2549515
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/M46I_F53Y.tsv
# Results saved to data/flip_out/M46I_F53Y.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, C53D: -8.76024055480957
# Consensus dm12: -10.2549515
# --------------------------------------------------
# Results saved to data/compensate_out/M46I_F53Y.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, C53D: -8.76024055480957
# Consensus dm12: -10.2549515
# --------------------------------------------------
# Results saved to data/rescue_out/M46I_F53Y.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, C53D: -8.76024055480957
# Consensus dm12: -10.2549515
# --------------------------------------------------
# Results saved to data/antag_out/M46I_F53Y.tsv
# Processing mutations: C46B, C55D
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C46B: -4.1704254150390625, C55D: -5.944815158843994
# Consensus dm12: -8.30777
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/M46L_K55R.tsv
# Results saved to data/flip_out/M46L_K55R.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C46B: -4.1704254150390625, C55D: -5.944815158843994
# Consensus dm12: -8.30777
# --------------------------------------------------
# Results saved to data/compensate_out/M46L_K55R.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C46B: -4.1704254150390625, C55D: -5.944815158843994
# Consensus dm12: -8.30777
# --------------------------------------------------
# Results saved to data/rescue_out/M46L_K55R.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C46B: -4.1704254150390625, C55D: -5.944815158843994
# Consensus dm12: -8.30777
# --------------------------------------------------
# Results saved to data/antag_out/M46L_K55R.tsv
# Processing mutations: C46B, C82B
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C46B: -4.1704254150390625, C82B: -3.2296361923217773
# Consensus dm12: -5.593793
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/M46L_V82A.tsv
# Results saved to data/flip_out/M46L_V82A.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C46B: -4.1704254150390625, C82B: -3.2296361923217773
# Consensus dm12: -5.593793
# --------------------------------------------------
# Results saved to data/compensate_out/M46L_V82A.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C46B: -4.1704254150390625, C82B: -3.2296361923217773
# Consensus dm12: -5.593793
# --------------------------------------------------
# Results saved to data/rescue_out/M46L_V82A.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C46B: -4.1704254150390625, C82B: -3.2296361923217773
# Consensus dm12: -5.593793
# --------------------------------------------------
# Results saved to data/antag_out/M46L_V82A.tsv
# Processing mutations: C46D, C55D
# Testing flip function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, C55D: -5.944815158843994
# Consensus dm12: -7.5405245
# --------------------------------------------------
# Consensus energies saved to data/consensus_out/M46I_K55R.tsv
# Results saved to data/flip_out/M46I_K55R.tsv
#
# Testing compensate function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, C55D: -5.944815158843994
# Consensus dm12: -7.5405245
# --------------------------------------------------
# Results saved to data/compensate_out/M46I_K55R.tsv
#
# Testing rescue function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, C55D: -5.944815158843994
# Consensus dm12: -7.5405245
# --------------------------------------------------
# Results saved to data/rescue_out/M46I_K55R.tsv
#
# Testing antagonistic function:
# --------------------------------------------------
# Consensus delta E for C46D: -3.3616909980773926, C55D: -5.944815158843994
# Consensus dm12: -7.5405245
# --------------------------------------------------
# Results saved to data/antag_out/M46I_K55R.tsv
