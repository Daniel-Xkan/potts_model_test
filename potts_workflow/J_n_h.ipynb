# %%
import numpy as np

import plotly.graph_objects as go

# Generate spiral points
num_points = 10
theta = np.linspace(0, 1 * np.pi, num_points)  # Angle for the spiral
z = np.linspace(0, 4, num_points)  # Height of the spiral
x = np.sin(theta)  # X-coordinates
y = np.cos(theta)  # Y-coordinates

# Define indices for red points
red_indices = [2, 8]

# Define colors for the points
colors = ['red' if i in red_indices else 'blue' for i in range(num_points)]

# Create the figure
fig = go.Figure()

# Add the spiral line
fig.add_trace(go.Scatter3d(
    x=x, y=y, z=z,
    mode='lines',
    line=dict(color='black', width=1),  # Thick black lines
    name='Spiral'
))

# Add the points
fig.add_trace(go.Scatter3d(
    x=x, y=y, z=z,
    mode='markers',
    marker=dict(size=8, color=colors),  # Color the points
    name='Points'
))

# Update layout
fig.update_layout(
    title='3D Spiral',
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z'
    )
)

# Add lines connecting each point to every other point
for i in range(num_points):
    for j in range(i + 1, num_points):
        color = 'red' if i in red_indices and j in red_indices else 'black'
        fig.add_trace(go.Scatter3d(
            x=[x[i], x[j]],
            y=[y[i], y[j]],
            z=[z[i], z[j]],
            mode='lines',
            line=dict(color=color, width=1.5),
            showlegend=False
        ))


fig.update_layout(
    scene=dict(
        xaxis=dict(visible=False),
        yaxis=dict(visible=False),
        zaxis=dict(visible=False)
    )
)
# Show the plot
fig.show()

# %%
#now instead of spiral on the upper cell, make it a squre rim of a 4*4 squre, 
# 10 in total and leave two blank, and red index the same. the indexs of z are all zero, 
# and index of xys are (0,0),(0,1),(0,2),(0,3),(1,0),(2,0),(3,0),(1,3)(2,3)(3,3)
# Define the coordinates for the square rim
x = [0, 0, 0, 0, 1, 2, 3, 1, 2, 3]
y = [0, 1, 2, 3, 0, 0, 0, 3, 3, 3]
z = [0] * len(x)  # All z-coordinates are zero

red_indices_square = [5, 7]  # Indices of red points
# Define colors for the points
colors = ['red' if i in red_indices_square else 'blue' for i in range(num_points)]

# Create the figure
fig = go.Figure()

# Add the square rim line
# fig.add_trace(go.Scatter3d(
#     x=x[:8], y=y[:8], z=z[:8],
#     mode='lines',
#     line=dict(color='black', width=1),
#     name='Square Rim'
# ))
# Add lines connecting each point to every other point
line_style = 'dash'  # Set the line style for black lines
for i in range(len(x)):
    for j in range(i + 1, len(x)):
        color = 'red' if i in red_indices_square and j in red_indices_square else 'grey'
        line_width = 2 if color == 'red' else 1
        fig.add_trace(go.Scatter3d(
            x=[x[i], x[j]],
            y=[y[i], y[j]],
            z=[z[i], z[j]],
            mode='lines',
            line=dict(color=color, width=line_width, dash='solid'),
            showlegend=False
        ))

# Add the points
fig.add_trace(go.Scatter3d(
    x=x, y=y, z=z,
    mode='markers',
    marker=dict(size=8, color=colors),
    name='Points'
))

# Update layout
fig.update_layout(
    title='3D Square Rim',
    scene=dict(
        xaxis=dict(visible=False),
        yaxis=dict(visible=False),
        zaxis=dict(visible=False)
    )
)

# Show the plot
fig.show()

# %%
import numpy as np

import plotly.graph_objects as go

# Generate spiral points
num_points = 30
theta = np.linspace(0, 4 * np.pi, num_points)  # Angle for the spiral
z = np.linspace(0, 2, num_points)  # Height of the spiral
x = np.sin(theta)  # X-coordinates
y = np.cos(theta)  # Y-coordinates

# Define indices for red points
red_indices = [2, 8]

# Define colors for the points
colors = ['red' if i in red_indices else 'blue' for i in range(num_points)]

# Create the figure
fig = go.Figure()

# Add the spiral line
fig.add_trace(go.Scatter3d(
    x=x, y=y, z=z,
    mode='lines',
    line=dict(color='black', width=1),  # Thick black lines
    name='Spiral'
))

# Add the points
fig.add_trace(go.Scatter3d(
    x=x, y=y, z=z,
    mode='markers',
    marker=dict(size=8, color=colors),  # Color the points
    name='Points'
))

# Update layout
fig.update_layout(
    title='3D Spiral',
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z'
    )
)

# # Add lines connecting each point to every other point
# for i in range(num_points):
#     for j in range(i + 1, num_points):
#         color = 'red' if i in red_indices and j in red_indices else 'black'
#         fig.add_trace(go.Scatter3d(
#             x=[x[i], x[j]],
#             y=[y[i], y[j]],
#             z=[z[i], z[j]],
#             mode='lines',
#             line=dict(color=color, width=1.5),
#             showlegend=False
#         ))


fig.update_layout(
    scene=dict(
        xaxis=dict(visible=False),
        yaxis=dict(visible=False),
        zaxis=dict(visible=False)
    )
)
# Show the plot
fig.show()

# %% [markdown]
# use plotly generate an empty 10*10 3d plot, and then put 10 coonected dots with same interval on the x and y axis the dots sementics are same as the plot above, with all blue expecpt for the red indexes. the dots should be 10 on index (x, 0,0) and 10 on index (0,y,0)

# %% [markdown]
# use plotly generate a 3d with 10 by 10 points, same as dots on x and y  surface, with random <1 points on z axis, and draw the surface on top of the two lined up dots

# %%
import numpy as np

import plotly.graph_objects as go

# Define the number of points and red indices
num_points = 10
red_indices = [2, 8]

# Generate x and y coordinates for the dots
x = np.linspace(0, 4, num_points)
y = np.linspace(0, 4, num_points)

# Define colors for the points
colors_x = ['red' if i in red_indices else 'blue' for i in range(num_points)]
colors_y = ['red' if i in red_indices else 'blue' for i in range(num_points)]

# Create the figure
fig = go.Figure()

# Add points on the x-axis
for i in range(num_points):
    fig.add_trace(go.Scatter3d(
        x=[x[i]], y=[0], z=[0],
        mode='markers',
        marker=dict(size=8, color=colors_x[i]),
        name=f'Point {i} on X-axis'
    ))

# Add points on the y-axis
for i in range(num_points):
    fig.add_trace(go.Scatter3d(
        x=[0], y=[y[i]], z=[0],
        mode='markers',
        marker=dict(size=8, color=colors_y[i]),
        name=f'Point {i} on Y-axis'
    ))

# Connect nearby dots on the x-axis
for i in range(num_points - 1):
    fig.add_trace(go.Scatter3d(
        x=[x[i], x[i + 1]],
        y=[0, 0],
        z=[0, 0],
        mode='lines',
        line=dict(color='black', width=2),
        showlegend=False
    ))

# Connect nearby dots on the y-axis
for i in range(num_points - 1):
    fig.add_trace(go.Scatter3d(
        x=[0, 0],
        y=[y[i], y[i + 1]],
        z=[0, 0],
        mode='lines',
        line=dict(color='black', width=2),
        showlegend=False
    ))

    # Generate random z values for the surface
    z_surface = np.random.uniform(-3, -1.5, (num_points, num_points))

    # Modify specific points (2,8) and (8,2) on the z-axis
    z_surface[2, 8] = np.random.uniform(-0.5, 0)
    z_surface[8, 2] = z_surface[2, 8]

    # Ensure symmetry for all (a, b) and (b, a) pairs
    for i in range(num_points):
        for j in range(i, num_points):
            z_surface[j, i] = z_surface[i, j]

# Add the surface
fig.add_trace(go.Surface(
    z=z_surface,
    x=np.tile(x, (num_points, 1)),
    y=np.tile(y, (num_points, 1)).T,
    colorscale='Viridis',
    name='Surface'
))
# Add dashed red lines connecting x-axis redot and y-axis redot to (2,8) and (8,2) on z=0 surface accordingly,
#  aka draw from 2,0 to 2,8 and from 8,0 to 8,2 and 0,8 to 2,8 and 0,2 to 8,2  
# Add dashed red lines connecting the red dots
fig.add_trace(go.Scatter3d(
    x=[x[2], x[2]],
    y=[0, y[8]],
    z=[0, 0],
    mode='lines',
    line=dict(color='red', dash='dash', width=2),
    showlegend=False
))

fig.add_trace(go.Scatter3d(
    x=[x[8], x[8]],
    y=[0, y[2]],
    z=[0, 0],
    mode='lines',
    line=dict(color='red', dash='dash', width=2),
    showlegend=False
))

fig.add_trace(go.Scatter3d(
    x=[0, x[2]],
    y=[y[8], y[8]],
    z=[0, 0],
    mode='lines',
    line=dict(color='red', dash='dash', width=2),
    showlegend=False
))

fig.add_trace(go.Scatter3d(
    x=[0, x[8]],
    y=[y[2], y[2]],
    z=[0, 0],
    mode='lines',
    line=dict(color='red', dash='dash', width=2),
    showlegend=False
))
# Add dashed red lines from (2,8,0) and (8,2,0) to their respective random points on the surface
fig.add_trace(go.Scatter3d(
    x=[x[2], x[2]],
    y=[y[8], y[8]],
    z=[z_surface[8,2], z_surface[2, 8]],
    mode='lines',
    line=dict(color='red', dash='dash', width=2),
    showlegend=False
))

fig.add_trace(go.Scatter3d(
    x=[x[8], x[8]],
    y=[y[2], y[2]],
    z=[0, z_surface[8, 2]],
    mode='lines',
    line=dict(color='red', dash='dash', width=2),
    showlegend=False
))
# Add labels to points on the x-axis
for i in range(num_points):
    fig.add_trace(go.Scatter3d(
        x=[x[i]], y=[0], z=[0],
        mode='text',
        text=str(i + 1),
        textposition='top center',
        showlegend=False
    ))

# Add labels to points on the y-axis
for i in range(num_points):
    fig.add_trace(go.Scatter3d(
        x=[0], y=[y[i]], z=[0],
        mode='text',
        text=str(i + 1),
        textposition='top center',
        showlegend=False
    ))

fig.update_layout(
    scene=dict(
        xaxis=dict(showticklabels=False, title=''),
        yaxis=dict(showticklabels=False, title=''),
        zaxis=dict(showticklabels=False, title='')
    )
)
# Show the plot
fig.show()

# %%
import numpy as np

import plotly.graph_objects as go

# Define the number of points and red indices
num_points = 10
red_indices = [2, 8]

# Generate x coordinates for the dots
x = np.linspace(0, 4, num_points)

# Define colors for the points
colors_x = ['red' if i in red_indices else 'blue' for i in range(num_points)]

# Create the figure
fig = go.Figure()

# Add points on the x-axis
for i in range(num_points):
    fig.add_trace(go.Scatter3d(
        x=[x[i]], y=[0], z=[0],
        mode='markers',
        marker=dict(size=8, color=colors_x[i]),
        name=f'Point {i} on X-axis'
    ))

# Connect nearby dots on the x-axis
for i in range(num_points - 1):
    fig.add_trace(go.Scatter3d(
        x=[x[i], x[i + 1]],
        y=[0, 0],
        z=[0, 0],
        mode='lines',
        line=dict(color='black', width=2),
        showlegend=False
    ))

fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        xaxis=dict(visible=True),
        yaxis=dict(visible=False),
        zaxis=dict(visible=False)
    ),
    title='3D Plot with Dots on X Plane'
)

# Show the plot
fig.update_layout(scene=dict(
    xaxis=dict(visible=False),
    yaxis=dict(visible=False),
    zaxis=dict(visible=False)
))
fig.show()

# %% [markdown]
# same as above but draw the first to 10th points on the follwing xy axis with z axis 0, and remain the red index and blue indecies:
# (0,6)
# (1,5)
# (2,4)
# (2.5,3)
# (3,2)
# (2,1)
# (3,0)
# (5,0)
# (6,1)
# (5,2)
# (6,3)

# %%
# Define the coordinates for the points
x = [1, 2, 2.5, 3, 2, 3,4 ,5, 6, 4, 4.5,5]
y = [5, 4, 3, 2, 1, 0,-0, 0, 1, 2, 3,4]
z = [-5,-4,-3,-2,-1,0,0.25,0,-1,-2,-2,-1.5]

# Define the red indices
red_indices_here = [3,9]

# Define colors for the points
colors = ['red' if i in red_indices_here else 'blue' for i in range(len(x))]

# Create the figure
fig = go.Figure()

# Add the points
for i in range(len(x)):
    fig.add_trace(go.Scatter3d(
        x=[x[i]], y=[y[i]], z=[z[i]],
        mode='markers',
        marker=dict(size=8, color=colors[i]),
        name=f'Point {i}'
    ))

# Connect nearby points with lines
for i in range(len(x) - 1):
    fig.add_trace(go.Scatter3d(
        x=[x[i], x[i + 1]],
        y=[y[i], y[i + 1]],
        z=[z[i], z[i + 1]],
        mode='lines',
        line=dict(color='black', width=2),
        showlegend=False
    ))

    # Connect nearby points with thick diameter lines and transparent color like tubes
    for i in range(len(x) - 1):
        fig.add_trace(go.Scatter3d(
            x=[x[i], x[i + 1]],
            y=[y[i], y[i + 1]],
            z=[z[i], z[i + 1]],
            mode='lines',
            line=dict(color='rgba(0, 100, 230, 0.5)', width=10),  # Tube-like appearance with thicker lines
            showlegend=False
        ))

# Update layout
fig.update_layout(
    scene=dict(
        xaxis=dict(showticklabels=False, title=''),
        yaxis=dict(showticklabels=False, title=''),
        zaxis=dict(showticklabels=False, title='')
    )
)

# %%
import numpy as np

import plotly.graph_objects as go

# Define the number of points and red indices
num_points = 10
red_indices = [2, 8]

# Generate x coordinates for the dots
x = np.linspace(1, 2, num_points)

# Define colors for the points
colors_x = ['red' if i in red_indices else 'blue' for i in range(num_points)]

# Create the figure
fig = go.Figure()
# Increase the marker size for all dots
fig.update_traces(marker=dict(size=20))  # Set size to 20 for larger dots
# Add points on the x-axis
for i in range(num_points):
    fig.add_trace(go.Scatter(
        x=[x[i]], y=[0],
        mode='markers',
        marker=dict(size=16, color=colors_x[i]),  # Increased size to make dots bigger
        name=f'Point {i} on X-axis'
    ))

# Connect nearby dots on the x-axis
for i in range(num_points - 1):
    fig.add_trace(go.Scatter(
        x=[x[i], x[i + 1]],
        y=[0, 0],
        mode='lines',
        line=dict(color='black', width=2),
        showlegend=False
    ))

fig.update_traces(marker=dict(size=12))  # Increase the marker size for all dots
fig.update_layout(
    # xaxis=dict(range=[0, 6])
    xaxis=dict(range=[0, 3], visible=False),
    yaxis=dict(visible=False),
    plot_bgcolor='rgba(0,0,0,0)'  # Set background to none
)


# Show the plot
fig.show()
