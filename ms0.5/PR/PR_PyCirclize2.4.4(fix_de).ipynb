# %%
# Import Libraries and Configure Matplotlib
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import re
import collections
from matplotlib import cm
from matplotlib import colors
from pycirclize import Circos
from tqdm import tqdm
import glob
import pandas as pd
import sys
import importlib
sys.path.append('/Users/xuechenkan/potts_model_test/')  # Adjust the path as needed

from utilities.functions import *
import utilities.functions as functions

# Reload the module to reflect the changes
importlib.reload(functions)
# Out:
# <module 'utilities.functions' from '/Users/xuechenkan/potts_model_test/utilities/functions.py'>

# %%
start_aa = 1  # Starting amino acid position
actual_length = 263
IN_path = '/Users/xuechenkan/potts_model_test/ms0.5/IN/'
PR_path = '/Users/xuechenkan/potts_model_test/ms0.5/PR/'
RT_path = '/Users/xuechenkan/potts_model_test/ms0.5/RT/'
IN_unreduced_seq_path = '/Users/xuechenkan/potts_model_test/ms1/IN/data/in.fullseq'
PR_unreduced_seq_path = '/Users/xuechenkan/potts_model_test/ms1/PR/data/pr.exper.fullseq'
RT_unreduced_seq_path = '/Users/xuechenkan/potts_model_test/ms1/RT/data/rt.fullseq'

IN_redux_dict = get_redu_dict(IN_path+'data/in.reduce4.redux',1)
PR_redux_dict = get_redu_dict(PR_path+'data/pr.reduce4.redux',0)
RT_redux_dict = get_redu_dict(RT_path+'data/rt.reduce4.redux',0)

# %%
# Initialize Circos with a single sector for nl43 ΔΔE
start_aa = 1  # Starting amino acid position
actual_length = 99
circos_length = actual_length +1
sectors = {"nl43 ΔΔE": actual_length}
circos = Circos(sectors, space=0, start=0, end=340)

# Get the sector
sector = circos.get_sector("nl43 ΔΔE")

# Add outer track for the main arc
track1 = sector.add_track((96, 98))
track1.rect(0, actual_length, fc="grey", ec="grey", lw=1.0)

# Add ticks and labels
major_ticks_pos = list(range(0, actual_length, 5))
major_ticks_labels = [str(i+1) if (i+1) % 5 == 1 else "" for i in major_ticks_pos]
all_ticks_pos = list(range(0, actual_length, 1))
all_ticks_labels = None

track1.xticks(major_ticks_pos, major_ticks_labels, label_size=10, tick_length=2,outer=False)
track1.xticks(all_ticks_pos, all_ticks_labels, label_size=8, tick_length=1,outer=False)
# Load and Parse data file
pairs = []
values_all = []

# %%
fig = circos.plotfig()
plt.show()

# %% [markdown]
# strictly follow the api of this exmple, for each position that has a mutaiton, annotate the specific drug and the drug resistant mutations it has:
#     from pycirclize import Circos
# from pycirclize.parser import Gff
# from pycirclize.utils import load_prokaryote_example_file
#
# gff_file = load_prokaryote_example_file("enterobacteria_phage.gff")
# gff = Gff(gff_file)
#
# seqid2size = gff.get_seqid2size()
# space = 0 if len(seqid2size) == 1 else 2
# circos = Circos(sectors=seqid2size, space=space)
#
# seqid2features = gff.get_seqid2features(feature_type="CDS")
# for sector in circos.sectors:
#     track = sector.add_track((90, 100))
#     track.axis(fc="#EEEEEE", ec="none")
#     track.grid(2, color="black")
#
#     features = seqid2features[sector.name]
#     for feature in features:
#         # Plot CDS feature
#         if feature.location.strand == 1:
#             track.genomic_features(feature, plotstyle="arrow", r_lim=(95, 100), fc="salmon")
#         else:
#             track.genomic_features(feature, plotstyle="arrow", r_lim=(90, 95), fc="skyblue")
#         # Plot feature annotation label
#         start, end = int(feature.location.start), int(feature.location.end)
#         label_pos = (start + end) / 2
#         label = feature.qualifiers.get("product", [""])[0]
#         if label == "" or label.startswith("hypothetical"):
#             continue
#         track.annotate(label_pos, label, label_size=7)
#
# fig = circos.plotfig()
#
# use format: T66A/I/K drug: BIC, CAB, DTG, EVG, RAL

# %%
import glob
import pandas as pd

# Create dictionary for NRTI and NNRTI resistance mutations
# Read and merge from all drug_resistant*.tsv files

# Initialize the resistance_mutations dictionary structure
resistance_mutations = {
    "Drug_Resistant": {
        "positions": [],
        "consensus": [],
        "mutations": []
    }
}

# Find all drug_resistant*.tsv files
tsv_files = glob.glob('data/drug_resistant*.tsv')

# Read and merge all TSV files
all_drms = []
for file in tsv_files:
    try:
        df = pd.read_csv(file, sep='\t')
        # Rename columns to standard format if needed
        if 'PositionConsensus' in df.columns:
            df = df.rename(columns={'PositionConsensus': 'Position'})
        all_drms.append(df[['Position', 'Consensus', 'DRM']])
    except Exception as e:
        print(f"Error reading {file}: {e}")
        continue

# Combine all dataframes
if all_drms:
    combined_df = pd.concat(all_drms, ignore_index=True)
    
    # Group by position and consensus to collect all mutations
    grouped = combined_df.groupby(['Position', 'Consensus'])['DRM'].apply(lambda x: ''.join(sorted(set(x)))).reset_index()
    
    # Populate the resistance_mutations dictionary
    for _, row in grouped.iterrows():
        resistance_mutations["Drug_Resistant"]["positions"].append(int(row['Position']))
        resistance_mutations["Drug_Resistant"]["consensus"].append(row['Consensus'])
        resistance_mutations["Drug_Resistant"]["mutations"].append(row['DRM'])
else:
    print("No drug resistant TSV files found or readable")

print("Resistance Mutations Dictionary created:")
for category, data in resistance_mutations.items():
    print(f"\nCategory: {category}")
    print(f"Positions: {data['positions']}")
    print(f"Consensus: {data['consensus']}")
# Out:
# Resistance Mutations Dictionary created:
#
# Category: Drug_Resistant
# Positions: [10, 20, 23, 24, 30, 32, 33, 43, 46, 47, 48, 50, 53, 54, 58, 73, 74, 76, 82, 83, 84, 88, 89, 90]
# Consensus: ['L', 'K', 'L', 'L', 'D', 'V', 'L', 'K', 'M', 'I', 'G', 'I', 'F', 'I', 'Q', 'G', 'T', 'L', 'V', 'N', 'I', 'N', 'L', 'L']

# %%
# Add annotation track for mutations
annotation_track = sector.add_track((90, 100))

# Annotate each mutation position
annotated_positions = set()  # Track annotations to avoid duplicates
for category in resistance_mutations.keys():
    for i, pos in enumerate(resistance_mutations[category]["positions"]):
        
        circos_pos = pos - start_aa  # Adjust position to start from start_aa
        consensus = resistance_mutations[category]["consensus"][i]

        # Ensure circos_pos is within the valid range of the sector
        if circos_pos < 0 or circos_pos >= sector.size:
            print(f"Skipping position {pos} as it is out of range for the sector.")
            continue

        # Create label with consensus and position
        label = f"{consensus}{pos}"

        # Check if this position has already been annotated
        if (consensus, pos) not in annotated_positions:
            annotation_track.annotate(circos_pos, label, label_size=13, shorten=100)
            annotated_positions.add((consensus, pos))

# %%
fig = circos.plotfig()
plt.show()

# %%
# Initialize dictionaries to store delta E and delta delta E values
delta_e_per_position = collections.defaultdict(lambda: [0.0, 0.0, 0.0, 0.0])
delta_delta_e_per_pair = []

# Define mutation_map to map amino acids to indices
mutation_map = {'A': 0, 'B': 1, 'C': 2, 'D': 3}

# Read the file and process the data
with open('data/kn.her2.all') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        
        columns = re.split(r'[,\t\s]+', line)
        mutations = columns[0]
        ddE = float(columns[1])
        delta_e1 = float(columns[3])
        delta_e2 = float(columns[4])
        
        # Extract positions from the mutation string
        positions = [int(pos) for pos in re.findall(r'\d+', mutations)]
        if len(positions) != 2:
            continue
        
        pos1, pos2 = positions
        
        #detect the wildtype 'first' aa seuqnce, and put A' delta e into [0]....D's delta e into [3]
        # Store delta E values for each position
        # Detect the wildtype 'first' amino acid sequence
        wildtype_aa1 = mutations[0]  # Extract the first amino acid from the mutation string
        wildtype_aa2 = mutations.split('-')[1][0]  # Extract the first letter after '-'
        mutate_aa1 = mutations[mutations.index('-') - 1]  # Extract the one letter before '-'
        mutate_aa2 = mutations[-1]
        # print(f"Processing mutation: {mutations}, Positions: {pos1}, {pos2}, Wildtype AAs: {wildtype_aa1}, {wildtype_aa2}, Mutated AA1: {mutate_aa1}, Mutated AA2: {mutate_aa2}")
        # Map the wildtype amino acid to the corresponding index in the delta_e_per_position list
        if mutate_aa1 in mutation_map:
            delta_e_per_position[pos1][mutation_map[mutate_aa1]] = delta_e1
        if mutate_aa2 in mutation_map:
            delta_e_per_position[pos2][mutation_map[mutate_aa2]] = delta_e2
        
        # Store delta delta E values for each pair of positions
        delta_delta_e_per_pair.append((pos1, pos2, ddE))


print("Delta E per position:")
for pos, values in delta_e_per_position.items():
    print(f"Position {pos}: {values}")

print("\nDelta Delta E per pair:")
for pair in delta_delta_e_per_pair[:10]:  # Print first 10 pairs for brevity
    print(pair)
# Out:
# Delta E per position:
# Position 1: [-7.65687820315361, 0.0, -15.270409390330315, -15.244200959801674]
# Position 2: [-8.055814119055867, -11.32244774652645, 0.0, -8.569090587086976]
# Position 3: [-7.9588273745030165, -8.571915650740266, 0.0, -8.155805517919362]
# Position 4: [-7.901709549129009, -9.062162205576897, -5.582528863102198, 0.0]
# Position 5: [-7.671862963587046, -8.509819394443184, -7.5506263598799706, 0.0]
# Position 6: [-8.702947990968823, -10.011449309065938, -10.609377598389983, 0.0]
# Position 7: [-8.150218181312084, -6.7850492196157575, 0.0, -6.993757659569383]
# Position 8: [-7.00242667645216, -10.810621596872807, -15.089234918355942, 0.0]
# Position 9: [-8.264814216643572, -11.578867871314287, 0.0, -15.075881361961365]
# Position 10: [-4.653488149866462, -5.01730927452445, -3.001409363001585, 0.0]
# Position 11: [-6.655691193416715, -8.730066085234284, -9.590635046362877, 0.0]
# Position 12: [-4.187727555632591, -2.6436189003288746, -5.369526390917599, 0.0]
# Position 13: [-8.335788495838642, -2.0054782573133707, -10.403790419921279, 0.0]
# Position 14: [-6.144697094336152, -7.580942366272211, 0.0, -2.5640227664262056]
# Position 15: [-9.686193680390716, -6.1875506937503815, -1.2176780756562948, 0.0]
# Position 16: [-9.739111291244626, -5.409278167411685, -4.092847662046552, 0.0]
# Position 17: [0.0, -5.095459245145321, -5.417207387275994, -8.983717489987612]
# Position 18: [-6.523982964456081, 0.0, -5.552409275434911, -6.132597170770168]
# Position 19: [-3.9864791333675385, -2.290499497205019, 0.0, -4.586674952879548]
# Position 20: [-4.384629253298044, -7.058664083480835, -6.121196448802948, 0.0]
# Position 21: [0.0, -8.77787435054779, -10.824223658069968, -10.730192564427853]
# Position 22: [-10.276443999260664, 0.0, -15.139029458165169, -7.664188075810671]
# Position 23: [-9.565782797988504, -7.098663568496704, 0.0, -15.27023833990097]
# Position 24: [0.0, -11.017500375397503, -9.962894095107913, -5.855606945231557]
# Position 25: [-8.308421857655048, 0.0, -10.736876465380192, -15.206019923090935]
# Position 26: [-14.981786474585533, -10.687271542847157, -15.079241022467613, 0.0]
# Position 27: [-8.441603312268853, 0.0, -15.080213710665703, -15.040663927793503]
# Position 28: [0.0, -15.181018576025963, -15.165641486644745, -15.031044363975525]
# Position 29: [-8.073532421141863, -14.992247343063354, 0.0, -15.053576409816742]
# Position 30: [-15.092699766159058, 0.0, -11.345135627314448, -3.382656466215849]
# Position 31: [-7.61832831799984, -8.97698368690908, -11.118305530399084, 0.0]
# Position 32: [-9.68159643188119, -12.329981778748333, 0.0, -4.815646150149405]
# Position 33: [0.0, -5.288293277844787, -6.287820678204298, -4.099870256148279]
# Position 34: [0.0, -9.353041347116232, -15.121450394392014, -6.550491392612457]
# Position 35: [-6.343857496976852, -8.829890800639987, -2.331563889980316, 0.0]
# Position 36: [-2.3546141143888235, -6.175913233309984, -6.11498171184212, 0.0]
# Position 37: [-1.4973157942295074, -2.2011372735723853, 0.0, -6.45199696905911]
# Position 38: [-8.106619467958808, 0.0, -9.294002560898662, -9.087001010775566]
# Position 39: [-4.98798324726522, -6.238044636324048, 0.0, -6.022555805742741]
# Position 40: [0.0, -15.03246608376503, -14.996756330132484, -15.102234348654747]
# Position 41: [-8.949488156475127, 0.0, -1.648823875002563, -9.241893777623773]
# Position 42: [0.0, -15.050895377993584, -15.101118862628937, -7.923373926430941]
# Position 43: [-8.318119537085295, -5.005974722094834, 0.0, -6.025289632380009]
# Position 44: [-10.540527060627937, 0.0, -15.102926895022392, -15.058534994721413]
# Position 45: [-7.076484648510814, -5.952788991853595, 0.0, -7.306345196440816]
# Position 46: [-7.276908309664577, -4.170426114462316, 0.0, -3.3616930274292827]
# Position 47: [0.0, -6.0373359471559525, -8.385907206684351, -9.092190183699131]
# Position 48: [-5.687661450356245, 0.0, -9.055708531290293, -15.308575242757797]
# Position 49: [-10.355678301304579, -15.205697759985924, 0.0, -15.084346905350685]
# Position 50: [0.0, -15.18673201650381, -5.949911307543516, -8.922869581729174]
# Position 51: [-6.645985446870327, -15.082579135894775, 0.0, -15.04492899775505]
# Position 52: [-15.07469530403614, 0.0, -15.201399609446526, -10.051013490185142]
# Position 53: [-7.764082534238696, -5.5772942253388464, 0.0, -8.760242585092783]
# Position 54: [-8.926516810432076, -5.994870617985725, 0.0, -4.856022844091058]
# Position 55: [-9.483021503314376, -12.717378798872232, 0.0, -5.94481373205781]
# Position 56: [-15.103457525372505, -7.205835856497288, 0.0, -15.14077390730381]
# Position 57: [-9.812536689918488, -15.167450100183487, 0.0, -2.8724094219505787]
# Position 58: [-9.484040473587811, 0.0, -5.300967089831829, -15.333592005074024]
# Position 59: [-9.417893454432487, -8.140889152884483, -10.726614499464631, 0.0]
# Position 60: [-9.161925805732608, 0.0, -3.3457519710063934, -8.489762186072767]
# Position 61: [0.0, -5.022668680176139, -5.175345990806818, -5.732071686536074]
# Position 62: [-6.96057428047061, -7.258390585426241, 0.0, -2.647924415767193]
# Position 63: [0.0, -1.3014670573174953, -1.3407612089067698, 0.6627579350024462]
# Position 64: [-4.805004488676786, 0.0, -0.34102187864482403, -3.83797044493258]
# Position 65: [-5.844754254445434, 0.0, -8.601502941455692, -4.248809158336371]
# Position 66: [-6.300214609131217, 0.0, -7.72937775705941, -15.247934140264988]
# Position 67: [-5.94923597574234, -6.0370502937585115, 0.0, -7.61973680742085]
# Position 68: [-9.697556464001536, 0.0, -8.193549243733287, -15.108738519251347]
# Position 69: [-3.4084097761660814, -3.4026348404586315, 0.0, -4.185484001412988]
# Position 70: [-5.570231262594461, 0.0, -3.538477124646306, -14.987347319722176]
# Position 71: [0.0, -2.99257527384907, -3.673072336241603, -7.438210319727659]
# Position 72: [-4.82531613856554, -5.184749566018581, 0.0, -3.040552747435868]
# Position 73: [-6.614708553999662, -5.399553783237934, 0.0, -6.983710002154112]
# Position 74: [0.0, -5.3937480263412, -4.3030765894800425, -6.635017279535532]
# Position 75: [-15.114760667085648, -15.074783653020859, 0.0, -6.08254636451602]
# Position 76: [0.0, -15.261400692164898, -6.4508815333247185, -15.266658633947372]
# Position 77: [-7.781090852571651, -8.23680654913187, -1.1932113207876682, 0.0]
# Position 78: [0.0, -15.066672518849373, -7.464534783735871, -6.4142729844897985]
# Position 79: [0.0, -7.894936518743634, -7.66937146242708, -7.104824800044298]
# Position 80: [-10.77669333294034, -15.084871664643288, 0.0, -15.133218735456467]
# Position 81: [-9.3323885910213, -15.064226165413857, 0.0, -15.084092184901237]
# Position 82: [-4.716043089982122, -3.229635303840041, 0.0, -4.556624655611813]
# Position 83: [-7.82513015717268, 0.0, -9.594795100390911, -15.166839927434921]
# Position 84: [0.0, -4.271495623514056, -15.422923034057021, -10.656731452792883]
# Position 85: [-8.087735366076231, 0.0, -5.46059525385499, -15.253221340477467]
# Position 86: [0.0, -7.228770203888416, -15.03439062833786, -15.115759626030922]
# Position 87: [-8.309783663600683, -7.410864464938641, -15.149246260523796, 0.0]
# Position 88: [-7.82917071133852, 0.0, -6.1018384248018265, -4.753562597557902]
# Position 89: [-6.001091204583645, -5.999609299004078, 0.0, -4.582768753170967]
# Position 90: [-6.697970561683178, -3.5690470281988382, 0.0, -15.507951678708196]
# Position 91: [0.0, -7.960727773606777, -8.415324157569557, -8.805117657408118]
# Position 92: [0.0, -6.671047427691519, -5.423410840332508, -5.77898752130568]
# Position 93: [0.0, -1.9300910958554596, -7.950536452233791, -12.06753658875823]
# Position 94: [-15.170296147465706, 0.0, -8.866784878075123, -15.192953795194626]
# Position 95: [-8.31280779838562, 0.0, -8.550135157071054, -6.095293398946524]
# Position 96: [-7.501941399648786, -8.065920670516789, 0.0, -5.233797535300255]
# Position 97: [-7.679179400205612, -7.727255713194609, 0.0, -15.091891571879387]
# Position 98: [-6.72287059482187, 0.0, -6.89091314189136, -8.468544648960233]
# Position 99: [-4.999852022156119, 0.0, -11.621473886072636, -15.011783376336098]
#
# Delta Delta E per pair:
# (1, 2, 7.2326283)
# (1, 2, 2.9241257)
# (1, 2, 3.93154)
# (1, 3, 6.6832037)
# (1, 3, 2.4686303)
# (1, 3, 2.352008)
# (1, 4, 1.6059126)
# (1, 4, -0.9539559)
# (1, 4, -0.25767866)
# (1, 5, -0.2764675)

# %%
import numpy as np
from collections import Counter

# Define the alphabet
alphabet = ['A', 'B', 'C', 'D']

# Read the sequences from the file
with open('data/pr.exper.reduce4.seq', 'r') as f:
    sequences = f.readlines()

# Remove any whitespace characters (e.g., newlines) from the sequences
sequences = [seq.strip() for seq in sequences]

# Initialize a list to store the frequency arrays
frequency_list = []

# Calculate the frequency for each position
sequence_length = len(sequences[0])  # Assume all sequences have the same length
sequence_count = len(sequences)
print(f"Total number of sequences: {sequence_count}")
for i in range(sequence_length):
    # Count the occurrences of each alphabet at the current position
    position_counts = Counter(seq[i] for seq in sequences)
    # Calculate the frequency for each alphabet
    frequencies = [position_counts[char] / sequence_count for char in alphabet]
    
    # Append the frequencies to the list
    frequency_list.append(frequencies)

# Convert the list to a NumPy array
frequency_array = np.array(frequency_list)

# Save the array to a .npy file
np.save('data/frequency.npy', frequency_array)

print("Frequency array saved to 'data/frequency.npy'")
# Out:
# Total number of sequences: 5710
# Frequency array saved to 'data/frequency.npy'

# %%
# Read the data from the file again
data = np.load("data/frequency.npy")  # Shape: (263, 4)

# Get the second largest value index for each row
second_largest_indices = []
for row in data:
    sorted_indices = np.argsort(row)[::-1]  # Sort indices in descending order of values
    if row[sorted_indices[1]] > 0:  # Check if the second largest value is not 0
        second_largest_indices.append(sorted_indices[1])
    else:
        second_largest_indices.append(None)

# Print the result
print("Second largest value indices (or None if second largest is 0):")
print(second_largest_indices)
# Out:
# Second largest value indices (or None if second largest is 0):
# [np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(1), np.int64(3), np.int64(2), np.int64(2), np.int64(1), np.int64(3), np.int64(1), np.int64(2), np.int64(3), np.int64(3), np.int64(1), np.int64(3), np.int64(0), np.int64(1), np.int64(0), None, np.int64(0), np.int64(3), np.int64(1), np.int64(3), np.int64(1), np.int64(3), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(0), None, np.int64(2), np.int64(3), np.int64(3), np.int64(0), np.int64(1), np.int64(3), np.int64(1), np.int64(0), np.int64(0), np.int64(2), np.int64(0), np.int64(3), np.int64(1), np.int64(3), np.int64(3), np.int64(1), np.int64(3), np.int64(2), np.int64(0), np.int64(2), np.int64(2), np.int64(3), np.int64(0), np.int64(2), np.int64(3), np.int64(0), np.int64(1), np.int64(2), np.int64(0), np.int64(2), np.int64(1), np.int64(3), np.int64(1), np.int64(2), np.int64(3), np.int64(2), np.int64(2), np.int64(3), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(2), np.int64(1), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(1), np.int64(2), np.int64(2), np.int64(3), np.int64(1), np.int64(0), np.int64(0)]

# %%
filtered_delta_e_values = []

for pos, index in enumerate(second_largest_indices):
    if index is not None:
        # Retrieve the delta E value at the given position and index
        filtered_delta_e_values.append(delta_e_per_position[pos + 1][index])
    else:
        # If index is None, append 0
        filtered_delta_e_values.append(0.0)

# %%
# Create a dictionary to store the filtered delta E values for each position
def filter_delta_e_by_positions(delta_e_per_position):
    """
    Filter delta E values for specific positions.

    Parameters:
    delta_e_per_position (dict): Dictionary containing delta E values for each position.
    positions_to_filter (list): List of positions to filter.

    Returns:
    dict: A dictionary containing filtered delta E values for the specified positions.
    """
    # mutation_map = {'A': 0, 'B': 1, 'C': 2, 'D': 3}
    mutation_map_re = {0: 'A', 1: 'B', 2: 'C', 3: 'D'}
    filtered_delta_e_dict = collections.defaultdict(list)
    PR_redux_dict = get_redu_dict(PR_path+'data/pr.reduce4.redux',0)
    PR_unreduced_seq = read_seq(PR_unreduced_seq_path)
    for pos in range(1, actual_length + 1):
        curr_Wildtype = mutation_map_re[[i for i in range(4) if delta_e_per_position[pos][i] == 0.0][0]] # Get the wildtype amino acid for the current position
        for index in range(4):

            curr_Mutant = mutation_map_re[index]
            reduced_pair = (f"{curr_Wildtype}{pos}{curr_Mutant}")
            unreduced_pair = reduced_to_unreduced(PR_redux_dict,reduced_pair, PR_unreduced_seq)
            unreduced_mutant = unreduced_pair[-1]
            unreduced_pos = int(re.findall(r'\d+', unreduced_pair)[0])
            
            if delta_e_per_position[pos][index] != 0.0 and (calculate_freq(unreduced_mutant,unreduced_pos, PR_unreduced_seq) > 1/len(PR_unreduced_seq)):
                filtered_delta_e_dict[pos].append(delta_e_per_position[pos][index])
                print(f"Position: {pos}, Wildtype: {curr_Wildtype}, Mutant: {curr_Mutant}, Reduced Pair: {reduced_pair}, Unreduced Pair: {unreduced_pair}, Delta E: {delta_e_per_position[pos][index]}, Frequency: {calculate_freq(unreduced_mutant,unreduced_pos, PR_unreduced_seq)}")
    return filtered_delta_e_dict

# filtered_delta_e_dict[pos].append(delta_e_per_position[pos][index])
filtered_delta_e_dict = filter_delta_e_by_positions(delta_e_per_position)
# Print the filtered delta E dictionary
print("Filtered delta E dictionary:")
for pos, values in filtered_delta_e_dict.items():
    print(f"Position {pos}: {values}")
# Out:
# Position: 2, Wildtype: C, Mutant: D, Reduced Pair: C2D, Unreduced Pair: Q2K, Delta E: -8.569090587086976, Frequency: 0.0003502626970227671
# Position: 3, Wildtype: C, Mutant: D, Reduced Pair: C3D, Unreduced Pair: I3V, Delta E: -8.155805517919362, Frequency: 0.0010507880910683013
# Position: 4, Wildtype: D, Mutant: B, Reduced Pair: D4B, Unreduced Pair: T4P, Delta E: -9.062162205576897, Frequency: 0.0024518388791593695
# Position: 4, Wildtype: D, Mutant: C, Reduced Pair: D4C, Unreduced Pair: T4S, Delta E: -5.582528863102198, Frequency: 0.0028021015761821367
# Position: 5, Wildtype: D, Mutant: B, Reduced Pair: D5B, Unreduced Pair: L5F, Delta E: -8.509819394443184, Frequency: 0.0010507880910683013
# Position: 6, Wildtype: D, Mutant: B, Reduced Pair: D6B, Unreduced Pair: W6L, Delta E: -10.011449309065938, Frequency: 0.0007005253940455342
# Position: 6, Wildtype: D, Mutant: C, Reduced Pair: D6C, Unreduced Pair: W6S, Delta E: -10.609377598389983, Frequency: 0.0003502626970227671
# Position: 7, Wildtype: C, Mutant: A, Reduced Pair: C7A, Unreduced Pair: Q7H, Delta E: -8.150218181312084, Frequency: 0.0012259194395796847
# Position: 7, Wildtype: C, Mutant: B, Reduced Pair: C7B, Unreduced Pair: Q7E, Delta E: -6.7850492196157575, Frequency: 0.0007005253940455342
# Position: 7, Wildtype: C, Mutant: D, Reduced Pair: C7D, Unreduced Pair: Q7R, Delta E: -6.993757659569383, Frequency: 0.0008756567425569177
# Position: 8, Wildtype: D, Mutant: A, Reduced Pair: D8A, Unreduced Pair: R8Q, Delta E: -7.00242667645216, Frequency: 0.0012259194395796847
# Position: 10, Wildtype: D, Mutant: A, Reduced Pair: D10A, Unreduced Pair: L10V, Delta E: -4.653488149866462, Frequency: 0.06234676007005254
# Position: 10, Wildtype: D, Mutant: B, Reduced Pair: D10B, Unreduced Pair: L10F, Delta E: -5.01730927452445, Frequency: 0.07302977232924694
# Position: 10, Wildtype: D, Mutant: C, Reduced Pair: D10C, Unreduced Pair: L10I, Delta E: -3.001409363001585, Frequency: 0.3299474605954466
# Position: 11, Wildtype: D, Mutant: A, Reduced Pair: D11A, Unreduced Pair: V11I, Delta E: -6.655691193416715, Frequency: 0.019439579684763574
# Position: 11, Wildtype: D, Mutant: B, Reduced Pair: D11B, Unreduced Pair: V11A, Delta E: -8.730066085234284, Frequency: 0.0005253940455341507
# Position: 11, Wildtype: D, Mutant: C, Reduced Pair: D11C, Unreduced Pair: V11L, Delta E: -9.590635046362877, Frequency: 0.0043782837127845885
# Position: 12, Wildtype: D, Mutant: A, Reduced Pair: D12A, Unreduced Pair: T12A, Delta E: -4.187727555632591, Frequency: 0.012784588441330999
# Position: 12, Wildtype: D, Mutant: B, Reduced Pair: D12B, Unreduced Pair: T12S, Delta E: -2.6436189003288746, Frequency: 0.026970227670753064
# Position: 12, Wildtype: D, Mutant: C, Reduced Pair: D12C, Unreduced Pair: T12P, Delta E: -5.369526390917599, Frequency: 0.03064798598949212
# Position: 13, Wildtype: D, Mutant: A, Reduced Pair: D13A, Unreduced Pair: I13L, Delta E: -8.335788495838642, Frequency: 0.0005253940455341507
# Position: 13, Wildtype: D, Mutant: B, Reduced Pair: D13B, Unreduced Pair: I13V, Delta E: -2.0054782573133707, Frequency: 0.20788091068301226
# Position: 13, Wildtype: D, Mutant: C, Reduced Pair: D13C, Unreduced Pair: I13M, Delta E: -10.403790419921279, Frequency: 0.0017513134851138354
# Position: 14, Wildtype: C, Mutant: A, Reduced Pair: C14A, Unreduced Pair: K14T, Delta E: -6.144697094336152, Frequency: 0.0008756567425569177
# Position: 14, Wildtype: C, Mutant: B, Reduced Pair: C14B, Unreduced Pair: K14E, Delta E: -7.580942366272211, Frequency: 0.0010507880910683013
# Position: 14, Wildtype: C, Mutant: D, Reduced Pair: C14D, Unreduced Pair: K14R, Delta E: -2.5640227664262056, Frequency: 0.08704028021015763
# Position: 15, Wildtype: D, Mutant: B, Reduced Pair: D15B, Unreduced Pair: I15L, Delta E: -6.1875506937503815, Frequency: 0.0021015761821366026
# Position: 15, Wildtype: D, Mutant: C, Reduced Pair: D15C, Unreduced Pair: I15V, Delta E: -1.2176780756562948, Frequency: 0.18476357267950963
# Position: 16, Wildtype: D, Mutant: A, Reduced Pair: D16A, Unreduced Pair: G16R, Delta E: -9.739111291244626, Frequency: 0.0003502626970227671
# Position: 16, Wildtype: D, Mutant: B, Reduced Pair: D16B, Unreduced Pair: G16A, Delta E: -5.409278167411685, Frequency: 0.018038528896672505
# Position: 16, Wildtype: D, Mutant: C, Reduced Pair: D16C, Unreduced Pair: G16E, Delta E: -4.092847662046552, Frequency: 0.02924693520140105
# Position: 17, Wildtype: A, Mutant: B, Reduced Pair: A17B, Unreduced Pair: G17E, Delta E: -5.095459245145321, Frequency: 0.006479859894921191
# Position: 17, Wildtype: A, Mutant: C, Reduced Pair: A17C, Unreduced Pair: G17D, Delta E: -5.417207387275994, Frequency: 0.003327495621716287
# Position: 18, Wildtype: B, Mutant: A, Reduced Pair: B18A, Unreduced Pair: Q18E, Delta E: -6.523982964456081, Frequency: 0.002276707530647986
# Position: 18, Wildtype: B, Mutant: C, Reduced Pair: B18C, Unreduced Pair: Q18L, Delta E: -5.552409275434911, Frequency: 0.003852889667250438
# Position: 18, Wildtype: B, Mutant: D, Reduced Pair: B18D, Unreduced Pair: Q18H, Delta E: -6.132597170770168, Frequency: 0.01436077057793345
# Position: 19, Wildtype: C, Mutant: A, Reduced Pair: C19A, Unreduced Pair: L19Q, Delta E: -3.9864791333675385, Frequency: 0.011908931698774081
# Position: 19, Wildtype: C, Mutant: B, Reduced Pair: C19B, Unreduced Pair: L19I, Delta E: -2.290499497205019, Frequency: 0.07653239929947461
# Position: 19, Wildtype: C, Mutant: D, Reduced Pair: C19D, Unreduced Pair: L19V, Delta E: -4.586674952879548, Frequency: 0.012784588441330999
# Position: 20, Wildtype: D, Mutant: A, Reduced Pair: D20A, Unreduced Pair: K20I, Delta E: -4.384629253298044, Frequency: 0.05604203152364273
# Position: 20, Wildtype: D, Mutant: B, Reduced Pair: D20B, Unreduced Pair: K20M, Delta E: -7.058664083480835, Frequency: 0.018213660245183887
# Position: 20, Wildtype: D, Mutant: C, Reduced Pair: D20C, Unreduced Pair: K20R, Delta E: -6.121196448802948, Frequency: 0.11033274956217162
# Position: 21, Wildtype: A, Mutant: C, Reduced Pair: A21C, Unreduced Pair: E21Q, Delta E: -10.824223658069968, Frequency: 0.0005253940455341507
# Position: 21, Wildtype: A, Mutant: D, Reduced Pair: A21D, Unreduced Pair: E21K, Delta E: -10.730192564427853, Frequency: 0.0005253940455341507
# Position: 22, Wildtype: B, Mutant: D, Reduced Pair: B22D, Unreduced Pair: A22V, Delta E: -7.664188075810671, Frequency: 0.004203152364273205
# Position: 23, Wildtype: C, Mutant: B, Reduced Pair: C23B, Unreduced Pair: L23I, Delta E: -7.098663568496704, Frequency: 0.009632224168126095
# Position: 24, Wildtype: A, Mutant: B, Reduced Pair: A24B, Unreduced Pair: L24S, Delta E: -11.017500375397503, Frequency: 0.0003502626970227671
# Position: 24, Wildtype: A, Mutant: C, Reduced Pair: A24C, Unreduced Pair: L24F, Delta E: -9.962894095107913, Frequency: 0.004553415061295972
# Position: 24, Wildtype: A, Mutant: D, Reduced Pair: A24D, Unreduced Pair: L24I, Delta E: -5.855606945231557, Frequency: 0.05919439579684763
# Position: 25, Wildtype: B, Mutant: A, Reduced Pair: B25A, Unreduced Pair: D25G, Delta E: -8.308421857655048, Frequency: 0.0005253940455341507
# Position: 30, Wildtype: B, Mutant: D, Reduced Pair: B30D, Unreduced Pair: D30N, Delta E: -3.382656466215849, Frequency: 0.07250437828371278
# Position: 32, Wildtype: C, Mutant: D, Reduced Pair: C32D, Unreduced Pair: V32I, Delta E: -4.815646150149405, Frequency: 0.04868651488616462
# Position: 33, Wildtype: A, Mutant: B, Reduced Pair: A33B, Unreduced Pair: L33F, Delta E: -5.288293277844787, Frequency: 0.08756567425569177
# Position: 33, Wildtype: A, Mutant: C, Reduced Pair: A33C, Unreduced Pair: L33I, Delta E: -6.287820678204298, Frequency: 0.016637478108581436
# Position: 33, Wildtype: A, Mutant: D, Reduced Pair: A33D, Unreduced Pair: L33V, Delta E: -4.099870256148279, Frequency: 0.013134851138353765
# Position: 34, Wildtype: A, Mutant: B, Reduced Pair: A34B, Unreduced Pair: E34V, Delta E: -9.353041347116232, Frequency: 0.0005253940455341507
# Position: 34, Wildtype: A, Mutant: D, Reduced Pair: A34D, Unreduced Pair: E34K, Delta E: -6.550491392612457, Frequency: 0.0036777583187390544
# Position: 35, Wildtype: D, Mutant: A, Reduced Pair: D35A, Unreduced Pair: E35G, Delta E: -6.343857496976852, Frequency: 0.005954465849387041
# Position: 35, Wildtype: D, Mutant: B, Reduced Pair: D35B, Unreduced Pair: E35N, Delta E: -8.829890800639987, Frequency: 0.004203152364273205
# Position: 35, Wildtype: D, Mutant: C, Reduced Pair: D35C, Unreduced Pair: E35D, Delta E: -2.331563889980316, Frequency: 0.30122591943957966
# Position: 36, Wildtype: D, Mutant: A, Reduced Pair: D36A, Unreduced Pair: M36I, Delta E: -2.3546141143888235, Frequency: 0.2873905429071804
# Position: 36, Wildtype: D, Mutant: B, Reduced Pair: D36B, Unreduced Pair: M36L, Delta E: -6.175913233309984, Frequency: 0.016637478108581436
# Position: 36, Wildtype: D, Mutant: C, Reduced Pair: D36C, Unreduced Pair: M36V, Delta E: -6.11498171184212, Frequency: 0.01838879159369527
# Position: 37, Wildtype: C, Mutant: A, Reduced Pair: C37A, Unreduced Pair: N37S, Delta E: -1.4973157942295074, Frequency: 0.09877408056042032
# Position: 37, Wildtype: C, Mutant: B, Reduced Pair: C37B, Unreduced Pair: N37D, Delta E: -2.2011372735723853, Frequency: 0.14500875656742557
# Position: 37, Wildtype: C, Mutant: D, Reduced Pair: C37D, Unreduced Pair: N37Y, Delta E: -6.45199696905911, Frequency: 0.002276707530647986
# Position: 38, Wildtype: B, Mutant: A, Reduced Pair: B38A, Unreduced Pair: L38F, Delta E: -8.106619467958808, Frequency: 0.0003502626970227671
# Position: 38, Wildtype: B, Mutant: C, Reduced Pair: B38C, Unreduced Pair: L38I, Delta E: -9.294002560898662, Frequency: 0.0005253940455341507
# Position: 38, Wildtype: B, Mutant: D, Reduced Pair: B38D, Unreduced Pair: L38V, Delta E: -9.087001010775566, Frequency: 0.0003502626970227671
# Position: 39, Wildtype: C, Mutant: A, Reduced Pair: C39A, Unreduced Pair: P39S, Delta E: -4.98798324726522, Frequency: 0.012434325744308231
# Position: 39, Wildtype: C, Mutant: B, Reduced Pair: C39B, Unreduced Pair: P39Q, Delta E: -6.238044636324048, Frequency: 0.004028021015761821
# Position: 39, Wildtype: C, Mutant: D, Reduced Pair: C39D, Unreduced Pair: P39T, Delta E: -6.022555805742741, Frequency: 0.0017513134851138354
# Position: 41, Wildtype: B, Mutant: A, Reduced Pair: B41A, Unreduced Pair: R41P, Delta E: -8.949488156475127, Frequency: 0.0005253940455341507
# Position: 41, Wildtype: B, Mutant: C, Reduced Pair: B41C, Unreduced Pair: R41K, Delta E: -1.648823875002563, Frequency: 0.1980735551663748
# Position: 41, Wildtype: B, Mutant: D, Reduced Pair: B41D, Unreduced Pair: R41N, Delta E: -9.241893777623773, Frequency: 0.0008756567425569177
# Position: 42, Wildtype: A, Mutant: D, Reduced Pair: A42D, Unreduced Pair: W42Y, Delta E: -7.923373926430941, Frequency: 0.0008756567425569177
# Position: 43, Wildtype: C, Mutant: A, Reduced Pair: C43A, Unreduced Pair: K43Q, Delta E: -8.318119537085295, Frequency: 0.0012259194395796847
# Position: 43, Wildtype: C, Mutant: B, Reduced Pair: C43B, Unreduced Pair: K43R, Delta E: -5.005974722094834, Frequency: 0.014535901926444834
# Position: 43, Wildtype: C, Mutant: D, Reduced Pair: C43D, Unreduced Pair: K43T, Delta E: -6.025289632380009, Frequency: 0.043432574430823115
# Position: 45, Wildtype: C, Mutant: A, Reduced Pair: C45A, Unreduced Pair: K45V, Delta E: -7.076484648510814, Frequency: 0.0010507880910683013
# Position: 45, Wildtype: C, Mutant: B, Reduced Pair: C45B, Unreduced Pair: K45R, Delta E: -5.952788991853595, Frequency: 0.019089316987740804
# Position: 45, Wildtype: C, Mutant: D, Reduced Pair: C45D, Unreduced Pair: K45Q, Delta E: -7.306345196440816, Frequency: 0.0031523642732049035
# Position: 46, Wildtype: C, Mutant: A, Reduced Pair: C46A, Unreduced Pair: M46V, Delta E: -7.276908309664577, Frequency: 0.0029772329246935203
# Position: 46, Wildtype: C, Mutant: B, Reduced Pair: C46B, Unreduced Pair: M46L, Delta E: -4.170426114462316, Frequency: 0.09964973730297723
# Position: 46, Wildtype: C, Mutant: D, Reduced Pair: C46D, Unreduced Pair: M46I, Delta E: -3.3616930274292827, Frequency: 0.2136602451838879
# Position: 47, Wildtype: A, Mutant: B, Reduced Pair: A47B, Unreduced Pair: I47V, Delta E: -6.0373359471559525, Frequency: 0.03590192644483362
# Position: 48, Wildtype: B, Mutant: A, Reduced Pair: B48A, Unreduced Pair: G48V, Delta E: -5.687661450356245, Frequency: 0.046935201401050786
# Position: 48, Wildtype: B, Mutant: C, Reduced Pair: B48C, Unreduced Pair: G48E, Delta E: -9.055708531290293, Frequency: 0.0007005253940455342
# Position: 50, Wildtype: A, Mutant: C, Reduced Pair: A50C, Unreduced Pair: I50V, Delta E: -5.949911307543516, Frequency: 0.01576182136602452
# Position: 51, Wildtype: C, Mutant: A, Reduced Pair: C51A, Unreduced Pair: G51A, Delta E: -6.645985446870327, Frequency: 0.0021015761821366026
# Position: 53, Wildtype: C, Mutant: A, Reduced Pair: C53A, Unreduced Pair: F53I, Delta E: -7.764082534238696, Frequency: 0.0017513134851138354
# Position: 53, Wildtype: C, Mutant: B, Reduced Pair: C53B, Unreduced Pair: F53L, Delta E: -5.5772942253388464, Frequency: 0.043432574430823115
# Position: 53, Wildtype: C, Mutant: D, Reduced Pair: C53D, Unreduced Pair: F53Y, Delta E: -8.760242585092783, Frequency: 0.0035026269702276708
# Position: 54, Wildtype: C, Mutant: A, Reduced Pair: C54A, Unreduced Pair: I54A, Delta E: -8.926516810432076, Frequency: 0.011208406304728547
# Position: 54, Wildtype: C, Mutant: B, Reduced Pair: C54B, Unreduced Pair: I54L, Delta E: -5.994870617985725, Frequency: 0.02136602451838879
# Position: 54, Wildtype: C, Mutant: D, Reduced Pair: C54D, Unreduced Pair: I54V, Delta E: -4.856022844091058, Frequency: 0.23380035026269702
# Position: 55, Wildtype: C, Mutant: A, Reduced Pair: C55A, Unreduced Pair: K55N, Delta E: -9.483021503314376, Frequency: 0.001926444833625219
# Position: 55, Wildtype: C, Mutant: D, Reduced Pair: C55D, Unreduced Pair: K55R, Delta E: -5.94481373205781, Frequency: 0.05201401050788091
# Position: 57, Wildtype: C, Mutant: D, Reduced Pair: C57D, Unreduced Pair: R57K, Delta E: -2.8724094219505787, Frequency: 0.11786339754816112
# Position: 58, Wildtype: B, Mutant: C, Reduced Pair: B58C, Unreduced Pair: Q58E, Delta E: -5.300967089831829, Frequency: 0.05131348511383538
# Position: 59, Wildtype: D, Mutant: A, Reduced Pair: D59A, Unreduced Pair: Y59F, Delta E: -9.417893454432487, Frequency: 0.0005253940455341507
# Position: 59, Wildtype: D, Mutant: B, Reduced Pair: D59B, Unreduced Pair: Y59H, Delta E: -8.140889152884483, Frequency: 0.0003502626970227671
# Position: 60, Wildtype: B, Mutant: A, Reduced Pair: B60A, Unreduced Pair: D60N, Delta E: -9.161925805732608, Frequency: 0.0014010507880910684
# Position: 60, Wildtype: B, Mutant: C, Reduced Pair: B60C, Unreduced Pair: D60E, Delta E: -3.3457519710063934, Frequency: 0.08739054290718039
# Position: 61, Wildtype: A, Mutant: B, Reduced Pair: A61B, Unreduced Pair: Q61D, Delta E: -5.022668680176139, Frequency: 0.007355516637478109
# Position: 61, Wildtype: A, Mutant: C, Reduced Pair: A61C, Unreduced Pair: Q61E, Delta E: -5.175345990806818, Frequency: 0.026795096322241682
# Position: 61, Wildtype: A, Mutant: D, Reduced Pair: A61D, Unreduced Pair: Q61N, Delta E: -5.732071686536074, Frequency: 0.012434325744308231
# Position: 62, Wildtype: C, Mutant: A, Reduced Pair: C62A, Unreduced Pair: I62M, Delta E: -6.96057428047061, Frequency: 0.0017513134851138354
# Position: 62, Wildtype: C, Mutant: B, Reduced Pair: C62B, Unreduced Pair: I62K, Delta E: -7.258390585426241, Frequency: 0.0007005253940455342
# Position: 62, Wildtype: C, Mutant: D, Reduced Pair: C62D, Unreduced Pair: I62V, Delta E: -2.647924415767193, Frequency: 0.32171628721541157
# Position: 63, Wildtype: A, Mutant: B, Reduced Pair: A63B, Unreduced Pair: L63A, Delta E: -1.3014670573174953, Frequency: 0.03204903677758319
# Position: 63, Wildtype: A, Mutant: C, Reduced Pair: A63C, Unreduced Pair: L63S, Delta E: -1.3407612089067698, Frequency: 0.028896672504378284
# Position: 63, Wildtype: A, Mutant: D, Reduced Pair: A63D, Unreduced Pair: L63P, Delta E: 0.6627579350024462, Frequency: 0.7138353765323993
# Position: 64, Wildtype: B, Mutant: A, Reduced Pair: B64A, Unreduced Pair: I64M, Delta E: -4.805004488676786, Frequency: 0.012259194395796848
# Position: 64, Wildtype: B, Mutant: C, Reduced Pair: B64C, Unreduced Pair: I64V, Delta E: -0.34102187864482403, Frequency: 0.18371278458844134
# Position: 64, Wildtype: B, Mutant: D, Reduced Pair: B64D, Unreduced Pair: I64L, Delta E: -3.83797044493258, Frequency: 0.021541155866900176
# Position: 65, Wildtype: B, Mutant: A, Reduced Pair: B65A, Unreduced Pair: E65K, Delta E: -5.844754254445434, Frequency: 0.0007005253940455342
# Position: 65, Wildtype: B, Mutant: D, Reduced Pair: B65D, Unreduced Pair: E65D, Delta E: -4.248809158336371, Frequency: 0.015586690017513135
# Position: 66, Wildtype: B, Mutant: A, Reduced Pair: B66A, Unreduced Pair: I66F, Delta E: -6.300214609131217, Frequency: 0.012259194395796848
# Position: 66, Wildtype: B, Mutant: C, Reduced Pair: B66C, Unreduced Pair: I66V, Delta E: -7.72937775705941, Frequency: 0.007530647985989492
# Position: 67, Wildtype: C, Mutant: A, Reduced Pair: C67A, Unreduced Pair: C67S, Delta E: -5.94923597574234, Frequency: 0.007180385288966725
# Position: 67, Wildtype: C, Mutant: B, Reduced Pair: C67B, Unreduced Pair: C67F, Delta E: -6.0370502937585115, Frequency: 0.009457092819614711
# Position: 67, Wildtype: C, Mutant: D, Reduced Pair: C67D, Unreduced Pair: C67D, Delta E: -7.61973680742085, Frequency: 0.0036777583187390544
# Position: 68, Wildtype: B, Mutant: A, Reduced Pair: B68A, Unreduced Pair: G68D, Delta E: -9.697556464001536, Frequency: 0.0005253940455341507
# Position: 68, Wildtype: B, Mutant: C, Reduced Pair: B68C, Unreduced Pair: G68E, Delta E: -8.193549243733287, Frequency: 0.0035026269702276708
# Position: 69, Wildtype: C, Mutant: A, Reduced Pair: C69A, Unreduced Pair: H69K, Delta E: -3.4084097761660814, Frequency: 0.023117338003502626
# Position: 69, Wildtype: C, Mutant: B, Reduced Pair: C69B, Unreduced Pair: H69Q, Delta E: -3.4026348404586315, Frequency: 0.02574430823117338
# Position: 69, Wildtype: C, Mutant: D, Reduced Pair: C69D, Unreduced Pair: H69Y, Delta E: -4.185484001412988, Frequency: 0.014535901926444834
# Position: 70, Wildtype: B, Mutant: A, Reduced Pair: B70A, Unreduced Pair: K70T, Delta E: -5.570231262594461, Frequency: 0.004728546409807356
# Position: 70, Wildtype: B, Mutant: C, Reduced Pair: B70C, Unreduced Pair: K70R, Delta E: -3.538477124646306, Frequency: 0.022066549912434327
# Position: 71, Wildtype: A, Mutant: B, Reduced Pair: A71B, Unreduced Pair: A71V, Delta E: -2.99257527384907, Frequency: 0.29614711033274954
# Position: 71, Wildtype: A, Mutant: C, Reduced Pair: A71C, Unreduced Pair: A71T, Delta E: -3.673072336241603, Frequency: 0.09439579684763573
# Position: 71, Wildtype: A, Mutant: D, Reduced Pair: A71D, Unreduced Pair: A71I, Delta E: -7.438210319727659, Frequency: 0.02119089316987741
# Position: 72, Wildtype: C, Mutant: A, Reduced Pair: C72A, Unreduced Pair: I72T, Delta E: -4.82531613856554, Frequency: 0.03817863397548161
# Position: 72, Wildtype: C, Mutant: B, Reduced Pair: C72B, Unreduced Pair: I72L, Delta E: -5.184749566018581, Frequency: 0.01838879159369527
# Position: 72, Wildtype: C, Mutant: D, Reduced Pair: C72D, Unreduced Pair: I72V, Delta E: -3.040552747435868, Frequency: 0.08739054290718039
# Position: 73, Wildtype: C, Mutant: A, Reduced Pair: C73A, Unreduced Pair: G73C, Delta E: -6.614708553999662, Frequency: 0.009632224168126095
# Position: 73, Wildtype: C, Mutant: B, Reduced Pair: C73B, Unreduced Pair: G73S, Delta E: -5.399553783237934, Frequency: 0.08248686514886165
# Position: 73, Wildtype: C, Mutant: D, Reduced Pair: C73D, Unreduced Pair: G73T, Delta E: -6.983710002154112, Frequency: 0.025394045534150613
# Position: 74, Wildtype: A, Mutant: B, Reduced Pair: A74B, Unreduced Pair: T74A, Delta E: -5.3937480263412, Frequency: 0.008756567425569177
# Position: 74, Wildtype: A, Mutant: C, Reduced Pair: A74C, Unreduced Pair: T74S, Delta E: -4.3030765894800425, Frequency: 0.040280210157618214
# Position: 74, Wildtype: A, Mutant: D, Reduced Pair: A74D, Unreduced Pair: T74K, Delta E: -6.635017279535532, Frequency: 0.0024518388791593695
# Position: 75, Wildtype: C, Mutant: D, Reduced Pair: C75D, Unreduced Pair: V75I, Delta E: -6.08254636451602, Frequency: 0.005779334500875657
# Position: 76, Wildtype: A, Mutant: C, Reduced Pair: A76C, Unreduced Pair: L76V, Delta E: -6.4508815333247185, Frequency: 0.033800350262697024
# Position: 77, Wildtype: D, Mutant: A, Reduced Pair: D77A, Unreduced Pair: V77T, Delta E: -7.781090852571651, Frequency: 0.0010507880910683013
# Position: 77, Wildtype: D, Mutant: B, Reduced Pair: D77B, Unreduced Pair: V77L, Delta E: -8.23680654913187, Frequency: 0.0007005253940455342
# Position: 77, Wildtype: D, Mutant: C, Reduced Pair: D77C, Unreduced Pair: V77I, Delta E: -1.1932113207876682, Frequency: 0.30542907180385287
# Position: 78, Wildtype: A, Mutant: D, Reduced Pair: A78D, Unreduced Pair: G78R, Delta E: -6.4142729844897985, Frequency: 0.0005253940455341507
# Position: 79, Wildtype: A, Mutant: B, Reduced Pair: A79B, Unreduced Pair: P79A, Delta E: -7.894936518743634, Frequency: 0.006479859894921191
# Position: 79, Wildtype: A, Mutant: C, Reduced Pair: A79C, Unreduced Pair: P79D, Delta E: -7.66937146242708, Frequency: 0.0029772329246935203
# Position: 79, Wildtype: A, Mutant: D, Reduced Pair: A79D, Unreduced Pair: P79S, Delta E: -7.104824800044298, Frequency: 0.0021015761821366026
# Position: 82, Wildtype: C, Mutant: A, Reduced Pair: C82A, Unreduced Pair: V82T, Delta E: -4.716043089982122, Frequency: 0.03222416812609457
# Position: 82, Wildtype: C, Mutant: B, Reduced Pair: C82B, Unreduced Pair: V82A, Delta E: -3.229635303840041, Frequency: 0.2404553415061296
# Position: 82, Wildtype: C, Mutant: D, Reduced Pair: C82D, Unreduced Pair: V82I, Delta E: -4.556624655611813, Frequency: 0.014010507880910683
# Position: 83, Wildtype: B, Mutant: A, Reduced Pair: B83A, Unreduced Pair: N83D, Delta E: -7.82513015717268, Frequency: 0.003852889667250438
# Position: 83, Wildtype: B, Mutant: C, Reduced Pair: B83C, Unreduced Pair: N83S, Delta E: -9.594795100390911, Frequency: 0.0012259194395796847
# Position: 84, Wildtype: A, Mutant: B, Reduced Pair: A84B, Unreduced Pair: I84V, Delta E: -4.271495623514056, Frequency: 0.1329246935201401
# Position: 84, Wildtype: A, Mutant: D, Reduced Pair: A84D, Unreduced Pair: I84L, Delta E: -10.656731452792883, Frequency: 0.0005253940455341507
# Position: 85, Wildtype: B, Mutant: C, Reduced Pair: B85C, Unreduced Pair: I85V, Delta E: -5.46059525385499, Frequency: 0.037478108581436076
# Position: 87, Wildtype: D, Mutant: A, Reduced Pair: D87A, Unreduced Pair: R87S, Delta E: -8.309783663600683, Frequency: 0.0007005253940455342
# Position: 87, Wildtype: D, Mutant: B, Reduced Pair: D87B, Unreduced Pair: R87K, Delta E: -7.410864464938641, Frequency: 0.0007005253940455342
# Position: 88, Wildtype: B, Mutant: A, Reduced Pair: B88A, Unreduced Pair: N88T, Delta E: -7.82917071133852, Frequency: 0.0015761821366024518
# Position: 88, Wildtype: B, Mutant: C, Reduced Pair: B88C, Unreduced Pair: N88D, Delta E: -6.1018384248018265, Frequency: 0.050087565674255694
# Position: 88, Wildtype: B, Mutant: D, Reduced Pair: B88D, Unreduced Pair: N88S, Delta E: -4.753562597557902, Frequency: 0.012959719789842382
# Position: 89, Wildtype: C, Mutant: A, Reduced Pair: C89A, Unreduced Pair: L89V, Delta E: -6.001091204583645, Frequency: 0.02416812609457093
# Position: 89, Wildtype: C, Mutant: B, Reduced Pair: C89B, Unreduced Pair: L89I, Delta E: -5.999609299004078, Frequency: 0.005779334500875657
# Position: 89, Wildtype: C, Mutant: D, Reduced Pair: C89D, Unreduced Pair: L89M, Delta E: -4.582768753170967, Frequency: 0.014010507880910683
# Position: 90, Wildtype: C, Mutant: A, Reduced Pair: C90A, Unreduced Pair: L90V, Delta E: -6.697970561683178, Frequency: 0.0003502626970227671
# Position: 90, Wildtype: C, Mutant: B, Reduced Pair: C90B, Unreduced Pair: L90M, Delta E: -3.5690470281988382, Frequency: 0.31436077057793343
# Position: 91, Wildtype: A, Mutant: B, Reduced Pair: A91B, Unreduced Pair: T91A, Delta E: -7.960727773606777, Frequency: 0.0029772329246935203
# Position: 91, Wildtype: A, Mutant: C, Reduced Pair: A91C, Unreduced Pair: T91S, Delta E: -8.415324157569557, Frequency: 0.008581436077057794
# Position: 91, Wildtype: A, Mutant: D, Reduced Pair: A91D, Unreduced Pair: T91V, Delta E: -8.805117657408118, Frequency: 0.0005253940455341507
# Position: 92, Wildtype: A, Mutant: B, Reduced Pair: A92B, Unreduced Pair: Q92S, Delta E: -6.671047427691519, Frequency: 0.0003502626970227671
# Position: 92, Wildtype: A, Mutant: C, Reduced Pair: A92C, Unreduced Pair: Q92R, Delta E: -5.423410840332508, Frequency: 0.008756567425569177
# Position: 92, Wildtype: A, Mutant: D, Reduced Pair: A92D, Unreduced Pair: Q92K, Delta E: -5.77898752130568, Frequency: 0.021716287215411557
# Position: 93, Wildtype: A, Mutant: B, Reduced Pair: A93B, Unreduced Pair: I93L, Delta E: -1.9300910958554596, Frequency: 0.37828371278458844
# Position: 93, Wildtype: A, Mutant: C, Reduced Pair: A93C, Unreduced Pair: I93M, Delta E: -7.950536452233791, Frequency: 0.003852889667250438
# Position: 95, Wildtype: B, Mutant: A, Reduced Pair: B95A, Unreduced Pair: C95V, Delta E: -8.31280779838562, Frequency: 0.0010507880910683013
# Position: 95, Wildtype: B, Mutant: C, Reduced Pair: B95C, Unreduced Pair: C95F, Delta E: -8.550135157071054, Frequency: 0.016987740805604203
# Position: 95, Wildtype: B, Mutant: D, Reduced Pair: B95D, Unreduced Pair: C95S, Delta E: -6.095293398946524, Frequency: 0.002276707530647986
# Position: 96, Wildtype: C, Mutant: D, Reduced Pair: C96D, Unreduced Pair: T96S, Delta E: -5.233797535300255, Frequency: 0.003327495621716287
# Position: 97, Wildtype: C, Mutant: B, Reduced Pair: C97B, Unreduced Pair: L97F, Delta E: -7.727255713194609, Frequency: 0.0007005253940455342
# Position: 98, Wildtype: B, Mutant: C, Reduced Pair: B98C, Unreduced Pair: N98K, Delta E: -6.89091314189136, Frequency: 0.0003502626970227671
# Position: 99, Wildtype: B, Mutant: A, Reduced Pair: B99A, Unreduced Pair: F99L, Delta E: -4.999852022156119, Frequency: 0.0007005253940455342
# Position: 99, Wildtype: B, Mutant: C, Reduced Pair: B99C, Unreduced Pair: F99Y, Delta E: -11.621473886072636, Frequency: 0.0007005253940455342
# Filtered delta E dictionary:
# Position 2: [-8.569090587086976]
# Position 3: [-8.155805517919362]
# Position 4: [-9.062162205576897, -5.582528863102198]
# Position 5: [-8.509819394443184]
# Position 6: [-10.011449309065938, -10.609377598389983]
# Position 7: [-8.150218181312084, -6.7850492196157575, -6.993757659569383]
# Position 8: [-7.00242667645216]
# Position 10: [-4.653488149866462, -5.01730927452445, -3.001409363001585]
# Position 11: [-6.655691193416715, -8.730066085234284, -9.590635046362877]
# Position 12: [-4.187727555632591, -2.6436189003288746, -5.369526390917599]
# Position 13: [-8.335788495838642, -2.0054782573133707, -10.403790419921279]
# Position 14: [-6.144697094336152, -7.580942366272211, -2.5640227664262056]
# Position 15: [-6.1875506937503815, -1.2176780756562948]
# Position 16: [-9.739111291244626, -5.409278167411685, -4.092847662046552]
# Position 17: [-5.095459245145321, -5.417207387275994]
# Position 18: [-6.523982964456081, -5.552409275434911, -6.132597170770168]
# Position 19: [-3.9864791333675385, -2.290499497205019, -4.586674952879548]
# Position 20: [-4.384629253298044, -7.058664083480835, -6.121196448802948]
# Position 21: [-10.824223658069968, -10.730192564427853]
# Position 22: [-7.664188075810671]
# Position 23: [-7.098663568496704]
# Position 24: [-11.017500375397503, -9.962894095107913, -5.855606945231557]
# Position 25: [-8.308421857655048]
# Position 30: [-3.382656466215849]
# Position 32: [-4.815646150149405]
# Position 33: [-5.288293277844787, -6.287820678204298, -4.099870256148279]
# Position 34: [-9.353041347116232, -6.550491392612457]
# Position 35: [-6.343857496976852, -8.829890800639987, -2.331563889980316]
# Position 36: [-2.3546141143888235, -6.175913233309984, -6.11498171184212]
# Position 37: [-1.4973157942295074, -2.2011372735723853, -6.45199696905911]
# Position 38: [-8.106619467958808, -9.294002560898662, -9.087001010775566]
# Position 39: [-4.98798324726522, -6.238044636324048, -6.022555805742741]
# Position 41: [-8.949488156475127, -1.648823875002563, -9.241893777623773]
# Position 42: [-7.923373926430941]
# Position 43: [-8.318119537085295, -5.005974722094834, -6.025289632380009]
# Position 45: [-7.076484648510814, -5.952788991853595, -7.306345196440816]
# Position 46: [-7.276908309664577, -4.170426114462316, -3.3616930274292827]
# Position 47: [-6.0373359471559525]
# Position 48: [-5.687661450356245, -9.055708531290293]
# Position 50: [-5.949911307543516]
# Position 51: [-6.645985446870327]
# Position 53: [-7.764082534238696, -5.5772942253388464, -8.760242585092783]
# Position 54: [-8.926516810432076, -5.994870617985725, -4.856022844091058]
# Position 55: [-9.483021503314376, -5.94481373205781]
# Position 57: [-2.8724094219505787]
# Position 58: [-5.300967089831829]
# Position 59: [-9.417893454432487, -8.140889152884483]
# Position 60: [-9.161925805732608, -3.3457519710063934]
# Position 61: [-5.022668680176139, -5.175345990806818, -5.732071686536074]
# Position 62: [-6.96057428047061, -7.258390585426241, -2.647924415767193]
# Position 63: [-1.3014670573174953, -1.3407612089067698, 0.6627579350024462]
# Position 64: [-4.805004488676786, -0.34102187864482403, -3.83797044493258]
# Position 65: [-5.844754254445434, -4.248809158336371]
# Position 66: [-6.300214609131217, -7.72937775705941]
# Position 67: [-5.94923597574234, -6.0370502937585115, -7.61973680742085]
# Position 68: [-9.697556464001536, -8.193549243733287]
# Position 69: [-3.4084097761660814, -3.4026348404586315, -4.185484001412988]
# Position 70: [-5.570231262594461, -3.538477124646306]
# Position 71: [-2.99257527384907, -3.673072336241603, -7.438210319727659]
# Position 72: [-4.82531613856554, -5.184749566018581, -3.040552747435868]
# Position 73: [-6.614708553999662, -5.399553783237934, -6.983710002154112]
# Position 74: [-5.3937480263412, -4.3030765894800425, -6.635017279535532]
# Position 75: [-6.08254636451602]
# Position 76: [-6.4508815333247185]
# Position 77: [-7.781090852571651, -8.23680654913187, -1.1932113207876682]
# Position 78: [-6.4142729844897985]
# Position 79: [-7.894936518743634, -7.66937146242708, -7.104824800044298]
# Position 82: [-4.716043089982122, -3.229635303840041, -4.556624655611813]
# Position 83: [-7.82513015717268, -9.594795100390911]
# Position 84: [-4.271495623514056, -10.656731452792883]
# Position 85: [-5.46059525385499]
# Position 87: [-8.309783663600683, -7.410864464938641]
# Position 88: [-7.82917071133852, -6.1018384248018265, -4.753562597557902]
# Position 89: [-6.001091204583645, -5.999609299004078, -4.582768753170967]
# Position 90: [-6.697970561683178, -3.5690470281988382]
# Position 91: [-7.960727773606777, -8.415324157569557, -8.805117657408118]
# Position 92: [-6.671047427691519, -5.423410840332508, -5.77898752130568]
# Position 93: [-1.9300910958554596, -7.950536452233791]
# Position 95: [-8.31280779838562, -8.550135157071054, -6.095293398946524]
# Position 96: [-5.233797535300255]
# Position 97: [-7.727255713194609]
# Position 98: [-6.89091314189136]
# Position 99: [-4.999852022156119, -11.621473886072636]

# %%
# Find the largest and smallest values in filtered_delta_e_dict
largest_value = max(max(values) for values in filtered_delta_e_dict.values() if values)
smallest_value = min(min(values) for values in filtered_delta_e_dict.values() if values)

print(f"Largest value in filtered_delta_e_dict: {largest_value}")
print(f"Smallest value in filtered_delta_e_dict: {smallest_value}")
# Out:
# Largest value in filtered_delta_e_dict: 0.6627579350024462
# Smallest value in filtered_delta_e_dict: -11.621473886072636

# %%
# Add a line track for filtered_delta_e_values
line_track = sector.add_track((68, 88), r_pad_ratio=0.1)
line_track.axis()
# Add scatter plot for delta_e_per_position
# Configure axis and ticks
line_track.yticks(
    [0, 5, 10, 15, 20],  # Positions
    ["-15","-10","-5", "0", "5"],  # Labels
    side="left",
    line_kws=dict(color="black", lw=1),
    text_kws=dict(color="black", size=8)
)

# Add grid lines for the values
line_track.grid(
    y_grid_num=5,  # Number of grid lines
    color="grey",
    lw=0.5,
    ls="--"
)

# # Plot the filtered delta E values as a line
# x_positions = np.arange(1, len(filtered_delta_e_values) + 1)  # X-axis positions
# line_track.line(x_positions, filtered_delta_e_values, lw=1.5, color="blue")

# # Add color-filled areas based on the values
# for i in range(len(filtered_delta_e_values) - 1):
#     x = [x_positions[i], x_positions[i + 1], x_positions[i + 1], x_positions[i]]
#     y = [0, 0, filtered_delta_e_values[i + 1], filtered_delta_e_values[i]]
#     color = "red" if filtered_delta_e_values[i] < 0 else "green"
#     line_track.fill(x, y, fc=color, ec="none", alpha=0.5)

# Plot all the delta E values from filtered_delta_e_dict
# Define the color map for the scatter plot
scatter_cmap_positive = cm.get_cmap("Purples")
scatter_cmap_negative = cm.get_cmap("Oranges_r")
scatter_norm_positive = colors.Normalize(vmin=0, vmax=largest_value)
scatter_norm_negative = colors.Normalize(vmin=smallest_value, vmax=0)

for x_key, y_values in filtered_delta_e_dict.items():
    # Add 15 to each y value and plot it on the grid
    for y_value in y_values:
        if y_value >= 0:
            adjusted_color = scatter_cmap_positive(scatter_norm_positive(y_value))
        else:
            adjusted_color = scatter_cmap_negative(scatter_norm_negative(y_value))
        line_track.scatter([x_key-1], [(y_value + 15)], vmax=20, s=10, color=adjusted_color, alpha=0.7)

fig = circos.plotfig()
plt.show()
# Out:
# /var/folders/17/rj19bvws2qscyfjmb7m44zmm0000gn/T/ipykernel_14697/3995997023.py:35: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   scatter_cmap_positive = cm.get_cmap("Purples")
# /var/folders/17/rj19bvws2qscyfjmb7m44zmm0000gn/T/ipykernel_14697/3995997023.py:36: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   scatter_cmap_negative = cm.get_cmap("Oranges_r")

# %% [markdown]
# with data from delta_delta_e_per_pair, add a track of cytoband (0-40) connect all the positions with delta delta e value >5.5 or dde <2 colored with color scheme PiYG
#
# use api from this example, code should be different:
#
# from pycirclize import Circos
# from pycirclize.utils import ColorCycler, load_eukaryote_example_dataset
#
# # Load hg38 dataset (https://github.com/moshi4/pycirclize-data/tree/main/eukaryote/hg38)
# chr_bed_file, cytoband_file, chr_links = load_eukaryote_example_dataset("hg38")
#
# # Initialize Circos from BED chromosomes
# circos = Circos.initialize_from_bed(chr_bed_file, space=3)
# circos.text("Homo sapiens\n(hg38)", deg=315, r=150, size=12)
#
# # Add cytoband tracks from cytoband file
# circos.add_cytoband_tracks((95, 100), cytoband_file)
#
# # Create chromosome color dict
# ColorCycler.set_cmap("hsv")
# chr_names = [s.name for s in circos.sectors]
# colors = ColorCycler.get_color_list(len(chr_names))
# chr_name2color = {name: color for name, color in zip(chr_names, colors)}
#
# # Plot chromosome name & xticks
# for sector in circos.sectors:
#     sector.text(sector.name, r=120, size=10, color=chr_name2color[sector.name])
#     sector.get_track("cytoband").xticks_by_interval(
#         40000000,
#         label_size=8,
#         label_orientation="vertical",
#         label_formatter=lambda v: f"{v / 1000000:.0f} Mb",
#     )
#
# # Plot chromosome link
# for link in chr_links:
#     region1 = (link.query_chr, link.query_start, link.query_end)
#     region2 = (link.ref_chr, link.ref_start, link.ref_end)
#     color = chr_name2color[link.query_chr]
#     if link.query_chr in ("chr1", "chr8", "chr16") and link.query_chr != link.ref_chr:
#         circos.link(region1, region2, color=color)
#
# fig = circos.plotfig()

# %%
# Add a track for the chords spanning 0-40
# chord_track = sector.add_track((0, 40))
df = pd.read_csv('data/PR_all_100pairs.tsv', sep='\t')
# anta_max = df[df['DR_position'] == 1]['ddE'].min()
# syner_min = df[df['DR_position'] == 1]['ddE'].max()

anta_max = -3.683883
syner_min = 8.50879

print(f"Antagonistic max (min ddE): {anta_max}")
print(f"Synergistic min (max ddE): {syner_min}")
# Define the color map for the chords
chord_cmap = cm.get_cmap("bwr_r")
chord_norm = colors.Normalize(vmin=anta_max, vmax=syner_min)
thickness = 0.5
thickness_d2 = thickness/2
background_thikness = 0.5
background_thickness_d2 = background_thikness/2

##########################background chords for drug resistant positions###############################
# Read the data from the TSV file
df = pd.read_csv('data/PR_all_100pairs.tsv', sep='\t')

# Add a DR_position column based on ddE values
# df['DR_position'] = 0

# Filter for DR_position = 0 (background chords)
background_pairs = df[df['DR_position'] == 0]

# Add background chords
for _, row in tqdm(background_pairs.iterrows(), total=len(background_pairs), desc="Processing background chords"):
    pos1, pos2, dde = row['pos1'], row['pos2'], row['ddE']
    
    # Define regions for the chord
    region1 = ("nl43 ΔΔE", pos1 - background_thickness_d2 - start_aa, pos1 + background_thickness_d2 - start_aa)
    region2 = ("nl43 ΔΔE", pos2 - background_thickness_d2 - start_aa, pos2 + background_thickness_d2 - start_aa)
    
    # Check if the regions are within valid bounds
    if region1[1] < 0 or region1[2] > actual_length or region2[1] < 0 or region2[2] > actual_length:
        continue
    
    # Use light gray color for background
    light_gray_color = "#e6e6fa"
    circos.link(region1, region2, color=light_gray_color)

##########################highlighted chords for drug resistant positions###############################

# Filter for DR_position = 1 (drug resistant pairs)
df = pd.read_csv('data/PR_all_100pairs.tsv', sep='\t')
dr_pairs = df[df['DR_position'] == 1]

# Add drug resistant chords with the same style as background
for _, row in tqdm(dr_pairs.iterrows(), total=len(dr_pairs), desc="Processing DR chords"):
    pos1, pos2, dde = row['pos1'], row['pos2'], row['ddE']
    
    # Define regions for the chord
    region1 = ("nl43 ΔΔE", pos1 - thickness_d2 - start_aa, pos1 + thickness_d2 - start_aa)
    region2 = ("nl43 ΔΔE", pos2 - thickness_d2 - start_aa, pos2 + thickness_d2 - start_aa)
    
    # Check if the regions are within valid bounds
    if region1[1] < 0 or region1[2] > actual_length or region2[1] < 0 or region2[2] > actual_length:
        continue
    
    # Map the delta delta E value to a color using the same colormap as the original selection

    color = chord_cmap(chord_norm(dde))
    
    # Add the chord to the circos plot
    circos.link(region1, region2, color=color, lw=0.01)

# Add a color bar for the chords
chord_mappable = cm.ScalarMappable(norm=chord_norm, cmap=chord_cmap)
fig = circos.plotfig()
# Out:
# /var/folders/17/rj19bvws2qscyfjmb7m44zmm0000gn/T/ipykernel_14697/3119316381.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   chord_cmap = cm.get_cmap("bwr_r")
# Antagonistic max (min ddE): -3.683883
# Synergistic min (max ddE): 8.50879
# Processing background chords: 100%|██████████| 55/55 [00:00<00:00, 2350.42it/s]

# %% [markdown]
# add the above negative de and positive de graphs together, but shrik the length of the positive de colormap length by 10 times

# %%
import matplotlib as mpl

# Calculate new data_min and data_max from filtered_delta_e_values
data_min = min(filtered_delta_e_values)
data_max = max(filtered_delta_e_values)

# Add 0.5% padding
padding = 0.005 * (data_max - data_min)
vmin = data_min - padding
vmax = data_max + padding
vcenter = 0

# Define new ticks based on the range
all_ticks = np.arange(np.floor(data_min) + 1, np.ceil(data_max) + 1, 1)  # Ticks from floor(data_min) + 1 to ceil(data_max)

# Build shifted colormap
def shifted_cmap(cmap_neg, cmap_pos, vmin, vmax, vcenter, name="shiftedcmap"):
    """Create a shifted diverging colormap with two different cmaps."""
    midpoint = (vcenter - vmin) / (vmax - vmin)
    cdict = {"red": [], "green": [], "blue": []}

    # Negative side
    reg_index_neg = np.linspace(0, 1, 128, endpoint=False)
    shift_index_neg = np.linspace(0.0, midpoint, 128, endpoint=False)
    for ri, si in zip(reg_index_neg, shift_index_neg):
        r, g, b, _ = cmap_neg(ri)
        cdict["red"].append((si, r, r))
        cdict["green"].append((si, g, g))
        cdict["blue"].append((si, b, b))

    # Positive side
    reg_index_pos = np.linspace(0, 1, 129, endpoint=True)
    shift_index_pos = np.linspace(midpoint, 1.0, 129, endpoint=True)
    for ri, si in zip(reg_index_pos, shift_index_pos):
        r, g, b, _ = cmap_pos(ri)
        cdict["red"].append((si, r, r))
        cdict["green"].append((si, g, g))
        cdict["blue"].append((si, b, b))

    newcmap = mpl.colors.LinearSegmentedColormap(name, cdict)
    return newcmap

cmap = shifted_cmap(plt.cm.Oranges_r, plt.cm.Purples, vmin, vmax, vcenter)
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)

# Plot with vertical orientation and slimmer bar
fig, ax = plt.subplots(figsize=(1, 8))
fig.subplots_adjust(left=0.5)

cb = mpl.colorbar.ColorbarBase(ax, cmap=cmap, norm=norm, orientation="vertical")
cb.set_ticks(all_ticks)
cb.set_ticklabels([f"{t:.2f}" for t in all_ticks])

cb.set_label("ΔE Values", rotation=90, labelpad=15)
plt.show()

# %% [markdown]
# combine the two above color bar dde and de together, but unify the label sizes, paddings and colormap size

# %%
def shifted_cmap_bwr_vibrant(cmap, vmin, vmax, vcenter, name="shiftedcmap_bwr_vibrant"):
    """Create a shifted diverging colormap using vibrant tones of bwr."""
    midpoint = (vcenter - vmin) / (vmax - vmin)
    cdict = {"red": [], "green": [], "blue": []}

    # Negative side (vibrant tones of bwr)
    reg_index_neg = np.linspace(0, 0.5, 128, endpoint=False)
    shift_index_neg = np.linspace(0.0, midpoint, 128, endpoint=False)
    for ri, si in zip(reg_index_neg, shift_index_neg):
        r, g, b, _ = cmap(ri)
        cdict["red"].append((si, r, r))
        cdict["green"].append((si, g, g))
        cdict["blue"].append((si, b, b))

    # Positive side (vibrant tones of bwr)
    reg_index_pos = np.linspace(0.5, 1, 129, endpoint=True)
    shift_index_pos = np.linspace(midpoint, 1.0, 129, endpoint=True)
    for ri, si in zip(reg_index_pos, shift_index_pos):
        r, g, b, _ = cmap(ri)
        cdict["red"].append((si, r, r))
        cdict["green"].append((si, g, g))
        cdict["blue"].append((si, b, b))

    newcmap = mpl.colors.LinearSegmentedColormap(name, cdict)
    return newcmap


# Define the range for the new colormap
vmin_new = -3.68
vmax_new = 4.61
vcenter_new = 0

# Create the shifted colormap using vibrant tones of bwr
cmap_bwr_vibrant = shifted_cmap_bwr_vibrant(plt.cm.bwr_r, vmin_new, vmax_new, vcenter_new)
norm_bwr_vibrant = mpl.colors.Normalize(vmin=vmin_new, vmax=vmax_new)

# Plot the new colormap
fig, ax = plt.subplots(figsize=(1, 8))
fig.subplots_adjust(left=0.5)
cb = mpl.colorbar.ColorbarBase(ax, cmap=cmap_bwr_vibrant, norm=norm_bwr_vibrant, orientation="vertical")
cb.set_label("ΔΔE Values", rotation=90, labelpad=15)
plt.show()
